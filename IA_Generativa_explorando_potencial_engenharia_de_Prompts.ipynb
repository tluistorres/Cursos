# %% [markdown]
# <a href="https://colab.research.google.com/github/tluistorres/Cursos/blob/main/IA_Generativa_explorando_potencial_engenharia_de_Prompts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Image Inteligência Artificial Generativa.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Aula 01 - IAs de texto**

# %% [markdown]
# **Usando o ChatGPT**

# %% [markdown]
# Para começarmos nosso curso introdutório sobre inteligência artificial, vamos iniciar com os famosos LLM. A sigla LLM, que se tornou muito popular nos últimos anos, significa Large Language Models (Grandes Modelos de Linguagem). O exemplo mais popular até o momento é o ChatGPT, que vamos abrir agora.
#
# Ao abrir a janela do ChatGPT depois de fazer o login, você verá um menu do lado esquerdo com as últimas perguntas ou prompts. Os prompts são perguntas ou pedidos que você fará para esse modelo. No topo, você pode ver que, no momento em que estamos gravando esse curso, a versão mais atualizada é o ChatGPT 4o. O "O" é uma abreviação de Omni.
#
# Basicamente, o ChatGPT é um produto com o qual você terá uma conversa com a inteligência artificial. A inteligência por trás dele, é chamado de versão 4o. Se você clicar em cima da versão atual no topo da página, ele oferecerá algumas outras possibilidades de versões mais antigas, como o GPT-4, o GPT-3.5 e o GPT-4o Mini, um pouco mais rápido, mas um pouco menos inteligente do que a versão 4o.
#
# Como diz no próprio site, "GPT-4o Best for Complex Tasks", é a melhor versão para tarefas complexas. Ela é um pouco mais lenta do que o 4o Mini, mas tem, entre aspas, um "raciocínio lógico" melhor.
#
# A parte mais importante é o campo na parte inferior da tela, onde está escrito "Message ChatGPT" (Mandar uma mensagem para o ChatGPT). Nessa parte, você vai inserir o prompt, que é um pedido, a mensagem, o que você vai escrever, perguntar para esse modelo de inteligência artificial.
#
# Para começarmos a testar esse modelo, vamos fazer uma pergunta muito básica. Vamos pedir para ele escrever uma poesia sobre a Itália. Ao fazer isso, ele começa a escrever uma poesia para nós.

# %%
Itália, terra de sol e arte,
Teu céu azul, um mar que parte.
De Roma antiga, histórias mil,
Coliseu, Fórum, coração gentil.

Nas ruas de Veneza, canais de amor,
Gôndolas deslizam, um sonho em flor.
Florença, berço do Renascimento,
Cores e formas, eterno momento.

A Toscana verde, colinas sem fim,
Vinhas e olivais, um vinho, um jardim.
Nápoles, o vulcão ao fundo,
Pizzas e sorrisos, um calor profundo.
(…)

# %% [markdown]
# Ele está rimando, pois sabe que em poesias, geralmente, há rimas. Esse modelo foi treinado com muito texto, então ele sabe que, geralmente, poesias têm rimas. Ele também inseriu pontos turísticos localizados naquele país.
#
# No entanto, esse exemplo não é muito útil no seu dia a dia de trabalho ou de estudos. Vamos, então, partir para um exemplo um pouco mais útil. Imagine que você trabalha em uma agência de viagens, e estão planejando uma campanha sobre viagens para a Itália.
#
# Para começarmos a criar uma nova pergunta, você pode simplesmente escrever no mesmo campo de "Message ChatGPT". No entanto, isso pode criar algum problema, porque ele vai manter a memória do que foi escrito anteriormente, nesse histórico de chat.
#
# Por isso, é recomendado que, quando quiser fazer uma atividade nova, não relacionada com a anterior, você crie uma nova janela de chat com o ChatGPT.
#
# Para fazer isso, clique no botão no topo da parte esquerda, no ícone que parece um lápis com um caderninho, escrito "New Chat" (Novo Chat). Quando você clica nele, ele abre uma janela completamente nova de chat, e aí você pode conversar do zero, é melhor para atividades novas.
#
# Vamos dizer que você queira fazer um post sobre alguns hotéis na cidade de Roma, na Itália. Então, vamos escrever outro prompt básico:

# %%
Me escreva sobre hotéis em Roma.

# %% [markdown]
# Ele começa a escrever, mas o resultado parece mais um artigo de post. Está muito genérico. Imagine que você quer realmente algo mais específico. É aqui que começamos a conversar sobre como desenvolver o seu prompt, o seu pedido, de uma maneira mais clara.
#
# Vamos dizer que agora vamos dar um prompt um pouco mais específico para ele. Vamos pedir, nesta mesma janela de histórico de conversa:

# %% [markdown]
# Me dê uma lista de 5 hotéis na cidade de Roma, na Itália. Eu quero hotéis que tenham sauna e que sejam amigáveis com crianças.

# %% [markdown]
# Esse é um prompt muito melhor, mais estruturado e mais claro também.
#
# Ele responde com uma lista de hotéis, exatamente como pedimos. E se buscarmos no Google, veremos que esses hotéis realmente existem e têm as características que pedimos.
#
# Continuando, imagine que você encontrou os hotéis que queria e agora quer focar nesses hotéis que têm sauna em Roma. Você pode pedir isso também para a inteligência artificial, ela sabe fazer isso. Vamos pedir o seguinte:

# %% [markdown]
# Transforme isso em um post de blog. Eu quero um parágrafo para cada hotel, destacando os pontos positivos de cada um. Não use listas. Use palavras intelectuais. Finalize com uma chamada para que a pessoa reserve agora mesmo.

# %% [markdown]
# Esse encerramento é muito comum em posts de blogs de agências. Ele cria exatamente o que pedimos. Um parágrafo para cada hotel, sem listas. Ele entende muito de texto, de línguas. Então, ele sabe o que é uma linguagem formal, o que é uma linguagem sofisticada e o que é uma linguagem informal com gírias.
#
# Mas também é possível que você esteja escrevendo para um público mais jovem. Talvez você tenha uma agência de viagens para adolescentes, pessoas que estão terminando o último ano do ensino médio, por exemplo, ou vão fazer uma viagem durante a faculdade.
#
# Isso precisaria talvez de uma linguagem menos sofisticada. Então, vamos pedir para ele reescrever o mesmo post, mas agora utilizando uma linguagem extremamente informal, com muitas gírias.

# %% [markdown]
# Reescreva o mesmo post, mas agora utilizando uma linguagem extremamente informal, com muitas gírias.

# %% [markdown]
# Ele reescreve o post exatamente como pedimos, usando uma linguagem extremamente informal e com muitas gírias. Isso mostra o poder de todas essas IAs, principalmente do ChatGPT. Vamos continuar explorando outras IAs nos próximas aulas.

# %% [markdown]
# ### **Descobrindo o Google Gemini**

# %% [markdown]
# No vídeo anterior, vimos como fazer perguntas e criar um post de blog no ChatGPT, uma IA generativa popular atualmente por gerar textos. No entanto, há outra IA que também tem ganhado destaque recentemente: o Gemini, do Google. Realizaremos tarefas semelhantes às anteriores, com os mesmos prompts, mas agora usando o Gemini. Neste caso, podemos literalmente copiar e colar os prompts utilizados.
#
# **Acesso ao Gemini**
#
# *Acesse a IA do Gemini no navegador e, se necessário, faça o login para começar a utilizar.*
#
# A estrutura do Gemini é muito semelhante à do ChatGPT. Do lado esquerdo, temos acesso às últimas perguntas e um botão para criar uma nova conversa. No topo, podemos escolher o modelo. Diferente do ChatGPT, o Gemini oferece dois modelos: a versão gratuita, chamada de Gemini, e a versão paga, chamada de Gemini Advanced. Não fica claro qual modelo específico está sendo usado, pois existem diferentes versões como o 1.0 Pro e 1.5 Pro. Vamos usar a versão gratuita, acessível a todos.
#
# **Testando o primeiro prompt**
#
# De volta à nossa janela do ChatGPT, vamos copiar o primeiro prompt que usamos anteriormente, colar no Gemini e pressionar "Enter" para ver o resultado.

# %% [markdown]
# Me dê uma lista de 5 hoteis na cidade de Roma, na Itália. Eu quero hoteis que tenham sauna e que sejam amigáveis com crianças.

# %% [markdown]
# **A resposta do Gemini foi a seguinte:**
#
# Google Hotels
#
# O Gemini nem sempre acerta tudo. Certifique-se de verificar os seguintes detalhes do hotel:
#
# Hotéis em Roma, Itália 26 Jul - 27 Jul 2 adultos
#
# Encontrei alguns hotéis em Roma que têm sauna e são amigáveis com crianças:
#
# • Hotel Center 3 - Hotel de 3 estrelas por 61€ por noite.
#
# • Hotel 87 eighty-seven - Hotel de 4 estrelas por 149€ por noite.
#
# • Autohotel Roma Hotel por 62€ por noite.
#
# • All Time Relais & Sport Hotel - Hotel de 4 estrelas por 79€ por noite.
#
# • Relais De L'Opera - Hotel de 2 estrelas por 103€ por noite.
#
# Lembre-se de verificar as politicas do hotel em relação à idade das crianças e se há alguma taxa adicional para crianças.
#
# Você gostaria de saber mais sobre algum desses hotéis ou gostaria de pesquisar em outras áreas de Roma?

# %% [markdown]
# Interessante notar que o Gemini buscou informações no Google Hotels. O Google possui várias ferramentas, como o Google Maps, e uma delas é o Google Hotels. Se não tivéssemos essa extensão, poderíamos obter respostas apenas do conhecimento interno da IA, mas o Gemini também tem acesso às ferramentas da internet do Google, o que é uma vantagem.
#
# Ele até sugeriu datas específicas e forneceu o preço dos hotéis, pois conseguiu buscar no Google Hotels. Além disso, forneceu links que levam diretamente à página do Google Hotels, com preços e botões para reservar um quarto. Isso é muito interessante, pois ele mostra uma variedade de preços, como 61 euros por noite, 149 euros por noite, entre outros.
#
# **Testando o segundo prompt**
#
# Agora, vamos testar o segundo prompt que usamos no ChatGPT para ver como o Gemini irá respondê-lo:

# %% [markdown]
# Transforme isso em um post de blog. Eu quero um parágrafo para cada hotel, destacando os pontos positivos de cada um. Não use listas. Use palavras intelectuais. Finalize com uma chamada para que a pessoa reserve agora mesmo.

# %% [markdown]
# **Como resposta, obtemos o seguinte:**
#
# Google Hotels
#
# O Gemini nem sempre acerta tudo. Certifique-se de verificar os seguintes detalhes do hotel:
#
# Autohotel Roma em Roma, Itália 26 Jul - 27 Jul - 2 adultos
#
# Hotel 87 eighty-seven em Roma, Itália 26 Jul - 27 Jul - 2 adultos
#
# Hotel Center 3 em Roma, Itália 26 Jul - 27 Jul 2 adultos
#
# Relais De L'Opera em Roma, Itália 26 Jul - 27 Jul. 2 adultos
#
# Hotéis em Roma para famílias com crianças: Uma viagem inesquecível
#
# Roma, a Cidade Eterna, é um destino perfeito para familias com crianças. Com sua rica história cultura vibrante e beleza impressionante, Roma oferece uma infinidade de atividades para todas as idades. E para tornar sua viagem ainda mais especial, selecionamos alguns hotéis que oferecem sauna e são ideais para familias com crianças:
#
# 1. Hotel Center 3: Relaxamento e conforto a um preço acessível
#
# Hotel Center 3 (61€/noite) é um hotel de 3 estrelas que oferece uma excelente relação custo-beneficio. Com sauna e quartos confortáveis, este hotel é perfeito para familias que buscam uma estadia relaxante e sem preocupações.
#
# 2. Hotel 87 eighty-seven: Luxo e modernidade no coração de Roma
#
# Hotel 87 eighty-seven (149€/noite) é um hotel de 4 estrelas que oferece luxo e modernidade no coração de Roma. Com sauna, piscina e um design elegante, este hotel é ideal para familias que desejam uma experiência inesquecível.
#
# 3. Autohotel Roma: Uma opção econômica e prática
#
# Autohotel Roma (62€/noite) é uma opção econômica e prática para familias com crianças. Com sauna e quartos simples, este hotel oferece um bom custo-beneficio para quem busca uma estadia confortável e sem frescuras.
#
# Retorno omitido.
#
# Note que ele pesquisou no Google Hotels e conseguiu gerar um texto sobre Roma. Mas algo interessante a observar é que, apesar de termos pedido para não usar listas, o modelo acabou criando uma lista numerada. Ele realmente escreveu um parágrafo sobre cada hotel, mas estruturou o conteúdo em uma lista numerada.
#
# Esse comportamento destaca uma limitação desses modelos, especialmente as versões gratuitas, que tendem a ser menos robustas e são as disponibilizadas ao público. O Gemini pode cometer erros e, em sua resposta, encontramos o aviso "O Gemini nem sempre acerta tudo. Certifique-se de verificar os seguintes detalhes do hotel", alertando a importância de confirmar os detalhes fornecidos.
#
# Agora, podemos interagir com o modelo, dizendo algo como:

# %%
Você usou listas. Eu pedi um artigo sem listas.

# %% [markdown]
# Retorno omitido.
#
# Novamente, ao buscar no Google Hotels, ele retorna informações em formato de lista, o que pode ser um padrão imposto pelo próprio Google. É provável que esse formato seja uma particularidade do tipo de dados que ele está acessando. De qualquer forma, é fundamental lembrar que esses modelos nem sempre entregam resultados perfeitos!
#
# **Testando o terceiro prompt**
#
# Agora, utilizaremos o prompt que solicita a reescrita do post:

# %% [markdown]
# Reescreva o mesmo post, mas agora utilizando uma linguagem extremamente informal, com muitas girias.

# %% [markdown]
# A resposta do Gemini foi a seguinte:
#
# Roma com a galera: Hotéis massa pra galera curtir!
#
# Fala galera! Tá pensando em levar a galera pra curtir uma trip inesquecível pela Cidade Eterna? Roma é o destino ideal pra curtir com a familia toda, desde os pequeninos até os marmanjos. Mas pra viagem ser épica, precisa ter um hotel massa pra galera se esbaldar, né? Então, preparei essa lista com 5 opções que vão te deixar de queixo caído:
#
# 1. Happy Village e Camping Roma (R$ 1.200):
#
# Esse hotel é tipo um resort, mas com preços marat Tem sauna, piscina pra galera se refrescar e quartos confortáveis pra todo mundo relaxar depois de um dia explorando a cidade. É o lugar perfeito pra quem quer curtir uma vibe tranquila sem gastar muito.
#
# Retorno omitido.
#
# Perceba que ele ainda criou uma lista numerada, mas elaborou parágrafos para cada item. Podemos usar esse texto simplesmente removendo os números ou desenvolvendo mais o conteúdo.
#
# **Conclusão e próximos passos**
#
# Isso nos mostra, desde o início, algumas diferenças entre o ChatGPT e o Gemini. O Gemini, por exemplo, tendo acesso ao Google, pode oferecer informações mais claras, como preços de hotéis por noite. Podemos, inclusive, personalizar a busca, pedindo informações para diferentes números de adultos, e ele nos direciona diretamente para a página do Google Hotels.
#
# Além disso, parece que a versão gratuita do Gemini é atualmente menos poderosa que a versão gratuita do ChatGPT, considerando a época de gravação deste curso.
#
# Na próxima aula, exploraremos mais sobre como lidar com textos usando essas IAs!

# %% [markdown]
# **Lidando com textos**

# %% [markdown]
# Na última aula, concluímos a análise das diferenças entre o Google Gemini, uma IA generativa, e o ChatGPT, que também é uma IA generativa. Vamos continuar explorando textos usando essas duas IAs superpoderosas!
#
# Ainda estamos trabalhando na nossa agência de marketing, pensando em viajar para a Itália. Agora, em vez de um post de blog sobre hotéis, queremos gerar um e-mail.
#
# Suponha que um cliente esteja nos enviando um e-mail perguntando sobre mais informações de hotéis e viagens para a Itália. Poderíamos criar um e-mail personalizado para essa pessoa, usando a pergunta dela e a inteligência artificial.
#
# Criamos um modelo de e-mail com regras para o título e para o corpo do e-mail:
#
# **ChatGPT - E-mail**
#
# **Regras Títulos do e-mail**
#
# 1. Use títulos de até 42 caracteres
#
# 2. Não use caixa alta
#
# 3. Não use pontuação em excesso
#
# 4. Personalize com o nome da pessoa
#
# 5. Faça perguntas
#
# 6. Use emojis
#
# **Regras para corpo do e-mail**
#
# 1. Escreva em primeira pessoa, use tom pessoal
#
# 2. Use o nome da pessoa no início do e-mail
#
# 3. Coloque o nome da pessoa antes de uma pergunta
#
# 4. Use bullet points para organizar ideias
#
# 5. Faça parágrafos curtos
#
# 6. Dê um espaço entre uma frase e outra
#
# 7. Coloque em negrito palavras que são importantes no texto
#
# 8. Deixe a mensagem do botão de ação bem claro
#
# Você pode ter uma lista de regras para os títulos dos e-mails e para o corpo dos e-mails. Você pode passar essa regra como padrão e pedir para a IA redigir o e-mail seguindo essas regras.
#
# Vamos copiar todas essas regras para o mesmo prompt que usamos antes, onde estávamos falando sobre Roma e hotéis.
#
# Suponha que nosso cliente pediu para falar sobre hotéis que tenham sauna e que sejam amigáveis para crianças em Roma.
#
# Vamos colar as nossas regras para e-mail e especificar o que é um padrão.
#
# Por exemplo, como isso aqui é um título para as linhas abaixo, vamos colocar isso de alguma maneira diferente, podemos usar um hífen para destacar. O mesmo vale para o tema do e-mail, que será sobre hotéis na Itália.
#
# Podemos também dar um comando, que é altamente recomendável. Por exemplo:

# %%
Crie um e-mail para um cliente seguindo as regras abaixo:

- Regras Títulos
Use títulos de até 42 caracteres
Não use caixa alta
Não use pontuação em excesso
Personalize com o nome da pessoa
Faça perguntas
Use emojis

Regras para o corpo do e-mail

Escreva em primeira pessoa, use tom pessoal
Use o nome da pessoa no início do e-mail
Coloque o nome da pessoa antes de uma pergunta
Use bullet points para organizar ideias
Faça parágrafos curtos
Dê um espaço entre uma frase e outra
Coloque em negrito palavras que são importantes no texto
Deixe a mensagem do botão de ação bem claro

- Tema do email

O mesmo sobre o post acima sobre hotéis na Itália

# %% [markdown]
# A resposta dele foi a seguinte:
#
# Assunto: [Nome], já escolheu seu hotel em Roma?
#
# Olá, [Nome]!
#
# Espero que você esteja tendo um ótimo dia!
#
# Eu estava pensando em sua próxima viagem e me lembrei de algumas opções incríveis de hotéis em Roma que são perfeitas para familias com crianças. Sei que você ama explorar novas culturas e relaxar, então separei algumas sugestões de hotéis que combinam sauna e um ambiente kids-friendly.
#
# Aqui estão algumas opções que você pode gostar: (resposta omitida)
#
# Ele usou parágrafos curtos e bullet points para listar as ideias. Em vez de criar um parágrafo para cada hotel, usou bullet points para explicar as vantagens de cada hotel.
#
# **Fazendo o mesmo no Gemini**
#
# Vamos tentar fazer a mesma coisa no Gemini?
#
# Copiamos o nosso prompt e vamos colá-lo e executá-lo no Gemini.
#
# O Gemini também entendeu e conseguiu fazer.
#
# Roma com a galera: Hotéis massa pra curtir!
#
# Oi [Nome do Cliente],
#
# Pronto para levar a galera pra curtir uma trip inesquecível pela Cidade Eterna? Roma é o destino ideal para curtir com a família toda, desde os pequeninos até os marmanjos. Mas pra viagem ser épica, precisa ter um hotel massa pra galera se esbaldar, né?
#
# Então, preparei essa lista com 5 opções que vão te deixar de queixo caido:
#
# (resposta omitida)
#
# Ele fez com base na versão um pouco mais informal, enquanto o outro fez baseado na versão mais padrão ou neutra. Poderíamos pedir que ele escrevesse na versão usando mais gírias, versão mais informal.
#
# A qualidade para criar o e-mail é basicamente a mesma em ambos. Ele também adicionou algumas coisas interessantes, como uma observação de que os preços dos hotéis podem mudar e um botão para reservar o hotel agora. Isso é um grande poder, gerar e-mails a partir de pedidos, e vai ajudar muito na sua produtividade.
#
# **Adapte as regras para a sua área**
#
# Estávamos dando um dos possíveis exemplos aqui, que é para uma pessoa que trabalha em marketing, em agência de viagens, ou uma pessoa que trabalha com experiência do usuário, atendimento ao público. Você pode usar o seu padrão, o seu tom de voz, e ele colocar algumas regras que sejam específicas para você.
#
# Você poderia colocar regras que sejam válidas para você, para como você escreve e-mails dentro do seu trabalho, ou e-mails com os seus clientes, em uma área de finanças, em uma área de advocacia, que precisa de um vocabulário um pouco mais rebuscado ainda, mais técnico também, uma área de engenharia, com vocabulário mais da área de exatas. Isso pode ser aplicável para todas as áreas.
#
# **Resumo de texto com Inteligência Artificial**
#
# Vamos ver um pouco mais sobre o poder dessas IAs, que é na questão de fazer resumos de textos muito grandes.
#
# Para isso, vamos criar um novo chat, porque vamos usar um contexto diferente dessa vez. Mas se você quiser voltar naquele contexto dos hotéis, naquela nossa janela de chat, ele vai estar aqui do lado esquerdo, hotéis em Roma, você clica lá, o histórico completo vai estar aqui, para você ter acesso a isso posteriormente.
#
# Na Alura, temos um podcast chamado "[Hipsters Fora de Controle](https://)", que fala sobre inteligência artificial, as novidades nesse mundo. Uma coisa que usamos bastante é as transcrições desse podcast. Temos aqui um arquivo que tem a transcrição completa de um desses podcasts. É literalmente uma transcrição completa desse episódio, bem longa inclusive.
#
# Vamos copiar a transcrição inteira e pedir para o ChatGPT criar um resumo dessa transcrição.
#
# Porque imagine, você tem uma transcrição inteira, enorme, você não quer ler isso inteiro, você não quer talvez escutar o podcast inteiro. Vamos pedir para ela fazer um resumo para nós com o seguinte prompt:

# %% [markdown]
# Resuma a transcrição abaixo e me explique do que se trata
#
# -----
# (texto da transcrição)

# %% [markdown]
# Novamente, quando vamos dar um exemplo, é bom colocar alguma separação, aqui estamos usando o hífen.
#
# O ChatGPT fez o resumo muito rapidamente, em dois segundos e ela começou a explicar. Fez um resumo e uma explicação do podcast.
#
# Podemos fazer isso de outras maneiras. Podemos pedir: "faça o resumo ainda mais curto" ou até mesmo "faça o resumo em apenas uma frase".
#
# **Resumo de texto no Gemini**
#
# Uma última curiosidade para finalizar a nossa aula. Queremos usar o mesmo exemplo, só que no Google Gemini, para ver as diferenças. Como ele se diferencia nesse quesito?
#
# Vamos copiar o nosso prompt e vamos colá-lo e tentar executá-lo.
#
# Note que o campo de prompt do Gemini aceita menos caracteres. Como o texto da transcrição era muito grande, o texto foi cortado na metade. E ficou confuso na resposta que deveria nos dar.
#
# Isso é uma coisa que o modelo gratuito do Gemini é menos poderoso quando comparado com o modelo gratuito do ChatGPT.
#
# O Gemini respondeu:
#
# Não tenho informações suficientes sobre essa pessoa para responder. Os textos que eu crio imitam a comunicação de vocês, humanos, em resposta a uma variedade de perguntas e comandos, já que sou um modelo de linguagem de grande escala. Porém, ainda não sei muito sobre essa pessoa. Tem alguma outra coisa que você quer saber?
#
# Com isso, aprendemos que diferentes IAs vão funcionar de modos diferentes. Isso não quer dizer que o Gemini é menos poderoso no geral.
#
# Na próxima aula, vamos aprender mais sobre essas Inteligências Artificiais!

# %% [markdown]
# **Aprimorando o contexto**
#
# Como vimos em aula, é importante que o comando enviado para a IA generativa tenha um contexto bem definido. Existem diferentes técnicas já estudadas para elaborar bons prompts, e uma das mais utilizadas é a utilização de exemplos.
#
# **Qual é o benefício de usar exemplos específicos em um prompt ao interagir com o ChatGPT ou o Gemini?**
#
# a)
# Reduz a necessidade de fornecer contexto adicional.
#
# b)
# Aumenta a ambiguidade da resposta.
#
# c)
# Reduz a complexidade do prompt.
#
# d)
# **Garante que o modelo forneça respostas mais precisas e relevantes.**
#
# Os exemplos enriquecem o contexto definido no prompt e o texto gerado pela IA terá o tom de voz e formato baseado nos exemplos fornecidos.

# %% [markdown]
# ### **Mão na massa: criando conteúdo para um blog de alimentação saudável**

# %% [markdown]
# Vamos praticar!
#
# Nas aulas anteriores, utilizamos o ChatGPT e o Gemini como assistentes em uma agência de viagens. Descobrimos hotéis na Itália com características específicas e criamos posts de blog e um e-mail dentro desse mesmo contexto.
#
# Agora, experimente criar um post de blog que fale sobre alimentação saudável e que forneça algumas receitas.
#
# Certifique-se de fornecer as instruções para que o resultado seja o que você busca. Use a criatividade!

# %% [markdown]
# **Opinião do instrutor**
#
# Existem muitas formas de obter um bom resultado ao interagir com IAs generativas. Porém, o mais importante é que o comando seja claro e tenha as preferências especificadas.
#
# Aqui está um exemplo de como o prompt para gerar o post de blog sobre alimentação saudável poderia ser:
#
# Crie um texto para blog.

# %%
Crie um texto para blog.

- o tema é alimentação saudável que também pode ser prazerosa
- o tom deve ser informal, mas com pouco uso de gírias
- use emojis
- dê 3 opções de receitas vegetarianas e saudáveis para um café da manhã
reforçado
- não use listas

# %% [markdown]
# O texto que foi gerado a partir desse prompt é descontraído e atendeu a todos os pedidos.

# %% [markdown]
# **Para saber mais**
#
#
# É bastante impressionante ver a IA generativa funcionando pela primeira vez. Os modelos de linguagem como o Gemini e o ChatGPT são verdadeiras revoluções na área de Inteligência Artificial - principalmente pelo alcance às mãos de qualquer pessoa com acesso à internet.
#
# Se conhecer esses modelos despertou sua curiosidade acerca do tema, leia o artigo [ChatGPT: o que é, como usar e dicas de comandos para o dia a dia](https://) e também [O que é Inteligência Artificial? Como funciona uma IA, quais os tipos e exemplos](https://).

# %% [markdown]
# O artigo "ChatGPT: o que é, como usar e dicas de comandos para o dia a dia" da Alura apresenta o ChatGPT como um modelo de linguagem avançado da OpenAI, baseado na arquitetura GPT (Generative Pre-trained Transformer). Ele foi treinado em uma vasta quantidade de dados textuais para gerar respostas coerentes e relevantes em diversos tópicos, interagindo de forma similar a uma conversa humana.
#
# O artigo explora a relevância do ChatGPT no campo da Inteligência Artificial, destacando sua capacidade de compreender e responder a perguntas, fornecer informações e realizar tarefas baseadas em texto de maneira eficiente. Ele também aborda as diretrizes éticas e limitações do ChatGPT, além de fornecer dicas sobre como usá-lo de forma eficaz, incluindo exemplos de uso em desenvolvimento de códigos de programação, correção de erros e geração de inputs.

# %% [markdown]
# **O que aprendemos?**
#
# **Nesta aula, aprendemos:**
#
#  - Usar as plataformas ChatGPT e Gemini para gerar textos.
#
#  - Manipular o tipo de linguagem que queremos em nossos textos.
#
#  - Gerar e-mails a partir de um conjunto de regras.
#
#  - Gerar resumos de textos longos com LLMs.

# %% [markdown]
# ### **Aula 02 - Modelos de linguagem**

# %% [markdown]
# **O que é e como funciona um modelo de linguagem?**

# %% [markdown]
# Na primeira aula, acompanhamos demonstrações de como utilizar todo o poder dos modelos de linguagem, as LLMs e IAs generativas, como o ChatGPT e o Google Gemini. Agora, podemos aprofundar nossos estudos e entender o que são modelos de linguagem e como eles funcionam.
#
# **O que é um modelo de linguagem?**
#
# Quando falamos em modelos de linguagem, estamos nos referindo a uma área da inteligência artificial chamada de NLP (Natural Language Processing - Processamento de Linguagem Natural).
#
# Essa área busca conduzir, organizar e estudar a comunicação entre seres humanos e máquinas utilizando a linguagem natural. Ou seja, em vez de criar um código e utilizar linguagens de programação, você pode simplesmente falar ou escrever para o computador, da mesma maneira que faria com outra pessoa, e o computador entenderá e responderá de acordo.
#
# Os modelos de linguagem tentam fazer isso, sendo treinados para entender os padrões de uma língua.
#
# Um exemplo interessante é que, na língua portuguesa, sempre que usamos o verbo gostar, sempre temos a preposição "de" logo depois, antes do objeto, como "gosto de viajar" ou "gosto de pizza". Isso é um padrão da língua portuguesa.
#
# Porém, na língua inglesa, o padrão é um pouco diferente. Eles constroem, por exemplo, a frase "I like traveling" (eu gosto de viajar), ou "I like pizza" (eu gosto de pizza), e não há uma preposição entre o verbo e o objeto. Esse é um padrão da língua inglesa, que é diferente do padrão da língua portuguesa.
#
# Esses modelos, quando treinados com grandes bases de dados (usando dados disponíveis da internet inteira, talvez), entendem esses padrões de uma língua - seja o padrão da gramática, seja o padrão semântico (de significado do texto).
#
# Esses treinamentos são feitos utilizando técnicas e arquiteturas de inteligência artificial por trás, por meio de hardwares muito poderosos, que são as GPUs. Você poderá ler mais sobre isso na seção "Para Saber Mais" desta aula.
#
# Ou seja, o que ChatGPT e o Google Gemini fazem é simplesmente calcular a probabilidade da próxima palavra em uma frase, mais ou menos como uma versão super poderosa do autocompletar do seu celular, dado um contexto específico.
#
# Por exemplo, quando digitamos no celular "eu gosto", a parte superior dele sugere automaticamente as preposições "de", "do" e "da", ou mesmo a palavra "muito", como próxima palavra provável na frase. Esse é um cálculo parecido com o que a LLM faz, de maneira bastante simplificada.
#
# **Como funciona um modelo de linguagem?**
#
# Para entender isso melhor, podemos fazer uma brincadeira utilizando o próprio ChatGPT. Vamos abrir um novo chat e enviar o seguinte prompt:

# %% [markdown]
# Vamos simular como funciona o ChatGPT.
#
# ***Para cada frase que eu escrever no prompt, você deve listar as 5 palavras com maior probabilidade que você usaria para completá-la, junto com a probabilidade de cada uma dela. Combinado? Apenas as palavras e probabilidades, sem mais nada.***

# %% [markdown]
# Demos as ordens, explicando exatamente o que queremos e não queremos. A resposta inicial é:
#
# *Entendido, vamos lá! Por favor, forneça a primeira frase para que eu possa continuar.*
#
# Para testá-lo, vamos enviar apenas:

# %%
Eu gosto de

# %% [markdown]
# As palavras e probabilidades listadas são:
#
# 1. chocolate - 0.35
#
# 2. viajar - 0.25
#
# 3. ler - 0.20
#
# 4. correr - 0.15
#
# 5. cozinhar - 0.05
#
# Esses números são fictícios, inventados para nossa brincadeira. Não são os números reais que a rede neural por trás do modelo usaria, mas serve para entendermos como ele funciona.
#
# Podemos continuar, escolhendo a primeira palavra. Vamos enviar:

# %%
Eu gosto de chocolate

# %% [markdown]
# A lista de palavras retornada muda, com novas probabilidades que fazem total sentido para a construção semântica e gramatical da língua portuguesa:
#
# 1. ao - 0.30
#
# 2. e - 0.25
#
# 3. porque - 0.20
#
# 4. mas - 0.15
#
# 5. com - 0.10
#
# Agora, vamos escolher a terceira palavra e enviar, por exemplo:

# %%
Eu gosto de chocolate porque

# %% [markdown]
# A lista de próximas palavras prováveis é:
#
# 1. é - 0.40
#
# 2. ele - 0.30
#
# 3. tem - 0.15
#
# 4. me - 0.10
#
# 5. é (em outra forma, como "é delicioso") - 0.05
#
# É assim que ele vai funcionando a cada vez. Ou seja, quando fornecemos um assunto para a LLM, como "Me escreva sobre hotéis em Roma", ela entende isso como contexto base para calcular probabilidades e escrever sua resposta.
#
# Nesse caso dos hotéis, o raciocínio é algo como: "se essa pessoa me pediu para escrever sobre algum assunto, provavelmente deseja um texto em formato de blog ou artigo de jornal". Então, ele começa com "Roma", depois uma vírgula, depois "a", depois "capital", depois "da", depois "Itália" - sempre calculando a probabilidade com base nas palavras anteriores, cumulativamente, com base em todo o conhecimento que ele tem.
#
# No processo de treinamento dessa tarefa, aperfeiçoamentos e refinamentos de seres humanos foram utilizados para melhorar as respostas, como um reforço para o aprendizado de máquina.
#
# **Memória contextual do chat**
#
# Vamos conferir outra revolução trazida pela OpenAI com o lançamento do ChatGPT como produto em novembro de 2022.
#
# Para isso, podemos criar um novo chat e enviar a seguinte pergunta:

# %% [markdown]
# ***Qual é o nome da fórmula de Excel para encontrar o maior número em uma lista de números? Responda apenas com o nome da fórmula.***

# %% [markdown]
# Ele respondeu apenas o nome da fórmula, conforme pedido: "MAX". Vamos responder:

# %%
Me dê um exemplo dessa fórmula.

# %% [markdown]
# Repare que não falamos, por exemplo, "me dê um exemplo da fórmula MAX", mas usamos o pronome demonstrativo "dessa". Mesmo assim, ele entende que estamos falando sobre a fórmula MAX devido ao contexto, e nos retorna um exemplo corretamente:
#
# ***Claro! Um exemplo de uso da fórmula MAX no Excel é: =MAX(A1:A10). Essa fórmula retornará o maior número presente no intervalo de células A1 e A10.***
#
# Essa foi a revolução: a memória contextual do chat. Ou seja, agora podemos utilizar modelos de linguagem não só para responder uma pergunta diretamente, ou para completar um texto diretamente, mas para ter um assistente real com quem podemos conversar num formato de chat. Esse foi, provavelmente, o principal causador da explosão dos modelos de IA generativa nesses últimos tempos.
#
# **Próximos passos**
#
# Na próxima aula, vamos abordar alguns conceitos sobre engenharia de prompt, ou seja, sobre como escrever melhor os seus prompts.

# %% [markdown]
# ### **Princípios da Engenharia de Prompt**

# %% [markdown]
# Nesta aula, vamos explorar alguns dos princípios da engenharia de prompt. Muitas pessoas podem estranhar esse termo, talvez por causa da palavra "engenharia", que geralmente é associada a campos como engenharia civil, elétrica, da computação, entre outros.
#
# No entanto, se pensarmos na etimologia da palavra "engenharia", ela se refere ao ato de desenhar, projetar, criar algo. Portanto, quando falamos de engenharia de prompt, estamos nos referindo ao processo de criar, projetar e "engenhar" o seu prompt - ou seja, o seu pedido para o modelo de IA - de forma que ele seja o melhor possível e que você obtenha a resposta que está esperando.
#
# **Melhorando o prompt**
#
# Já discutimos isso nas últimas aulas, mas vamos reforçar e dar dicas adicionais sobre como melhorar o prompt na hora de escrevê-lo. Para isso, vamos utilizar outro modelo de linguagem, o MariTalk, um modelo brasileiro e gratuito desenvolvido pela empresa Maritaca.
#
# Para acessá-lo, basta acessar o [site da MariTalk](https://), clicar em "Entrar" e nos autenticar. No vídeo, utilizaremos uma conta Google para isso.
#
# A estrutura da tela do MariTalk é muito semelhante à do ChatGPT e do Gemini. Para começar uma nova conversa, basta clicar no botão "Começar uma nova conversa", no canto superior esquerdo. O histórico de conversas anteriores também fica no lado esquerdo.
#
# No topo da tela principal, podemos escolher o modelo que desejamos usar. Durante a gravação deste vídeo, eles tinham o modelo Sabiá-2 pequeno (Small), o intermediário (Medium) e o 3, que é o modelo mais avançado. Manteremos a opção "Sabiá-3" selecionada.
#
# Como podemos criar prompts? Digamos que queiramos, assim como no exemplo do Excel, a fórmula para calcular a média. Então, vamos pedir para o MariTalk:

# %%
Me dê a fórmula da média.

# %% [markdown]
# Após pressionar "Enter", a IA começa a responder:
#
# A fórmula para calcular a média aritmética simples de um conjunto de valores é a soma de todos os valores dividida pelo total de valores.
#
# Matematicamente, se você tem um conjunto de valores (x_1, x_2, ..., x_n), a média (\bar{x}) é calculada como:
#
# [\bar{x} = \frac{x_1 + x_2 + … + x_n}{n}]
#
# Onde:
#
#  - (x_1, x_2, …, x_n) são os valores individuais do conjunto de dados.
#
#  - (n) é o número total de valores no conjunto de dados.
#
#  - (\bar{x}) é a média aritmética do conjunto de dados.
#
# No entanto, a fórmula que ele fornece é estranha. Você percebe onde erramos? Pedimos a fórmula da média, mas não especificamos qual média e qual fórmula.
#
# **Construindo um prompt claro**
#
# Portanto, uma das principais maneiras de melhorar o prompt é estruturá-lo de forma clara, como se fôssemos profissionais sêniores e estivéssemos explicando uma tarefa para uma pessoa estagiária que tem muito conhecimento, mas precisa de instruções claras.
#
# Vamos começar uma nova conversa na MariTalk e pedir o seguinte:

# %%
Me dê a fórmula em Excel que é usada para calcular a média aritmética.

# %% [markdown]
# Após o "Enter", notaremos a diferença na resposta.
#
# Para calcular a média aritmética de um conjunto de valores no Excel, você pode usar a função MÉDIA. Aqui está um exemplo de como você pode usar essa função:
#
# Suponha que você tenha um conjunto de valores nas células A1 a A5 e deseja calcular a média desses valores. Você usaria a seguinte fórmula:

# %%
=MÉDIA(A1:A5)

# %% [markdown]
# Essa fórmula vai somar todos os valores dentro do intervalo A1 até A5 e dividir pelo número de células que contêm valores numéricos nesse intervalo, resultando na média aritmética desses valores.
#
# Se você quiser incluir valores específicos, você pode listar os números separados por vírgulas diretamente na função, assim:

# %%
=MÉDIA(5, 10, 15, 20, 25)

# %% [markdown]
# Isso calcularia a média dos valores numéricos fornecidos diretamente na fórmula.
#
# Ele entendeu e forneceu a função MÉDIA do Excel, até mesmo com exemplos de código. Isso aconteceu porque explicamos com clareza que queríamos a fórmula do Excel, e não a fórmula geral da média.
#
# Essa é a regra principal que devemos ter em mente ao criar um prompt: ter clareza com os modelos de linguagem. Explique de maneira que uma pessoa menos experiente entenderia, dando o maior número de detalhes possíveis e salientando o que deve e o que não deve ser feito.
#
# Só de fazer isso de maneira clara, a chance de obter uma resposta desejada e correta será infinitamente maior.
#
# **Princípios de engenharia de prompt**
#
# Existem outros princípios que também são muito interessantes na engenharia de prompt. Vamos ver os princípios para a criação de um prompt ideal:
#
# 1. Ter clareza ao dar as instruções.
#
# 2. Dividir tarefas complexas em subtarefas menores.
#
# 3. Pedir para o modelo explicar os passos antes de dar a resposta.
#
# 4. Pedir para o modelo dar justificativas das respostas.
#
# 5. Usar a técnica de autoconsistência (self-consistency), que pode ser utilizada quando você quer fazer várias chamadas, pegando o resultado que for mais frequente.
#
# **Dividindo a tarefa em etapas**
#
# Voltando ao ChatGPT, vamos criar uma nova conversa. Nela, com base na conversa sobre hotéis em Roma que fizemos na aula 1, podemos enviar o seguinte prompt:

# %%
Passo 1 - Me dê uma lista de 5 hotéis em Roma que tenham sauna

Passo 2 - Escreva um artigo de blog sobre eles

Passo 3 - Crie um post para o Instagram com base no artigo de blog gerado

# %% [markdown]
# Esse problema não é tão grande, mas ao separá-lo, a IA entenderá que deve fazer um passo por vez. Isso resultará em uma resposta mais estruturada.
#
# **Passo 1 - Lista de Hotéis em Roma com Sauna**
#
# Aqui estão cinco hotéis em Roma que oferecem sauna:
#
# **1. Hotel Artemide** - Localizado no coração de Roma, este hotel é famoso por sua atmosfera elegante e serviços de spa, incluindo uma sauna e um centro de bem-estar completo. É ideal para relaxamento após explorar a cidade histórica.
#
# **2. Rocco Forte Hotel De La Ville** - Situado próximo aos degraus da Praça de Espanha, este hotel de luxo oferece uma experiência de spa sofisticada com sauna e outras comodidades de bem-estar. É conhecido pela sua elegância e serviço impecável.
#
# **3. A.Roma Lifestyle Hotel** - Este hotel é uma ótima opção para quem procura uma experiência moderna e relaxante. Além da sauna, o hotel dispõe de uma piscina e um centro de fitness, tornando-se um excelente lugar para relaxar.
#
# **4. Hotel Villa Pamphili Roma** - Este hotel é famoso por seu ambiente tranquilo e seus serviços de spa, incluindo uma sauna. É perfeito para quem procura um refúgio longe da agitação do centro da cidade.
#
# **5. Crowne Plaza Rome St. Peter's** - Este hotel oferece uma experiência completa de bem-estar com sauna, banho turco e tratamentos de spa. É uma ótima opção para famílias e viajantes a negócios que procuram relaxar. (Booking.com) (Booking.com)
#
# **Passo 2 - Artigo de Blog**
#
# **Descubra os Melhores Hotéis com Sauna em Roma**
#
# Roma, a cidade eterna, não é apenas um destino para amantes de história e cultura, mas também para quem busca relaxamento e bem-estar. Depois de explorar ruínas antigas e maravilhas arquitetônicas, que tal relaxar em uma sauna? Aqui está uma seleção dos melhores hotéis com sauna em Roma para tornar sua estadia ainda mais memorável.
#
# **1. Hotel Artemide**
#
# Este hotel icônico, localizado no centro de Roma, oferece uma combinação perfeita de luxo e conforto. Além da sua localização privilegiada, o Hotel Artemide é famoso por seu spa, que inclui uma sauna moderna. Ideal para relaxar após um dia agitado de turismo, o spa oferece uma variedade de tratamentos que revitalizam o corpo e a mente.
#
# **2. Rocco Forte Hotel De La Ville**
#
# Com uma vista deslumbrante sobre os degraus da Praça de Espanha, o Rocco Forte Hotel De La Ville é um refúgio de luxo. O hotel dispõe de um spa completo com sauna, oferecendo uma experiência de bem-estar sofisticada. Perfeito para quem busca uma experiência de luxo em Roma, com serviços de alta qualidade e atenção aos detalhes.
#
# **3. A.Roma Lifestyle Hotel**
#
# Para aqueles que preferem um ambiente mais moderno, o A.Roma Lifestyle Hotel é uma excelente escolha. Este hotel oferece uma ampla gama de comodidades, incluindo uma sauna, piscina e centro de fitness. O ambiente relaxante e as instalações modernas fazem deste hotel uma escolha popular entre os viajantes que buscam conforto e conveniência.
#
# **4. Hotel Villa Pamphili Roma**
#
# Situado em uma área tranquila, o Hotel Villa Pamphili é ideal para quem deseja escapar do burburinho da cidade. O spa do hotel oferece uma sauna revigorante, perfeita para relaxar após um dia explorando Roma. Este hotel é conhecido por sua atmosfera serena e serviço amigável.
#
# **5. Crowne Plaza Rome St. Peter's**
#
# Este hotel é uma opção fantástica para famílias e viajantes a negócios. O Crowne Plaza oferece uma variedade de instalações de bem-estar, incluindo sauna, banho turco e massagens. A combinação de conforto e serviço de alta qualidade faz deste hotel uma escolha popular para quem busca relaxamento e rejuvenescimento.
#
# Cada um desses hotéis oferece uma experiência única, proporcionando um equilíbrio perfeito entre exploração cultural e relaxamento. Se você está planejando uma viagem a Roma, considere ficar em um desses hotéis para aproveitar ao máximo sua estadia na cidade eterna.
#
# **Passo 3 - Post para o Instagram**
#
# **Texto para Instagram:**
#
# **Relaxe em Grande Estilo em Roma!**
#
# Depois de explorar as maravilhas históricas de Roma, que tal um momento de puro relaxamento? Descubra os melhores hotéis com sauna na cidade eterna! De spas luxuosos a ambientes modernos, há opções para todos os gostos.
#
#  - Hotel Artemide - Elegância no coração de Roma
#
#  - Rocco Forte Hotel De La Ville - Luxo com vista para a Praça de Espanha
#
#  - A.Roma Lifestyle Hotel - Modernidade e conforto
#
#  - Hotel Villa Pamphili Roma - Tranquilidade e serenidade
#
#  - Crowne Plaza Rome St. Peter's - Perfeito para famílias e negócios
#
# Na resposta acima, o ChatGPT estruturou a resposta, pesquisando no site Booking.com por meio do Bing, pois a OpenAI é parceira da Microsoft.
#
# Após gerar o passo 1, ele gerou o passo 2 com artigos sobre cada hotel. Após finalizar esse passo, gerou o passo 3, com um post de Instagram sobre cada hotel para nossa página (de empresa, por exemplo), utilizando emojis e hashtags, simulando a linguagem das redes sociais.
#
# **Observação:** Os emojis foram omitidos para facilitar a leitura por pessoas que utilizam leitores de tela.
#
# Resumindo, dividir a tarefa em subtarefas permite que a IA responda melhor. Essa é uma dica valiosa para criar prompts melhores.
#
# **Pedir explicações**
#
# Também podemos pedir que a IA explique passo a passo como ela vai resolver o problema, em vez de só fornecer a resposta. Isso serve para problemas de lógica e matemáticos.
#
# **Pedir justificativas**
#
# É interessante pedir que a IA forneça justificativas para suas respostas. Isso tem a ver com o princípio anterior, indo além da explicação.
#
# **Autoconsistência**
#
# Outra dica é utilizar a técnica de engenharia de prompt chamada Self-Consistency (autoconsistência). Ela pode ser utilizada quando queremos realizar várias chamadas.
#
# Quando temos um resultado numérico e não sabemos se a IA vai acertar de primeira, por exemplo, podemos realizar o mesmo prompt várias vezes e coletar o resultado mais frequente (que, provavelmente, será o correto).
#
# A autoconsistência é mais usada em análises matemáticas e é mais caro. Quando falamos de texto, os quatro primeiros princípios são mais importantes.
#
# **Analisando o prompt de hotéis**
#
# Na conversa do ChatGPT sobre hotéis em Roma, já estávamos estruturando o prompt de alguma forma. Inicialmente, fizemos um pedido genérico: "escreva sobre hotéis em Roma". Depois, fomos mais específicos: "me dê uma lista de cinco hotéis em Roma que tenham sauna e sejam amigáveis com crianças".
#
# Em seguida, pedimos que o retorno fosse transformado em um texto de blog. Mas se quiséssemos fazer isso automaticamente, poderíamos gerar um texto único, dividindo a tarefa em passos, assim como fizemos neste aula, evitando confusões e evitando que a IA se perca a longo prazo.
#
# **Próximos passos**
#
# Na próxima aula, vamos entender como utilizar essas IAs para análises no dia a dia de trabalho.

# %% [markdown]
# ### **Análise de Prompts no ChatGPT**
#
# **Você está utilizando o ChatGPT como assistente em um projeto complexo e precisa criar um prompt eficaz. Das alternativas abaixo, qual poderia prejudicar na qualidade da resposta do chat, se fosse uma característica do seu prompt?**
#
# a)
# **Usar termos técnicos sem fornecer contexto.**
#
# Usar termos técnicos sem contexto pode levar a interpretações erradas ou respostas que não atendem suas necessidades.
#
# b)
# Ser claro e específico.
#
# c)
# Pedir exemplos práticos quando necessário.
#
# d)
# Dividir perguntas complexas em partes menores.

# %% [markdown]
# **Mão na massa: criando um post para seu trabalho**
#
# Na aula anterior falamos sobre engenharia de prompt - a área que estuda como obter resultados cada vez mais precisos em IAs generativas.
#
# São algumas das técnicas de engenharia de prompt:
#
#  - Ter clareza ao dar as instruções;
#
#  - Dividir tarefas complexas em subtarefas menores;
#
#  - Pedir para o modelo explicar seus passos antes de dar a resposta;
#
#  - Pedir para o modelo dar justificativas de suas respostas;
#
#  - Gerar várias respostas diferentes e pedir para o modelo escolher a melhor.
#
# Essas técnicas parecem simples, mas são detalhes que fazem uma imensa diferença na utilidade que a IA tem no dia a dia.
#
# Para praticar, use as técnicas e crie um prompt com múltiplos passos em que o resultado final seja um post sobre algum assunto específico da sua área de trabalho ou estudo. Esse post deve ter o formato adequado para ser publicado no seu LinkedIn pessoal e utilizar a hashtag #IAnaAlura.
#
# **Opinião do instrutor**
#
# Utilizando a divisão em subtarefas e mantendo as instruções claras e bem contextualizadas, os resultados obtidos são bastante interessantes!
#
# Veja um exemplo de prompt:

# %% [markdown]
# 1. Fale sobre as 5 bibliotecas mais utilizadas para criação de gráficos em análise de dados com Python
#
# 2. Faça uma analogia de cada biblioteca mencionada com um personagem emoção do filme Divertida Mente - Alegria, Tristeza, Nojinho, Medo e Raiva
#
# 3. Crie um post para eu postar em meu Linkedin pessoal, utilizando a hashtag #IAnaAlura. O post deve ser apropriado para o Linkedin, mas trazer o aspecto divertido da analogia com o filme

# %% [markdown]
# Pratique bastante, explorando assuntos do seu interesse e diferentes técnicas. Compare os resultados obtidos para compreender como adequar as técnicas à sua realidade.

# %% [markdown]
# ### **Para saber mais**
#
# Se você quiser aprender mais a fundo sobre os modelos de linguagem e como os modelos mais poderosos da atualidade foram treinados, recomendo a leitura do livro “Inteligência Artificial e ChatGPT” da Casa do Código, que explica desde a base da IA até conceitos mais avançados de Engenharia de Prompt:
#
#  - https://www.casadocodigo.com.br/products/livro-inteligencia-artificial-chatgpt

# %% [markdown]
# ####**O que aprendemos?**
#
# #### **Nesta aula, aprendemos:**
#
#  - Como funcionam os modelos de linguagem por baixo dos panos.
#
#  - Como criar prompts melhores.
#
#  - O que é e quais são os princípios mais relevantes da Engenharia de Prompt.

# %% [markdown]
# ### **Aula 03 - IAs para análises**

# %% [markdown]
# **Análise de documentos**

# %% [markdown]
# Começaremos a verificar como esses modelos de IA podem ser úteis para analisar documentos, imagens e até mesmo áudio. Inicialmente, utilizaremos o ChatGPT, que já estamos usando, supondo que temos alguns itens para analisar.
#
# **Exemplos para análise**
#
# *A tabela abaixo foi parcialmente transcrita:*

# %% [markdown]
# | *Data* | *Rendimento* | *Gastos* | *Lucro* |
# | -------- | -------------- | ---------- | --------- |
# | 01/01/2023 | 10.000,00 | 5.000,00 | 5.000,00 |
# | 02/01/2023 | 10.055,00 | 5.034,00 | 5.021,00 |
# | 03/01/2023 | 10.114,14 | 5.070,56 | 5.043,59 |
# | 04/01/2023 | 10.175,98 | 5.108,62 | 5.067,36 |
# | 05/01/2023 | 10.240,00 | 5.147,86 | 5.092,14 |
# | 06/01/2023 | 10.305,90 | 5.188,07 | 5.117,83 |
# | 07/01/2023 | 10.373,48 | 5.229,14 | 5.144,34 |
# | 08/01/2023 | 10.442,60 | 5.270,98 | 5.171,62 |
# | 09/01/2023 | 10.513,14 | 5.313,52 | 5.199,62 |
# | 10/01/2023 | 10.585,00 | 5.356,70 | 5.228,30 |
# | 11/01/2023 | 10.658,11 | 5.400,48 | 5.257,63 |
# | 12/01/2023 | 10.732,41 | 5.444,82 | 5.287,60 |

# %%
import pandas as pd

# Criando os dados
dados = {
    "Data": [
        "01/01/2023", "02/01/2023", "03/01/2023", "04/01/2023",
        "05/01/2023", "06/01/2023", "07/01/2023", "08/01/2023",
        "09/01/2023", "10/01/2023", "11/01/2023", "12/01/2023"
    ],
    "Rendimento": [
        10000, 10055, 10114.14, 10175.98,
        10240, 10305.9, 10373.48, 10442.6,
        10513.14, 10585, 10658.11, 10732.41
    ],
    "Gastos": [
        5000, 5034, 5070.56, 5108.62,
        5147.86, 5188.07, 5229.14, 5270.98,
        5313.52, 5356.7, 5400.48, 5444.82
    ],
    "Lucro": [
        5000, 5021, 5043.59, 5067.36,
        5092.14, 5117.83, 5144.34, 5171.62,
        5199.62, 5228.3, 5257.63, 5287.6
    ]
}

# Criando o DataFrame
df = pd.DataFrame(dados)

# Mostrando a tabela
df
# Out:
#           Data  Rendimento   Gastos    Lucro
# 0   01/01/2023    10000.00  5000.00  5000.00
# 1   02/01/2023    10055.00  5034.00  5021.00
# 2   03/01/2023    10114.14  5070.56  5043.59
# 3   04/01/2023    10175.98  5108.62  5067.36
# 4   05/01/2023    10240.00  5147.86  5092.14
# 5   06/01/2023    10305.90  5188.07  5117.83
# 6   07/01/2023    10373.48  5229.14  5144.34
# 7   08/01/2023    10442.60  5270.98  5171.62
# 8   09/01/2023    10513.14  5313.52  5199.62
# 9   10/01/2023    10585.00  5356.70  5228.30
# 10  11/01/2023    10658.11  5400.48  5257.63
# 11  12/01/2023    10732.41  5444.82  5287.60

# %% [markdown]
# Por exemplo, há uma tabela de Excel com datas, rendimentos, gastos, lucros, mas não sabemos a soma total. Não temos nenhuma informação, pois a tabela tem 100 valores. Desejamos usar a IA para nos ajudar a trabalhar com esses dados.
#
# Há também um [PDF sobre a Itália](https://), que é um guia da Lonely Planet (Planeta Solitário) em inglês. A Lonely Planet é uma empresa muito famosa de revistas de viagens. O guia tem 23 páginas, contendo bastante conteúdo, dicas, atividades para julho e setembro, além de muitas imagens.
#
# Outro arquivo disponível é a documentação do modelo Llama 3, intitulada "The Llama 3 Herd od Models". Destinada às pessoas mais técnicas que trabalham com modelos de linguagem, o Llama 3 é similar ao ChatGPT ou Gemini, porém desenvolvido pela Meta. A grande diferença é que ele é um código aberto, permitindo que qualquer pessoa explore, entenda o que está nele e saiba como foi treinado.
#
# É um artigo científico muito técnico, explicando detalhadamente como o modelo foi treinado. O artigo tem 92 páginas, repletas de explicações técnicas que podem ser complicadas para quem não é da área ou não trabalha diariamente com programação ou machine learning (aprendizado de máquina).
#
# **Como Utilizar as IAs para análise**
#
# Veremos como utilizar as IAs para analisar esses documentos.
#
# **Uso do ChatGPT para análise de planilhas**
#
# Primeiramente, no ChatGPT, faremos o upload. Do lado esquerdo do campo de prompt no message ChatGPT, há um ícone de clipe. Ao clicarmos nele, selecionamos a opção "Upload from Computer" ("Fazer o upload a partir do seu computador").
#
# Selecionamos o documento finance.csv, sendo uma planilha e pedimos à IA para analisar e explicar sobre o que trata esse arquivo. Não mencionamos que é uma planilha, apenas dizemos "este arquivo"

# %%
Analise e explique sobre o que se trata este arquivo.

# %% [markdown]
# Pressionamos "Enter". A IA começará a análise.
#
# O que está acontecendo é que o código está sendo executado em uma linguagem chamada Python. No entanto, esses detalhes não são importantes para nós e podem ser ocultados se preferirmos. Para isso, desabilitamos o botão "Always show details".

# %% [markdown]
# O arquivo é uma planilha financeira que contém as seguintes colunas:
#
# 1. Data: A data de registro das informações financeiras.
# 2. Rendimentos: Os valores de receita ou rendimentos obtidos na data correspondente.
# 3. Gastos: Os valores de despesas ou gastos incorridos na mesma data.
# 4. Lucro: A diferença entre os rendimentos e os gastos, representando o lucro líquido.
#
# A tabela parece registrar dados diários, mostrando como os rendimentos, gastos e lucros variam ao longo do tempo. Os dados podem ser usados para análise financeira, como calcular tendências de crescimento, identificar períodos de aumento ou redução nos lucros, e para planejamento financeiro.

# %% [markdown]
# O arquivo é uma planilha financeira com as seguintes colunas: data, rendimentos, gastos e lucro. O modelo conseguiu abrir o documento e visualizar essas informações.
#
# Clicamos no ícone no final do texto de retorno representado por "View analysis" ("Ver análise"). Uma aba "Analysis" será exibida e notamos que o ChatGPT exibiu apenas os cinco primeiros dados:
#
#     Result

# %% [markdown]
# | *#* | *Data* | *Rendimento* | *Gastos* | *Lucro* |
# | ----- | -------- | -------------- | ---------- | --------- |
# | 1 | 01/01/2023 | 10.000,00 | 5.000,00 | 5.000,00 |
# | 2 | 02/01/2023 | 10.055,00 | 5.034,00 | 5.021,00 |
# | 3 | 03/01/2023 | 10.114,14 | 5.070,56 | 5.043,59 |
# | 4 | 04/01/2023 | 10.175,98 | 5.108,62 | 5.067,36 |
# | 5 | 05/01/2023 | 10.240,00 | 5.147,86 | 5.092,14 |

# %% [markdown]
# Desejamos, por exemplo, saber quantas linhas o documento inteiro possui. Verificaremos se ele consegue descobrir isso para nós.

# %%
Analise quantas linhas tem o documento inteiro

# %% [markdown]
# Obtemos:

# %%
O documento contém 100 linhas de dados.

# %% [markdown]
# O documento contém 100 linhas de dados, conforme esperado: uma linha de título e 100 linhas de dados.
#
# **Cálculo da soma total no ChatGPT**
#
# Agora, desejamos calcular a soma total do lucro para todas as linhas.

# %%
Calcule a soma total do lucro para todas as linhas

# %% [markdown]
# O modelo está realizando a mesma análise por trás das cenas e encontrou o valor de 692.605,73.

# %%
A soma total do lucro para todas as linhas do documento é de R$ 692.605,73.

# %% [markdown]
# Vamos verificar se o valor está correto.
#
# Abrimos a planilha, somaremos todos os valores até o final e utilizaremos a função de AutoSum automática nas fórmulas. Ao descer até o final, encontraremos 662.605,73, que é exatamente o mesmo número encontrado. Veja como a IA pode auxiliar no dia a dia com análise de dados, planilhas financeiras, tabelas e muito mais.
#
# Este é um primeiro passo, e também vimos o uso do ChatGPT. No entanto, há outra ferramenta de IA desenvolvida pelo Google, que não é o Gemini.
#
# **Comparação com o Google AI Studio**
#
# Trata-se do Google AI Studio, geralmente utilizado por pessoas que trabalham com programação e tecnologia. Ele permite visualizar e testar o código, além de explorar os detalhes técnicos.
#
# *A Interface do Google AI Studio exibe várias opções de menu na lateral esquerda, como "Get API key", "Create new prompt", e outras ferramentas. Ao centro, há uma área com o título "Get started" e opções de exemplos como "Which shape comes next?", "Recipe to JSON" e "Time complexity". À direita, as "Run settings" incluem seleção do modelo "Gemini 1.5 Pro", contador de tokens, ajuste de temperatura e configurações de segurança.*
#
# A princípio, pode parecer um pouco mais complicado devido à quantidade de recursos disponíveis, mas explicaremos tudo.
#
# **Uso do Google AI Studio para análise**
#
# No primeiro passo, não é necessário se preocupar com muitos detalhes. Desejamos fazer o upload do mesmo arquivo, o finance.csv.
#
# Na parte inferior, onde diz "Type something" (digite alguma coisa), ao lado direito há um botão de mais ("+"). Ao clicar nesse botão, selecionamos "Upload to Drive" ("fazer upload para o drive"). Como a ferramenta é do Google, ela utiliza o seu Google Drive. Portanto, será necessário fazer o upload do arquivo finance.csv para o seu Google Drive para analisá-lo.
#
# Após isso, clicamos em "Type something" para escrever uma mensagem e colamos o texto que usamos no ChatGPT:
#
# *Lembre-se de inserir o arquivo finance.csv junto com a pergunta.*

# %%
Analise e me explique de que trata esse arquivo

# %% [markdown]
# Em seguida, pressionamos "Enter" ou clicamos no botão "Run" à direita ("executar").
#
# Notamos que no topo direito está escrito modelo "Gemini 1.5 Pro", algo que não podíamos escolher no Gemini padrão, pois a versão gratuita do aplicativo Gemini oferecia apenas opções básicas. No Google AI Studio, disponível em aistudio.google.com, é possível escolher o modelo. Por padrão, ele provavelmente virá com o "Gemini 1.5 Flash", que é mais rápido, mas menos poderoso e inteligente.
#
# **Para utilizar o modelo mais poderoso atualmente, escolhemos o Gemini 1.5 Pro.**
#
# *Ao assistir a este curso, é possível que já exista um modelo ainda mais avançado do Google. No momento, estamos utilizando o 1.5 Pro, que é o modelo mais poderoso disponível.*
#
# Analisando o retorno, temos:

# %% [markdown]
# O arquivo "finance.csv" parece ser um registro financeiro diário de um indivíduo ou empresa fictícia.
#
# Formato:
#
# O arquivo utiliza o formato CSV (Comma Separated Values), onde cada linha representa um dia e as informações são separadas por vírgulas.
#
# Conteúdo:
#
# - Data: Representa o dia a que se referem os dados, no formato DD/MM/AAAA.
#
# - Rendimentos: Representa o total de receitas ou ganhos obtidos naquele dia, provavelmente em unidades monetárias (não especificado).
#
# - Gastos: Representa o total de despesas ou saídas de dinheiro naquele dia, na mesma unidade monetária que os rendimentos.
#
# - Lucro: Representa o lucro líquido do dia, calculado pela subtração dos gastos dos rendimentos (Rendimentos - Gastos = Lucro).
#
# Observações:
#
# - O arquivo cobre o período de 01/01/2023 a 10/04/2023.
# - Os valores em "Rendimentos" parecem crescer a uma taxa constante, indicando um possível investimento com rendimento fixo.
# - Os "Gastos" também parecem aumentar, mas a uma taxa menor que os rendimentos, o que é positivo, pois indica um aumento no lucro ao longo do tempo.
# - A última linha "Analise e me explique de que trata esse arquivo" não faz parte da estrutura do arquivo e parece ser uma instrução para análise dos dados.
#
# Análise:
#
# Uma análise mais aprofundada dos dados poderia revelar:
#
# - Média de rendimentos e gastos mensais.
# - Lucro total no período.
# - Padrões de comportamento nos rendimentos e gastos (ex: dias de semana vs fins de semana).
# - Eficácia na gestão financeira ao longo do tempo.
#
# Em resumo, o arquivo "finance.csv" apresenta dados financeiros diários que, após análise, podem fornecer informações valiosas sobre a saúde financeira e hábitos de consumo do indivíduo ou empresa.

# %% [markdown]
# Ele forneceu a resposta indicando que o arquivo finance.csv parece ser um registro financeiro diário de um indivíduo ou empresa fictícia, mencionando a data, rendimentos, gastos e lucro, exatamente como esperávamos. Podemos fazer as mesmas perguntas que fizemos para o ChatGPT, como "analise quantas linhas tem o documento inteiro".

# %%
analise quantas linhas tem o documento inteiro

# %% [markdown]
# Clicamos em "Run", e ele começou a análise.
#
# Embora não mostre exatamente o que está fazendo por trás, ele informa o tempo de cada solicitação. Neste caso, levou 3,9 segundos para completar tudo, e o modelo também respondeu corretamente que o documento possui 100 linhas.

# %% [markdown]
# O arquivo "finance.csv" possui 101 linhas.
#
# Vale ressaltar que a última linha, "Analise e me explique de que trata esse arquivo", parece ser uma instrução deslocada e não um dado financeiro. Portanto, se considerarmos apenas as linhas com dados financeiros, o arquivo possui 100 linhas.

# %% [markdown]
# Pedimos ao modelo para calcular a soma total do lucro, assim como fizemos com o GPT.

# %%
Calcule a soma total do lucro para todas as linhas

# %% [markdown]
# Após clicar em "Run", ele começou a processar e apresentou um erro, indicando 58.785,87.
#
# Cuidado com dados numéricos, pois modelos de IA podem cometer erros e gerar resultados incorretos. Chamamos isso de alucinação.

# %% [markdown]
# A soma total do lucro para todas as linhas do arquivo "finance.csv" é **58765.87**.
#
# Este valor foi obtido somando os valores da coluna "Lucro" para todas as 100 linhas que continham dados financeiros.

# %%
Digitamos para o modelo, perguntando:

# %%
Tem certeza? Faça os cálculos novamente.

# %% [markdown]
# Você está certo! Cometi um erro no cálculo anterior.
#
# Após refazer a soma da coluna "Lucro" para todas as 100 linhas com dados financeiros, o valor correto da soma total do lucro é 34017.12.
#
# Peço desculpas pelo erro anterior. Agradeço por apontá-lo para que eu pudesse corrigir!

# %% [markdown]
# O modelo admitiu o erro e forneceu um novo resultado correto, que não coincide com o resultado original encontrado na nossa planilha nem com o que o ChatGPT havia encontrado. No entanto, isso mostra as diferentes possibilidades ao utilizar o Google AI Studio.
#
# **Análise de documentos em PDF**
#
# Continuamos com os PDFs que mencionamos para análise.
#
# **Comparação de resumos dos modelos de IA**
#
# Criamos um novo chat no ChatGPT e fazemos o upload do documento sobre a Itália, solicitando "faça um resumo sobre esse arquivo".

# %%
Faça um resumo sobre esse arquivo

# %% [markdown]
# Em seguida, criamos uma nova janela no Gemini (em "Create new prompt"), fazemos o upload do mesmo arquivo da Itália e solicitamos "faça um resumo sobre esse arquivo". Assim que o arquivo carregar, clicamos em "Run".
#
# Retorno ChatGPT:

# %% [markdown]
# O documento parece ser um guia de viagem abrangente sobre a Itália, com informações detalhadas sobre diversos aspectos do país, incluindo dados demográficos, geográficos e econômicos. Ele destaca a importância do turismo para a economia italiana e fornece uma visão geral das atrações culturais, históricas e naturais disponíveis para os visitantes.
#
# Pontos principais do guia:
#
# 1. Fatos Rápidos: Dados como população, área, PIB, taxa de crescimento do PIB, taxa de inflação, taxa de desemprego e expectativa de vida.
# 2. Cidades e Regiões Importantes: Discussão sobre cidades notáveis como Roma, Florença, Veneza, Milão, e outros locais de interesse turístico.
# 3. Cultura e História: Inclui uma visão sobre a rica herança cultural da Itália, com menção especial à sua arte, arquitetura e festivais tradicionais.
# 4. Natureza e Atividades ao Ar Livre: Informações sobre parques nacionais, atividades de aventura como esqui e caminhadas, e paisagens naturais como os Alpes e as Dolomitas.
# 5. Gastronomia: Destaques da culinária italiana, incluindo movimentos como o Slow Food e especialidades regionais.
# 6. Patrimônio da Humanidade: Listagem de sites reconhecidos pela UNESCO, enfatizando a importância histórica e cultural destes locais.
# 7. Itinerários Sugeridos: Recomendações de roteiros de viagem, desde visitas a cidades clássicas até rotas menos conhecidas e temáticas específicas, como roteiros gastronômicos e culturais.
#
# O guia também menciona questões sociais e políticas, como a presença do crime organizado e as políticas de imigração, bem como eventos históricos recentes que impactaram o país, como desastres naturais.
#
# Este documento é útil para quem planeja visitar a Itália e quer uma compreensão detalhada do que o país oferece, incluindo dicas práticas sobre quando visitar, como se locomover, e o que não perder em uma viagem.

# %% [markdown]
# Enquanto isso, verificamos a resposta do ChatGPT: "O documento parece ser um guia de viagem abrangente sobre a Itália, com informações detalhadas sobre diversos aspectos do país, incluindo dados demográficos, geográficos e econômicos."
#
# O modelo conseguiu identificar exatamente o conteúdo do guia, mencionando vários dados como mapas, dados demográficos, geográficos, pontos principais, fatos rápidos, natureza, patrimônios e itinerários de viagem. Assim, ele analisou o documento em PDF, demonstrando mais uma forma de como as IAs podem ser úteis para nós.
#
# O Gemini está realizando exatamente a mesma tarefa e conseguiu fazer isso sem problemas.
#
# Retorno Gemini:

# %% [markdown]
# Resumo do Guia de Viagem Lonely Planet Italia (9ª Edição)
#
# Este guia abrangente da Lonely Planet sobre a Itália oferece uma imersão profunda na cultura, história, gastronomia e belezas naturais do país. Com dicas detalhadas sobre as melhores épocas para visitar, custos, roteiros clássicos e fora dos roteiros tradicionais, o guia é ideal para viajantes independentes que desejam explorar tudo o que a Itália tem a oferecer.
#
# Destaques:
#
# Destinos: Explore cidades icônicas como Roma, Florença, Veneza e Milão, além de regiões menos conhecidas como Puglia, Basilicata e Calábria.
#
# Roteiros: Encontre sugestões de roteiros para todos os gostos, desde um tour clássico de duas semanas por cidades imperdíveis até uma aventura de um mês percorrendo o país de norte a sul. Há também roteiros temáticos, como um tour gastronômico por Emilia-Romagna, Toscana e Úmbria, e uma expedição pelos 44 Patrimônios Mundiais da UNESCO.
#
# Cultura e História: Mergulhe na rica história da Itália, desde as civilizações pré-romanas até os dias atuais. Descubra os segredos dos nuraghi da Sardenha, explore as cidades etruscas de Cerveteri e Tarquinia e maravilhe-se com a grandiosidade dos templos gregos em Paestum e Agrigento.
#
# Gastronomia: Delicie-se com a culinária italiana em toda a sua glória, desde mercados vibrantes a restaurantes renomados. O guia destaca especialidades regionais, vinhos locais e a filosofia do Slow Food.
#
# Natureza e Aventura: A Itália oferece uma variedade impressionante de paisagens e atividades ao ar livre. Desfrute de esquiar nos Alpes, caminhar no Parque Nacional Gran Paradiso, fazer rafting em Valsesia e mergulhar nas Ilhas Tremiti.
#
# Dicas Práticas: Encontre informações úteis sobre transporte, acomodação, idioma, saúde e muito mais. O guia também inclui mapas detalhados, dicas de segurança e conselhos para viajar de forma responsável.
#
# Autores:
#
# Uma equipe de experientes autores da Lonely Planet, apaixonados pela Itália, contribuiu para esta edição, incluindo Damien Simonis, Alison Bing, Gregor Clark, Duncan Garwood, Cristian Bonetto, Virginia Maxwell, Abigail Hole, Alex Leviton, Josephine Quintero e Brendan Sainsbury.
#
# Informação Adicional:
#
# O guia também inclui seções sobre:
#
# - Cinema italiano
# - Literatura italiana
# - Música italiana
# - Calendário de eventos
#
# Com este guia completo da Lonely Planet, você estará pronto para planejar sua viagem inesquecível à Itália.

# %% [markdown]
# Ele forneceu um resumo do guia de viagem da Lonely Planet, reconhecendo a empresa por trás do modelo. O resumo abrange a Itália, roteiros e outras informações, praticamente da mesma forma, mas com algumas diferenças. O Gemini também mencionou os autores do guia e forneceu informações adicionais, demonstrando que é um modelo extremamente poderoso, o Gemini 1.5 Pro.
#
# Para concluir esta aula, vamos fazer o upload do último arquivo mencionado, que é o documento técnico sobre o Llama 3, um modelo de IA da Meta.
#
# Primeiro para o ChatGPT. Copiamos o texto "Faça um resumo sobre esse arquivo" e enviamos para o modelo. Como o PDF tem 9 megabytes, realizamos o mesmo processo no Google AI Studio para comparar os resultados e avaliar o desempenho dos dois modelos.
#
# Retorno ChatGPT:

# %% [markdown]
# O arquivo descreve o "Llama 3.1", uma nova geração de modelos de linguagem desenvolvidos pela equipe de IA da Meta. Este conjunto de modelos, chamado de "Herd of Models" ou "Manada de Modelos", inclui versões com capacidades de suporte a múltiplos idiomas, codificação, raciocínio e uso de ferramentas. O maior modelo, um Transformer denso com 405 bilhões de parâmetros, possui uma janela de contexto de até 128 mil tokens.
#
# Os modelos Llama 3.1 foram treinados em uma ampla variedade de tarefas de compreensão de linguagem e são comparáveis em qualidade a modelos de ponta como o GPT-4. Além dos modelos pré-treinados, a Meta também lançou versões pós-treinadas para melhorar a segurança de entrada e saída. Experimentos adicionais estão em andamento para integrar capacidades de reconhecimento de imagem, vídeo e fala, usando uma abordagem composicional.
#
# O processo de desenvolvimento do Llama 3.1 inclui duas etapas principais: pré-treinamento, onde o modelo aprende a estrutura da linguagem e adquire conhecimento, e pós-treinamento, onde o modelo é ajustado para seguir instruções, alinhar-se com preferências humanas e melhorar em capacidades específicas. Os modelos foram treinados em uma vasta quantidade de dados multilinguísticos, com melhorias significativas em termos de qualidade e quantidade de dados comparados aos modelos anteriores.
#
# A Meta planeja lançar publicamente os modelos Llama 3.1, incluindo uma nova versão do modelo "Llama Guard" para segurança de entrada e saída. O documento também detalha as capacidades multimodais dos modelos, como reconhecimento de imagem, vídeo e fala, que ainda estão em desenvolvimento.

# %% [markdown]
# Enquanto isso, o GPT já completou a tarefa, fornecendo o resumo: "O arquivo descreve o Llama 3.1, uma nova geração de modelos de linguagem desenvolvidos pela equipe de IA da Meta.
#
# Esse conjunto de modelos, chamado de 'herd of models' (manada de modelos), inclui o maior modelo, um transformer denso com 405 bilhões de parâmetros, e possui uma janela de contexto de até 128 mil tokens." O ChatGPT conseguiu acessar o arquivo PDF, ler seu conteúdo e resumir as 92 páginas.
#
# Uma última coisa: vamos procurar um detalhe específico no PDF, como "Scaling Law Experiments" ("Experimentos de Lei de Escalabilidade"). Perguntamos para o ChatGPT "o que ele fala sobre Scaling Law Experiments?", e o modelo está lendo o documento novamente.

# %%
O que ele fala sobre Scaling Law Experiments?

# %% [markdown]
# Ele encontrou a informação desejada e forneceu a explicação em português, pois estamos conversando com ele nesse idioma.
#
# Retorno ChatGPT parcialmente transcrito:

# %% [markdown]
# Os "experimentos de leis de escalonamento" no documento descrevem a abordagem utilizada para determinar o tamanho ideal do modelo e o número de tokens de treinamento necessários para modelos de linguagem da série Llama 3. A equipe realizou pré-treinamentos com orçamentos de computação variando de 6×10¹⁸ a 10²² FLOPs, testando modelos com tamanhos de 40 milhões a 16 bilhões de parâmetros. Durante esses testes, foi utilizado um agendamento de taxa de aprendizado cosseno, com um aquecimento linear inicial e uma subsequente decaída do cosseno.
#
# …

# %% [markdown]
# Assim, ele traduziu o conteúdo do arquivo em inglês para o português, informando que "a equipe realizou pré-treinamentos com orçamento de computação variando de 6×10¹⁸ a 10²² flops", exatamente como está no artigo da Meta sobre o Llama 3.1.
#
# Vamos **verificar no Google AI Studio** para ver o que ele está fazendo.
#
# Retorno Google AI Studio:

# %% [markdown]
# Este artigo apresenta o Llama 3, um conjunto de modelos de fundação de última geração para IA, desenvolvido pela equipe de IA do Meta. O Llama 3 é apresentado como uma coleção (ou "manada") de modelos de linguagem, destacando-se por seu suporte nativo a múltiplos idiomas, codificação, raciocínio e uso de ferramentas. O modelo mais notável da coleção é um Transformer denso com 405 bilhões de parâmetros e uma janela de contexto de até 128 mil tokens.
#
# O artigo enfatiza três pilares principais no desenvolvimento do Llama 3: dados, escala e gerenciamento de complexidade.
#
# - Dados: O Llama 3 foi pré-treinado em um conjunto de dados massivo de aproximadamente 15 trilhões de tokens multilingues, representando um aumento significativo em relação ao seu predecessor, o Llama 2. O foco está na qualidade e diversidade dos dados, incluindo código, raciocínio e dados multilingues.
#
# - Escala: O treinamento do modelo carro-chefe utilizou 3.8 x 10²⁵ FLOPs, significativamente maior do que as versões anteriores do Llama, permitindo um desempenho superior em benchmarks em comparação com modelos menores.
#
# - Gerenciamento de complexidade: O Llama 3 mantém uma arquitetura Transformer padrão com adaptações mínimas, priorizando a estabilidade do treinamento e a escalabilidade em detrimento de modelos mais complexos como Mixture-of-Experts. Similarmente, o processo de pós-treinamento emprega técnicas simples, porém eficazes, como ajuste fino supervisionado, amostragem por rejeição e otimização direta de preferência.
#
# O artigo detalha os resultados de uma extensa avaliação empírica do Llama 3, demonstrando qualidade comparável a modelos de linguagem líderes, como o GPT-4, em uma ampla gama de tarefas. Os modelos Llama 3, incluindo o modelo pré-treinado de 405 bilhões de parâmetros e o modelo Llama Guard 3 para segurança de entrada e saída, foram disponibilizados ao público sob a Licença da Comunidade Llama 3.
#
# Além disso, o artigo explora extensões multimodais do Llama 3, incorporando capacidades de imagem, vídeo e fala através de uma abordagem composicional. Resultados promissores são relatados em tarefas de reconhecimento de imagem, vídeo e fala, indicando a competitividade dessas extensões com o estado da arte.
#
# Em resumo, o artigo apresenta o Llama 3 como um avanço significativo no desenvolvimento de modelos de fundação, destacando seu desempenho, escalabilidade, segurança e potencial para aplicações multimodais. A decisão de disponibilizar os modelos ao público visa fomentar a inovação e promover o desenvolvimento responsável da inteligência artificial geral (AGI).

# %% [markdown]
# Ele conseguiu analisar o documento e forneceu a seguinte descrição: "Esse artigo representa o LLAMA 3, um conjunto de modelos, uma coleção de modelos de linguagem, transformer denso de 405 bilhões de parâmetros." O modelo permite editar o texto clicando no ícone de lápis na parte superior direita, se desejarmos.
#
# Fazemos a mesma pergunta sobre "Scaling Law Experiments":

# %%
O que ele fala sobre Scaling Law Experiments?

# %% [markdown]
# O modelo analisa o documento novamente, o que pode levar algum tempo devido ao tamanho do arquivo.
#
# Retorno Google AI Studio:

# %% [markdown]
# O artigo descreve os experimentos de scaling laws (leis de escala) como uma ferramenta crucial para determinar o tamanho ideal do modelo e prever o desempenho em tarefas de benchmark downstream. O processo envolve duas etapas:
#
# 1. Correlação entre a verossimilhança negativa do modelo com o número de FLOPs de treinamento:
#
# - Modelos de diferentes tamanhos são pré-treinados com diferentes orçamentos computacionais (FLOPs).
# - A perda de predição do próximo token (medida pela verossimilhança negativa) é plotada em relação aos FLOPs, criando curvas IsoFLOPs.
# - O modelo com a menor perda para cada orçamento computacional é considerado "computacionalmente ótimo".
# - Assume-se uma relação de lei de potência entre o orçamento computacional e o número ideal de tokens de treinamento para o modelo ótimo.
# - Essa relação é usada para extrapolar e estimar o número ideal de tokens para o modelo Llama 3 de 405B.
#
# 2. Correlação entre a verossimilhança negativa e a precisão em tarefas downstream:
#
# - A verossimilhança negativa do modelo em tarefas downstream é correlacionada linearmente com os FLOPs de treinamento, utilizando os modelos "computacionalmente ótimos" dos experimentos de scaling laws.
# - A verossimilhança negativa é então correlacionada com a precisão em benchmarks, usando dados tanto dos modelos de scaling laws quanto de modelos Llama 2 já treinados com orçamentos computacionais maiores.
# - Essa análise de duas etapas permite prever a precisão do modelo em tarefas específicas, antes mesmo do início do pré-treinamento em larga escala.
#
# Resultados:
#
# - Os experimentos de scaling laws levaram à decisão de treinar o modelo Llama 3 de 405B com aproximadamente 16.5 trilhões de tokens.
# - A previsão de desempenho em benchmarks downstream, baseada em extrapolação de scaling laws, demonstrou-se bastante precisa, subestimando apenas ligeiramente o desempenho final do modelo de 405B.
#
# Em resumo, os experimentos de scaling laws permitiram otimizar o tamanho do modelo e prever seu desempenho, comprovando a utilidade dessa ferramenta no desenvolvimento de modelos de linguagem em larga escala.

# %% [markdown]
# Após aproximadamente 10 segundos, ele começa a fornecer informações: "O artigo descreve as leis de escala, incluindo o número de flops e outros detalhes", exatamente como solicitado. O modelo explica os resultados e fornece informações detalhadas sobre o que pedimos, revelando muitos dados interessantes.
#
# **Conclusão e Próximos passos**
#
# Com isso, é possível observar o poder das IAs na análise de documentos, sejam arquivos Excel, CSV ou PDFs. No próximo vídeo, exploraremos como utilizar essas IAs para analisar imagens e vídeos!

# %% [markdown]
# ### **Análise de imagens e vídeos**

# %% [markdown]
# Neste aula, vamos aprender como utilizar inteligências artificiais para analisar imagens e vídeos.
#
# Criando um post a partir de uma imagem
# Vamos usar como exemplo a seguinte imagem de recipientes de comida, com arroz, cenoura, brócolis e frango:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Primeiramente, vamos analisar essa imagem. Mas não queremos apenas analisar, queremos otimizar esse processo. Imagine que você trabalha escrevendo textos e deseja automatizar essa tarefa. Por exemplo, você envia uma imagem e pede que a IA retorne um artigo completo ou um post escrito sobre ela.
#
# Vamos criar uma nova janela no Google AI Studio, clicando em "Create New Prompt" no canto superior esquerdo. Nessa nova janela, clicamos no ícone de "+" ("Insert assets...") dentro da caixa de input de texto, e selecionamos a opção "Upload to Drive", para carregar no Drive a imagem dos recipientes de comida e enviá-la para a IA.
#
# Mas não queremos apenas a imagem, queremos que a IA faça algo sobre isso. Portanto, junto da imagem, vamos escrever o seguinte prompt:

# %% [markdown]
# Escreva um post de blog curto e envolvente com base nessa foto. Ele deve incluir uma descrição da refeição da foto e falar sobre minha jornada de preparação de refeições.

# %% [markdown]
# Repare que não falamos sobre o conteúdo da foto no texto do prompt, pois esperamos que a IA a analise sozinha.
#
# Após clicar em "Run" para executar, a IA começa a escrever. Ela entende que é um artigo de blog escrito em primeira pessoa, pois pedimos para falar sobre a "minha" jornada. Portanto, ela escreve algo mais pessoal. Ela escreve sobre refeições, dando várias dicas com base numa experiência individual. Além disso, identifica o conteúdo da foto e usa a refeição descrita como exemplo.
#
# Retorno da IA:

# %% [markdown]
# Preparação de Refeições para Iniciantes: Como Começar a Preparar Refeições
#
# A preparação de refeições mudou totalmente minha vida! Honestamente, não sei como vivia sem ela antes. Preparar refeições com antecedência me economiza muito tempo e energia, e me ajuda a fazer escolhas mais saudáveis durante a semana.
#
# Se você está pensando em começar a preparar refeições, eu recomendo muito! É realmente fácil de começar. Veja aqui o que fiz esta semana: frango teriyaki com arroz integral e brócolis. É super fácil de fazer e fica pronto em apenas 30 minutos!
#
# Para começar a preparar refeições, recomendo planejar suas refeições para a semana com antecedência. Assim, você pode ir ao supermercado e comprar tudo o que precisa de uma vez. Em seguida, reserve um tempo para [...]
#
# Podemos incrementar esse pedido, mandando um segundo prompt para a IA:

# %%
Adicione uma receita para esse prato

# %% [markdown]
# Isso poderia estar no nosso prompt inicial, se quisermos fazer isso de maneira automatizada, sem ter que ficar conversando com a IA. Mas aqui estamos testando a memória contextual da IA.
#
# Na resposta, ela mantém a base do post retornado anteriormente e adiciona uma receita de frango teriyaki com arroz integral e brócolis:
#
# Retorno da IA:
#
# Preparação de Refeições para Iniciantes: Como Começar a Preparar Refeições
#
# Preparar as refeições mudou minha vida! Honestamente, não sei como vivia sem isso antes. Preparar as refeições com antecedência economiza muito tempo e energia, e me ajuda a fazer escolhas mais saudáveis durante a semana.
#
# Se você está pensando em começar a preparar suas refeições, eu recomendo muito! É realmente fácil de começar. Veja aqui o que fiz esta semana: frango teriyaki com arroz integral e brócolis. É super fácil de fazer e fica pronto em apenas 30 minutos!
#
# Frango Teriyaki com Arroz Integral e Brócolis
#
# Ingredientes:
#
#  - 1 quilo de peito de frango desossado e sem pele, cortado em cubos
#
#  - 1 xícara de brócolis em floretes
#
#  - 1 xícara de arroz integral cozido
#
#  - 1/2 xícara de molho teriyaki
#
#  - 1 colher de sopa de óleo de gergelim
#
#  - 1/4 xícara de sementes de gergelim, para guarnecer (opcional)
#
#  - Cebolinha picada, para guarnecer (opcional)
#
# Instruções [...]
#
# Ela sabe como fazer um frango teriyaki com arroz integral e brócolis, pois tem o conhecimento da internet, dos dados de seu treinamento. O conhecimento sobre como escrever um artigo de blog também vem desse treinamento. Agora temos um artigo de blog pronto para postar, a partir de apenas uma imagem e uma frase!
#
# **Resumindo e analisando a versão bruta de um vídeo**
#
# Vamos dar outro exemplo, agora para quem trabalha com vídeos e precisa analisá-los e cortá-los, por exemplo. O Google AI Studio também pode facilitar sua vida com essa tarefa. Vamos criar um novo prompt para demonstrar.
#
# Temos como exemplo a versão bruta de um vídeo criado e gravado pelo instrutor Fabrício para o YouTube da Alura. Por ser uma versão bruta, pré-edição, há vários erros e reformulações de fala, pausas e outros detalhes que não vão para a versão final, e que as pessoas editoras terão que remover antes de publicar.
#
# O Google AI Studio tem a opção de fazer upload de vídeos, diferente de outras IAs, que ainda não possuem essa funcionalidade. Então, vamos fazer o upload desse vídeo seguindo o mesmo caminho de upload de imagem, carregando-o no Google Drive. Como o vídeo é um arquivo mais pesado, pode demorar um pouco mais para carregar.
#
# Atualmente (julho de 2024), o Google AI Studio permite o carregamento de vídeos de até quase duas horas, o equivalente a aproximadamente dois milhões de tokens. O vídeo carregado, de 29 minutos, resultou em 514 mil tokens.
#
# Com o vídeo carregado, escrevemos o seguinte prompt:

# %%
Analise esse vídeo e explique de que ele trata.

# %% [markdown]
# Clicamos em "Run" para executar. Após um breve tempo de processamento, a IA começa a retornar um texto de descrição do conteúdo do vídeo:
#
# Retorno da IA
#
# Claro! O vídeo trata de como utilizar o Google AI Studio, uma ferramenta da Google para interagir com IAs, em especial, com o modelo de linguagem Gemini. O apresentador demonstra como criar prompts, subir arquivos de diferentes tipos, como imagens, áudios e documentos, e como obter respostas da IA. Ele destaca a capacidade da ferramenta em lidar com diferentes formatos de dados e linguagens.
#
# O apresentador também destaca a importância de manter a segurança de sua API Key ao utilizar a ferramenta. O vídeo ainda apresenta informações sobre a IA Conference Brasil 2024, que acontecerá em São Paulo no dia 21 de agosto e que tem o objetivo de reunir as maiores mentes da IA no Brasil para discutir as principais tendências, cases de sucesso e técnicas do estado da arte da área. Por fim, o apresentador incentiva os usuários a se inscreverem na formação da Alura sobre IAs generativas, para aprender mais sobre o tema.
#
# A descrição está correta! A IA conseguiu analisar rapidamente um vídeo de meia hora e resumi-lo em dois parágrafos. Mas queremos saber mais sobre o vídeo.
#
# Como mencionado, este é um vídeo bruto; ou seja, ainda não foi editado e ainda tem erros de fala e outros detalhes que desejamos resolver.
#
# Para facilitar o trabalho das pessoas editoras no futuro, podemos pedir o seguinte para a IA:

# %% [markdown]
# Essa é uma versão bruta do vídeo, antes da edição. Encontre possíveis pontos de erros de fala que deverão ser corrigidos na edição e me dê a minutagem exata deles.

# %% [markdown]
# Depois de alguns segundos, a IA começa a dar a resposta:
#
# Olá! Identifiquei alguns pontos no vídeo com erros de fala ou repetições que podem ser corrigidos na edição. Segue a minutagem e a descrição:
#
#  - 0:55 - "Não esquece que esses instructions" - Repetição da palavra "instructions". Sugestão: Remover a primeira menção ou editar a frase.
#
#  - 1:56 - "Escreva um tu um email" - Repetição da sílaba "um". Sugestão: Remover a primeira menção.
#
#  - 5:40 - "...para esticar, para esticar seu cérebro e também o seu senso de realidade, não, deixa eu repetir." - Repetição da frase "para esticar seu cérebro e também seu senso de realidade". Sugestão: Remover a primeira menção.
#
#  - 8:07 - "Mas vem em em vários arquivos que eu tenho aqui." - Repetição da preposição "em". Sugestão: Remover as repetições e manter apenas um "em".
#
#  - 8:19 - "Ô meu saco." - Expressão informal inadequada para o contexto. Sugestão: Remover a fala.
#
#  - 10:04 - "Putz, será isso." - Expressão informal inadequada para o contexto. Sugestão: Remover a fala.
# [...]
#
# Claro, você, como pessoa editora, terá que analisar se o que a IA identificou e sugeriu faz sentido. Mas é um processo que pode facilitar e otimizar o seu trabalho, caso você não queira ou não consiga assistir ao vídeo completo.
#
# **Desafio!**
#
# Considerando o que abordamos neste vídeo com o que aprendemos sobre o uso de documentos no vídeo anterior, você pode tentar relacionar o PDF e o vídeo com a ajuda da IA.
#
# Por exemplo: no mesmo chat, analise primeiro o PDF e identifique os assuntos, depois suba um vídeo e procure nele uma palavra, expressão ou conceito desse PDF, pedindo a parte do vídeo que trata desse assunto.
#
# As possibilidades de conectar esses pontos e utilizar as diferentes funcionalidades das IAs generativas para fazer análises são realmente infinitas!
#
# **Próximos passos**
#
# Na próxima aula, o último desta aula, falaremos sobre áudios.

# %% [markdown]
# ### **Para saber mais: Sobre Tokens**

# %% [markdown]
# Tokens são as menores unidades de texto que um modelo de IA utiliza para processar e gerar linguagem. Eles podem ser palavras inteiras, partes de palavras, ou até mesmo caracteres individuais, dependendo do contexto. Em linguagens baseadas em alfabeto, como o português ou o inglês, uma frase pode ser dividida em vários tokens para que a IA entenda ou produza texto.
#
# Por exemplo, a frase "Eu gosto de aprender" pode ser decomposta em tokens como "Eu", "gosto", "de", "aprend", "er". Cada token é uma peça fundamental que a IA manipula para construir ou interpretar sentenças de forma precisa.
#
# Os tokens são fundamentais para o funcionamento eficaz de modelos de IA porque eles são as unidades básicas de informação que a IA manipula ao processar e gerar texto. A importância dos tokens reside em sua função como blocos de construção que a IA usa para compreender e formar frases, ideias e conceitos. Sem a divisão em tokens, a IA teria dificuldade em segmentar, analisar e organizar as informações textuais de maneira coerente

# %% [markdown]
# ### **Análise de áudios**

# %% [markdown]
# Neste vídeo, queremos mostrar mais uma funcionalidade do Google AI Studio: a análise de áudios. Já exploramos como ele funciona com vídeos e imagens, agora vamos criar um novo prompt para áudios.
#
# **Transcrevendo áudios**
#
# No canto superior esquerdo, clicamos na opção "Create new prompt" e selecionamos "OK". Em seguida, faremos o upload de um arquivo no Drive, clicando no sinal de mais à direita do campo de prompt e selecionando "Upload to Drive".
#
# Suponhamos que na sua empresa vocês tenham reuniões gravadas ou um podcast para divulgação ao público geral. Vocês publicam esses podcasts em redes sociais, no Spotify, e também têm áudios que compartilham entre si. Como analisar esses áudios sem perder tempo?
#
# Nós, na Alura, temos um podcast chamado "Dev Sem Fronteiras", onde entrevistamos pessoas brasileiras que trabalham com tecnologia fora do país. Vamos usar um episódio inteiro desse podcast, que tem 44 minutos de duração, para demonstrar a funcionalidade.
#
# Na janela modal de upload, clicaremos em "Procurar" e selecionaremos o arquivo desejado na tela do explorador do computador, pressionando "Enter" para carregá-lo no campo de prompt.
#
# Queremos não apenas saber do que se trata o episódio, mas também obter a transcrição completa. Antigamente, isso era algo que precisava ser feito manualmente ou com ferramentas que ajudavam no inglês, mas não eram tão eficientes para o português. Vamos ver se o Google AI Studio consegue gerar a transcrição completa para o áudio.
#
# No campo de prompt, acima do vídeo carregado, escreveremos o seguinte:

# %%
Gere a transcrição completa para o áudio abaixo.

# %% [markdown]
# Vamos enviar e ver o que ele responderá.
#
# Em apenas 15 a 16 segundos, ele começa a gerar uma transcrição, com a minutagem à esquerda de cada linha.

# %% [markdown]
# Transcrição do Áudio
#
# 0:07 Olá,
#
# 0:08 hello e hallo, porque hoje a gente está indo
#
# 0:11 para a Suíça. Aqui é o
#
# 0:13 Fábio Carraro, seu
#
# 0:14 viajante poliglota. E
#
# 0:16 hoje, eu vou bater um papo
#
# 0:17 com o Roger,
#
# 0:18 que ele é
#
# 0:19 engenheiro de software lá no Google
#
# (retorno omitido)

# %% [markdown]
# Ele conseguiu transcrever a abertura do podcast, mas cometeu um pequeno erro ao transcrever o nome do apresentador, escrevendo Fábio ao invés de Fabrício. Isso mostra que, às vezes, podem ocorrer pequenos erros na transcrição, talvez devido à velocidade da fala.
#
# No entanto, o fato de ele conseguir gerar, do zero, uma transcrição completa de um episódio de 44 minutos de um podcast, com a minutagem ao lado, é algo fantástico e muito poderoso. As IAs podem ajudar muito no nosso dia a dia, seja em uma reunião de empresa ou na análise de imagens e vídeos.
#
# Como mencionado anteriormente, podemos relacionar o tema desse podcast com algum arquivo, seja de Excel, CSV, PDF, ou outro tipo. Podemos procurar partes do vídeo ou do áudio que possuem algum conceito encontrado nesse arquivo. As possibilidades são muitas.
#
# Com o Google AI Studio, temos o poder de subir imagens, vídeos, áudios e também de fazer a conversa com o chat, da mesma forma que fizemos anteriormente com o ChatGPT e a MariTalk.
#
# **Próximos passos**
#
# A seguir, vamos explorar outro tipo de IAs generativas, que trabalham com imagens.

# %% [markdown]
# ### **Trabalhando com dados**

# %% [markdown]
# Trabalhar com documentos de diversos formatos amplia significativamente as possibilidades de uso da Inteligência Artificial generativa, mas não substitui o uso das ferramentas tradicionais de manipulação desses documentos, como o Excel ou Docs, por exemplo.
#
# Considere que você enviou uma planilha para o ChatGPT. De que forma ele pode te ajudar na análise desses dados?
#
# a)
# O ChatGPT pode abrir a planilha diretamente no navegador e fazer edições, inserindo fórmulas e alterando células conforme necessário.
#
#
# ChatGPT não tem a capacidade de abrir ou editar diretamente arquivos no Excel. Ele pode analisar os dados se forem fornecidos em texto ou tabela, mas a manipulação direta de documentos é feita em ferramentas específicas como o Excel.
#
# b)
# **Analisando e identificando inconsistências ou erros em valores e fórmulas.**
#
# Você pode descrever as fórmulas ou funções que está usando e mostrar o documento como sendo o contexto de utilização. O ChatGPT pode ajudar a criar a lógica ideal para as fórmulas.
#
# c)
# O ChatGPT pode compartilhar a planilha automaticamente com outros usuários via e-mail ou outras plataformas de comunicação.
#
# O ChatGPT não tem a capacidade de enviar ou compartilhar arquivos automaticamente. A ação de compartilhamento precisa ser feita pelo usuário por meio das ferramentas apropriadas, como e-mail ou plataformas de colaboração.
#
# d)
# Fornecendo contexto histórico.

# %% [markdown]
# ### **Mão na massa: analisando planilha e gerando gráficos**
#
#
# Faça o download [desta planilha](https://) em formato CSV.
#
# Obs: Para ver as informações clique aqui aqui (https://github.com/alura-cursos/ias-generativas/blob/main/M%C3%A9dia%20de%20notas.csv.)
#
# Utilizando o Google AI Studio ou o ChatGPT 4o, faça upload da planilha e peça para que o modelo analise que tipos de dados ela contém.
#
# Depois, peça para o modelo calcular a média aritmética das notas de cada um dos alunos.
#
# Você pode também pedir que o modelo gere um gráfico, como o de dispersão das médias dos estudantes, por exemplo. Se não for possível, você pode pedir as instruções para gerar esse gráfico no Excel ou Google Sheets.

# %% [markdown]
# ### **Opinião do instrutor**
#
# A multimodalidade de alguns modelos é muito útil para analisar documentos e fazer perguntas sobre ele. É importante lembrar que os modelos de linguagem contém limitações. Eles são ótimos assistentes, mas não substituem a importância do olhar humano!
#
# Sempre cheque resultados de cálculos com ferramentas totalmente confiáveis e evite compartilhar dados sensíveis com grandes modelos.

# %% [markdown]
# ### **Para saber mais: Mais ferramentas**

# %% [markdown]
#  - A SheetGPT é uma ferramenta bastante interessante para auxiliar na análise de dados. Nesse vídeo da websérie sobre IAs Generativas, eu explico como usá-la.
#
#  - Outro vídeo da mesma websérie demonstra como utilizar o ChatGPT para a análise de arquivos e planilhas.

# %% [markdown]
# ### **Aula 04 - Geradores de imagens**

# %% [markdown]
# **Bing Images e DALL-E**

# %% [markdown]
# Nesta aula, exploraremos os principais geradores de imagem, focando nas inteligências artificiais que criam imagens. Até o momento, a nossa atenção esteve voltada para as I.A.s que geram ou analisam textos, áudio, vídeo ou imagens.
#
# **Modelos Multimodais**
#
# Quando uma I.A. lida com mais de um tipo de dado, como texto e imagens, ela é chamada de modelo multimodal. Isso significa que ela pode operar em diferentes modos: um modo para texto, outro para imagens (seja para criação ou reconhecimento) e outro para vídeos (também para criação ou reconhecimento).
#
# Essas I.A.s são conhecidas como I.A.s multimodais. Uma I.A. que opera apenas em um modo é limitada a realizar apenas uma dessas atividades.
#
# **Explorando o Bing Images**
#
# Vamos começar com o Bing Images, que ainda é gratuito no momento da gravação deste curso e está relacionado ao Copilot, ambos produtos da Microsoft. Embora a qualidade não seja a mais avançada, talvez por isso seja gratuita, é um bom ponto de partida para começar a usar I.A.s de geração de imagens.
#
# Faça login com sua conta Microsoft em "Ingressar e Criar" para utilizar o serviço.
#
# **Criando imagens com o Bing Images**
#
# Após o login, digitamos o pedido diretamente na plataforma, na parte superior. Neste campo de busca, temos a mensagem "Deseja ver como o Criador de imagens funciona? Selecione "Surpreenda-me" e depois "Criar"".
#
# Usaremos a mesma abordagem que nas aulas anteriores, supondo que trabalhamos em uma agência de marketing ou de viagens. Por exemplo, solicitamos:

# %%
Desenhe uma capa para um post de blog sobre viagens à Itália

# %% [markdown]
# No lado direito da tela, temos o número de créditos disponíveis. Depois de inserir a solicitação, pressionamos "Enter" ou clicamos em "Criar" para começar a gerar a imagem.
#
# O processo é rápido e eficiente, permitindo que façamos solicitações de forma bastante natural. Quanto mais claros formos em nossos pedidos, melhores serão os resultados. A ferramenta gera quatro imagens para cada solicitação:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por exemplo, ao solicitar uma imagem sobre viagens à Itália, podemos receber as seguintes opções: a primeira pode mostrar a Torre de Pisa, representando bem a Itália; a segunda pode apresentar gôndolas e a Piazza San Marco em Veneza; a terceira pode exibir um lago e montanhas do norte da Itália; e a quarta pode novamente mostrar a Torre de Pisa, uma igreja e uma tentativa de Coliseu.
#
# Este serviço é gratuito, então podemos experimentar à vontade. No lado da tela, temos opções para compartilhar a imagem na internet, salvá-la na nossa conta ou baixá-la para usar em artigos de blog, por exemplo. No entanto, o formato quadrado da imagem não pode ser alterado no momento.
#
# **Comparação com outras I.A.s**
#
# Esta é a primeira I.A. geradora de imagens que queremos apresentar. As outras duas opções que abordaremos nesta aula são pagas. Enquanto esta é gratuita, as outras têm custo.
#
# **Introdução ao DALL-E 3**
#
# Uma delas é o DALL-E 3, integrado ao ChatGPT. A OpenAI, que desenvolve o ChatGPT, é financiada pela Microsoft, a mesma empresa responsável pelo Bing, Bing Images e Copilot.
#
# Podemos ver que a plataforma DALL·E 3 é mencionada abaixo das quatro imagens geradas. O Bing Images oferece uma maneira gratuita de utilizar o DALL·E 3, que está integrado ao ChatGPT, sendo o gerador de imagens relacionado ao ChatGPT.
#
# Vamos voltar ao nosso chat "Hotéis em Roma com Sauna". Em vez de criar artigos de blog, desejamos criar uma imagem. Solicitamos nessa conversa em específico no ChatGPT:

# %%
Crie uma imagem para ilustrar esse artigo

# %% [markdown]
# **Análise da imagem criada**
#
# Observe que não estamos detalhando o que é a imagem, pois, com base no histórico, já sabemos o que estamos buscando.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Temos a seguinte descrição abaixo da imagem gerada:

# %% [markdown]
# Podemos visualizar que a imagem representa Roma, pois há um Coliseu ao fundo. As colunas também fazem referência a Roma e à Grécia. A sauna é representada por um modelo seco e o hotel inclui toalhas. A imagem incorpora todos os elementos do nosso post para ilustrar o conteúdo de forma adequada.
#
# Caso a imagem não esteja do seu agrado, você pode solicitar uma nova.
#
# Por exemplo, podemos pedir para gerar outra imagem sem a sauna e com mais foco na Itália.

# %%
Não gostei. Gere outra imagem, sem a sauna e com mais foco na Itália.

# %% [markdown]
# A nova imagem será criada conforme a solicitação: sem a sauna e com um foco maior na Itália.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Descrição abaixo da imagem gerada:

# %% [markdown]
# Aqui está a nova imagem que destaca uma experiência de luxo em Roma, com foco na rica herança cultural da cidade e sua arquitetura icônica. Esta imagem pode ser usada para promover uma estadia luxuosa na cidade eterna.

# %% [markdown]
# O modelo entenderá o contexto e, por exemplo, criará uma imagem de um quarto de hotel confortável, com uma mala e o Coliseu ao fundo, para reforçar que a cena é na Itália.
#
# Ele incluiu o símbolo do Instagram na imagem, como solicitado anteriormente para um post no Instagram, que era o passo 3. Se preferir, você pode pedir para remover o símbolo, e ele gerará uma nova imagem.
#
# **Conclusão**
#
# Esse é o poder das I.A.s generativas de imagem. O Bing Images, que utiliza o DALL·E 3, oferece uma forma gratuita com créditos limitados. Além disso, a versão paga do ChatGPT-4 também permite realizar essas gerações de imagens!

# %% [markdown]
# ### **Midjourney**

# %% [markdown]
# A terceira e última ferramenta que mencionamos é o Midjourney.
#
# **Midjourney**
#
# O Midjourney é, provavelmente, a ferramenta mais famosa e, atualmente, a que tem a melhor qualidade das imagens geradas. Até um tempo atrás, ela só estava disponível através do Discord, uma plataforma onde existem muitos chats e grupos, sendo muito utilizada pela comunidade de jogos online. No entanto, recentemente, eles lançaram uma plataforma própria, isto é, um site onde é possível solicitar as imagens, tornando o processo mais fácil.
#
# **Acessando o Midjourney**
#
# Para acessar, basta ir ao site midjourney.com.
#
# Neste site, existem algumas opções. A primeira exibida, caso você ainda não tenha uma conta no Midjourney, será a opção Sign Up, para se registrar na ferramenta.
#
# Ao clicar, o site perguntará se queremos continuar com a conta do Discord ou do Google. Não é possível criar uma conta do zero; deve ser uma conta do Discord ou do Google já existente.
#
# Nesse caso, faremos o login com a conta Google.
#
# Após o login, seremos redirecionados para o site, onde existem várias opções e uma lista para explorar, conforme indicado no menu "Explore", no canto superior esquerdo.
#
# A partir da página inicial do Midjourney, já conseguimos gerar imagens. Nessa página, também são exibidas imagens que a comunidade criou, todas muito bonitas e interessantes.
#
# Uma das principais vantagens do Midjourney é a ótima qualidade das imagens.
#
# O Midjourney é, majoritariamente, um serviço pago. Atualmente, eles oferecem algumas imagens gratuitas para contas novas, mas é possível que, no futuro, quando você assistir a este vídeo, as opções gratuitas estejam indisponíveis, então será necessário pagar para criar uma conta.
#
# No entanto, como mencionamos, a qualidade é ótima e o controle é muito bom, então, provavelmente, vale a pena.
#
# **Criando imagens no Midjourney**
#
# Para começar a criar imagens, o processo é muito simples. No menu à esquerda, basta clicar em "Create" (Criar), que nos redirecionará para a página midjourney.com/imagine.
#
# No Midjourney do Discord, o comando /imagine era usado para gerar as imagens.
#
# Ao clicar na barra de digitação "What will you imagine?", na parte superior, o site pedirá para aceitarmos os termos de serviço. Recomendamos ler os termos antes de aceitar.
#
# Em seguida, de maneira muito simples, escrevemos o nosso prompt, isto é, o nosso pedido. À direita da barra, há um símbolo que fornece as configurações do prompt.
#
# Clicando sobre ele, podemos escolher se queremos a imagem no formato Portrait (Retrato), mais vertical, voltado para TikTok, por exemplo; no formato Square (Quadrado), que é literalmente um quadrado 1 por 1; ou o formato Landscape (Paisagem), voltado para YouTube e similares.
#
# Nesse caso, escolheremos o formato Landscape na seção "Image Size".
#
# Existem várias opções de configuração, como o quanto queremos que a imagem seja estilizada (Stylization), o quanto queremos que ela seja estranha (Weirdness), a variedade (Variety), o modo padrão (Standard) ou o modo cru (Raw) do modelo, entre outras.
#
# Na seção "Model", usamos a versão mais atual do Midjourney no momento: a 6.1. É possível que haja uma versão mais atual futuramente, quando você assistir a este vídeo.
#
# Em relação à velocidade (Speed), podemos controlar se queremos que ele gere de uma maneira mais tranquila e demorada, ou se queremos que ele gere rapidamente. Isso é mais importante quando pagamos o Midjourney, pois há um limite de gerações rápidas por mês a depender da conta.
#
# **Como criar um prompt?**
#
# A maneira de gerar o pedido, normalmente, é sempre muito semelhante, mas podemos adicionar o estilo que desejamos para a imagem gerada. Nesse caso, vamos colocar, por exemplo, que queremos uma paisagem muito realista da Itália; um pedido muito simples.

# %%
uma paisagem muito realista da Itália

# %% [markdown]
# Após digitar e teclar "Enter", ele começa a gerar quatro imagens. O ar (Aspect Ratio) é a proporção da imagem gerada, que nesse caso, é 4:3, ou seja, no formato de landscape, de uma paisagem mais larga, como em vídeos no YouTube. Além disso, temos a versão (v) como 6.1.
#
# Por padrão, o Midjourney sempre irá gerar quatro opções de imagens diferentes. Ao clicar sobre as imagens geradas, elas parecem paisagens realistas de fato, o que é muito interessante.
#
# Agora vamos mudar o pedido e fazer um prompt um pouco diferente:

# %%
uma capa de artigo de blog com os principais pontos turísticos da Itália

# %% [markdown]
# Utilizando o Midjourney atualmente, percebemos que, ao digitar o pedido em inglês, ele funciona melhor do que em outros idiomas, como português, afinal, a ferramenta foi treinada com imagens nessa língua. O Midjourney entende português, mas fica mais nítido para ele se escrevermos em inglês.
#
# Mesmo com o prompt em português, ele gerou uma imagem de Veneza que parece uma foto. Temos também a imagem de um castelo no meio de um lago, do Coliseu de Roma parecendo uma foto com filtros, e da Catedral de Milão. As imagens estão perfeitas, destacando o realismo do Midjourney.
#
# **Alterando a proporção das imagens geradas**
#
# Agora, imagine que não queremos o Aspect Ratio da imagem em 4:3. O formato de paisagem, utilizado em vídeos no YouTube, por exemplo, normalmente não é o 4:3. A proporção 4:3 é um pouco mais fechada, enquanto o formato de paisagem é o 16:9, que é um pouco mais largo.
#
# Ao clicar no ar à direita das imagens geradas, automaticamente, é adicionado --ar 4:3 na barra de digitação do pedido. Da mesma forma, podemos incluir manualmente a proporção desejada.
#
# Dito isso, vamos copiar o texto do prompt anterior, colar no campo de pedido, e adicionar uma vírgula seguida de --ar 16:9, proporção mais larga usada no YouTube que estamos buscando.

# %%
uma capa de artigo de blog com os principais
pontos turísticos da Itália, --ar 16:9

# %% [markdown]
# Com isso, o Midjourney começará a criar as imagens com um ar de 16:9. Também conseguimos ajustar essa proporção na janela de configurações do prompt, na seção "Image Size".
#
# Para isso, usamos a barra de rolagem, enquanto analisamos o resultado à direita de "Reset" no canto superior direito. Ao fazer esse ajuste, o Midjourney cria mais quatro imagens diferentes, todas com qualidade excelente.
#
# **Alterando o estilo das imagens geradas**
#
# Além disso, podemos escolher o estilo. Imagine que, em vez do estilo realista do Midjourney, queremos um estilo de anime, por exemplo. Para isso, enviamos o seguinte prompt:

# %%
uma capa de artigo de blog com os principais pontos turísticos da Itália,
estilo anime, --ar 16:9

# %% [markdown]
# Ao clicar nas imagens geradas, percebemos nitidamente um personagem em uma cidade italiana no meio das montanhas, seguindo o estilo anime. Temos também a imagem de uma cidade mais moderna, como Milão, e outras imagens mais focadas em cidades nas montanhas.
#
# Podemos definir manualmente as opções de estilo desejadas. Uma ideia seria utilizar, por exemplo, "estilo do Van Gogh" no prompt, ou outros pedidos nesse sentido.
#
# **Conclusão**
#
# Esse é o poder do Midjourney, que como mencionamos anteriormente, é uma ferramenta majoritariamente paga. No canto inferior esquerdo, temos a opção "My Account > Manage Subscription, onde conseguimos gerenciar a nossa assinatura.
#
# Podemos assinar o plano anual (Yearly Billing) ou o plano mensal (Monthly Billing), cujos valores estão indicados na página "Manage Subscription".
#
# Caso prefira, você pode usar os recursos gratuitos enquanto ainda estiverem disponíveis, pois no momento em que você assistir a este vídeo, eles podem estar indisponíveis.
#
# Esperamos que você tenha gostado deste vídeo e consiga criar as suas imagens, seja utilizando o Bing Images, o Dall-E do ChatGPT, ou o Midjourney!

# %% [markdown]
# **Prompts para imagens**
#
# Em IAs geradoras de imagens, temos um campo de inserção de texto que funciona de forma similar aos prompts em IAs textuais. Considerando as técnicas de engenharia de prompt, qual das alternativas abaixo é um comando mais adequado para gerar uma imagem?
#
# a)
# "Imagem de um carro bonito."
#
# b)
# "Um carro esportivo em um café em Paris."
#
# c)
# "Desenhe um carro vermelho."
#
# d)
# **“Estilo realista. Baixo contraste. Um carro esportivo vermelho em frente a um café parisiense.”**
#
# Podemos pedir detalhes de estilo, cenário, contexto, ajustes, entre outros.

# %% [markdown]
# **Mão na massa: completando post com imagens**
#
# Lembra da atividade feita na aula 2, em que você criou um prompt para um post de Linkedin com um assunto do seu interesse?
#
# Utilize alguma das IAs generativas de imagem apresentadas para criar a imagem que ilustra esse post. Explore as ferramentas e prompts com diferentes especificações para encontrar a imagem que faz mais sentido para você.
#
# Aproveita para postar lá no Linkedin e marca a gente!
#
# **Opinião do instrutor**
#
# Pratique aplicar as técnicas que você aprendeu neste curso em problemas do seu cotidiano. Pode ser que a IA seja uma ótima assistente.
#
# Lembre-se: as respostas não são 100% precisas e a IA não substitui o trabalho humano. É imprescindível sempre checar fatos e cálculos.
#
# Além disso, em uma tecnologia tão recente, ainda existem debates éticos importantíssimos acontecendo. Para saber mais sobre esse assunto, recomendo a leitura do artigo https://www.alura.com.br/artigos/etica-e-inteligencia-artificial

# %% [markdown]
# **Para saber mais: Outras ferramentas**
#
# **Nessa aula, criamos imagens com três ferramentas: Bing Images, DALL-E e Midjourney.**
#
# Existem muitas outras, como a https://www.alura.com.br/artigos/stable-diffusion, por exemplo. No artigo Inteligência https://www.alura.com.br/artigos/inteligencia-artificial-desenha-e-cria-imagens você pode conhecer outras ferramentas interessantes.

# %% [markdown]
# ### **O que aprendemos?**
#
# ### **Nesta aula, aprendemos sobre:**
#
#  - Criação de imagens usando Bing Images, DALL-E e Midjourney.
#
#  - Prompts para imagens.

# %% [markdown]
# ### **Conclusão**

# %% [markdown]
# **O que aprendemos?**
#
# Desde o início do curso, aprendemos como não escrever um prompt, entendendo que é necessário incluir detalhes precisos e aprendendo a fornecê-los, indicando o que a IA pode e não pode fazer. No exemplo da agência, aprendemos a criar uma lista de hotéis, transformá-la em um post de blog com um parágrafo para cada hotel e até reescrever o post de uma maneira mais informal.
#
# Também aprendemos a criar regras para enviar e-mails automatizados para a clientela, respondendo a perguntas sobre hotéis na Itália, República Tcheca e Alemanha. Além disso, aprendemos a personalizar esses e-mails usando o nome da pessoa cliente, emojis amigáveis e respondendo às perguntas deles de uma maneira que possa incentivá-los a fazer uma compra.
#
# Em vez de enviar o prompt de uma vez, vimos que é possível dividir o processo em etapas: primeiro, pedimos que ele criasse uma lista, depois que escrevesse o artigo do blog, e então, que criasse um post no Instagram.
#
# Se você pretende trabalhar com mídias sociais, isso será muito útil para criar artigos e posts para diferentes redes, como Instagram e LinkedIn.
#
# Além disso, podemos usar essas técnicas para criar imagens que ilustrarão nossos posts, seja usando o DALL-E, o Bing Images ou o MidJourney. Além disso, podemos criar resumos de artigos e PDFs, como vimos com os artigos sobre a Itália e o Llama, sendo este último mais técnico.
#
# Depois de criar um resumo, podemos explorar um ponto mais específico do artigo, documento, PDF ou planilha. Mesmo que o documento original esteja em inglês, como vimos com os Scaling Law Experiments, a IA pode responder em português.
#
# Há muitas outras possibilidades, como alterar o texto ou pedir à IA para escrever um artigo de blog baseado no PDF, explicando o conteúdo de uma maneira mais simples e menos técnica.
#
# No Google AI Studio, vimos que além de lidar com textos e imagens, podemos analisar arquivos de vídeo e áudio longos, de até duas horas, relacionando com outros tipos de documentos. Isso pode ser útil em várias áreas do conhecimento, seja trabalhando com tecnologia, finanças, marketing, redes sociais, advocacia ou outras.
#
# Uma frase famosa do professor Scott Galloway, da Universidade de Nova York, diz a IA, não necessariamente, vai roubar nosso trabalho, mas que uma pessoa que saiba utilizar essas IAs pode ser mais qualificada e, portanto, ter uma vantagem na hora de ser escolhida para uma vaga de emprego.
#
# **Próximos passos**
#
# Recomendamos que você refaça todas as atividades deste curso, faça os exercícios extras e leia mais sobre o assunto para entender melhor e aplicar no seu dia a dia essas e outras IAs que você possa encontrar. A sua curiosidade é o único limite. Boa sorte!

# %% [markdown]
# ![Image Engenharia de Prompt..png](data:image/png;base64,...)

# %% [markdown]
# # **Criando prompts eficazes para IA Generativa.**

# %% [markdown]
# ## **Aula 01 - Preparando o ambiente.**

# %% [markdown]
# Antes de começar…
#
# Durante o curso, vamos utilizar diferentes ferramentas de Inteligência Artificial Generativa.
#
# Nesta aula, utilizaremos o ChatGPT, uma ferramenta disponível na [página da OpenAI](https://). Para começar a utilizá-la, é necessário criar uma conta na OpenAI.
#
# Se você ainda não possui uma conta, basta clicar na opção "Sign up" ou “Cadastrar” na página inicial e, em seguida, escolher entre criar uma conta ou utilizar uma conta Google ou Microsoft - caso escolha a segunda opção, será necessário permitir que a OpenAI acesse suas informações.
#
# Após efetuar o login, seguem abaixo alguns passos para começar a usar o ChatGPT:
#
# 1 - Digite sua primeira mensagem na caixa de texto e pressione "Enviar". Por exemplo: você pode começar com um simples "Olá" ou fazer uma pergunta.
#
# 2 - O ChatGPT responderá automaticamente à sua mensagem com uma resposta gerada por inteligência artificial. A partir daí, você pode continuar a conversa fazendo mais perguntas ou respondendo às perguntas do ChatGPT.
#
# 3 - Experimente diferentes tipos de perguntas ou tópicos para ver o que o ChatGPT é capaz de fazer. Você pode perguntar sobre um tema específico, pedir ajuda com uma tarefa ou simplesmente conversar com o ChatGPT.
#
# Caso você deseje mudar de tópico e começar uma nova conversa a qualquer momento, basta clicar na opção "New chat" (nova conversa) no menu lateral esquerdo.
#
# Para acompanhar este curso, é possível utilizar tanto a versão gratuita quanto a versão paga, chamada "Plus".
#
# Também vamos utilizar o [playground](https://) da OpenAI. Entretanto, essa é uma funcionalidade paga. Para essa atividade, é possível utilizar o [AI Studio](https://), o playground do modelo Gemini, do Google. Para utilizar, basta estar em uma conta Gmail.
#
#     Agora que você já sabe como utilizar o ChatGPT, podemos começar!

# %% [markdown]
# ## **A proximidade semântica**

# %% [markdown]
# ###**Modelos de linguagem**
#
# Quando observamos modelos de linguagem, como os famosos Large Language Models, vemos uma parte muito específica, que são modelos treinados com muitos dados, praticamente, com a internet inteira. Porém, o conceito de modelos de linguagem é anterior a isso.
#
# Imagine que, na língua portuguesa, temos a seguinte frase:
#
#     "Eu gosto de pizza".
#
# Quando usamos o verbo "gostar", é evidente que, após esse verbo, conjugado ou não, precisamos da preposição "de". Assim, temos "Eu gosto de pizza", "Eu gosto de viajar", "Eu gosto de você", e assim por diante. Quando analisamos outros idiomas, começamos a perceber que nem sempre é assim.
#
# Na língua inglesa, por exemplo, temos a frase "I like pizza". Nesse caso, o verbo "to like" equivale ao verbo "gostar" do português, mas não usa a preposição obrigatória do português.
#
# Em inglês, isso não existe. Quando falamos sobre um verbo, como, por exemplo, na frase "Eu gosto de viajar", podemos dizer "I like to travel" ou "I like traveling". Porém, não tem a preposição "de" obrigatória. O padrão da língua inglesa é diferente do padrão da língua portuguesa.
#
# Quando observamos um idioma completamente diferente, como turco, podemos encontrar o verbo sempre no final da frase. Assim, em turco, "Eu gosto de pizza" seria "Pizza severim".
#
# O substantivo "pizza" vem no começo, antes do verbo. Esse padrão do idioma turco é completamente diferente, tanto em relação ao português, quanto em relação ao inglês.
#
# ###**O que é um modelo de linguagem?**
#
# Analisados esses exemplos, o que é um modelo de linguagem?
#
# Falamos sobre idiomas, pois a ideia é passar dados para que o modelo aprenda padrões da linguagem humana e relações entre as palavras.
#
# Em português, o modelo que recebe os dados aprende, por exemplo, que depois do verbo "gostar" e suas conjugações, como "Eu gosto de" ou "Você gosta de", sempre teremos a preposição "de".
#
# Já em inglês, não será assim. Da mesma forma, em turco, teremos primeiro o substantivo e depois o verbo. Portanto, o modelo irá aprender esses padrões e relações entre as palavras.
#
# ###**O que são word embeddings?**
#
# Como o modelo aprende padrões e relações?
#
# Existe o conceito de word embeddings. Teoricamente, eles são representações distribuídas de palavras ou sub palavras numéricas; ou seja, é um número que representa cada palavra. Além disso, os embeddings conseguem representar a proximidade semântica entre uma palavra e outra.
#
# Imagine a palavra "carro". Analisando um gráfico de embeddings, provavelmente, essa palavra estará muito próxima das palavras "táxi", "ônibus", "trem", pois são todos meios de transporte.
#
# Da mesma forma, a palavra "carro" fica longe das palavras "cachorro", "focinho", "rei", "café", "escola", "universidade", entre outras, pois são palavras de categorias diferentes.
#
# Observe o word embedding abaixo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O word embedding consegue entender o significado da palavra. Quando observamos um gráfico desses vetores, notamos que a distância entre as palavras "carro" e "ônibus" é muito menor do que a distância entre as palavras "carro" e "escola", ou entre as palavras "carro" e "cachorro", por exemplo.
#
# Essa é uma base mais teórica, mas também é possível verificar alguns números:

# %% [markdown]
# | Palavra   | Proximidade |
# |-----------|-------------|
# | avião     |             |
# | voar      | 0,95        |
# | trem      | 0,78        |
# | ônibus    | 0,76        |
# | …         | …           |
# | focinho   | 0,015       |
# | xícara    | 0,09        |
# | abastecer | 0,61        |

# %% [markdown]
#     Observação! Os números da tabela acima são fictícios.
#
# Por exemplo: entre 0 e 1, quão próxima a palavra "avião", que está no topo da tabela, é da palavra "voar"? As palavras "avião" e "voar" possuem uma relação muito forte, então entre 0 e 1, poderia ser 0,95 o valor da relação entre elas. Com a palavra "trem", temos uma relação de 0,78, pois ambos são meios de transporte. Da mesma forma, a relação com "ônibus" é 0,76.
#
# Por outro lado, a relação de "avião" com "focinho" seria 0.0015, pois não há proximidade. Embora sejam números fictícios, conseguimos ter uma ideia de como os modelos funcionam internamente.
#
# ###**Word embeddings e operações matemáticas**
#
# Outra coisa muito interessante que pessoas cientistas conseguiram resolver a partir desses embeddings é que conseguimos fazer operações matemáticas. Como mencionamos, no momento de calcular e treinar os modelos de linguagem, ele não terá, por exemplo, a palavra "avião", mas sim uma representação numérica da palavra "avião". Porém, como fazer cálculos com esses números?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Na imagem acima, temos como exemplo as palavras "homem" e "mulher". Da mesma forma, encontramos "rei" e "rainha". A palavra "homem", geralmente, é relacionada a "rei", e "rainha" a "mulher". Trata-se de uma questão de gênero das palavras.
#
# A partir disso, foi identificado que quando temos, por exemplo, a palavra "rei" e a palavra "homem", ao fazer um cálculo matemático substituindo a palavra "rei" pela palavra "mulher", o word embedding muda para a palavra "rainha".
#
# O mesmo acontece no exemplo à direita, mas para tempos verbais. Com o verbo "andando", se colocarmos uma soma, uma subtração, fizermos um cálculo com um valor específico, por exemplo, do passado, ele saberá que o resultado deve ser "andei" ou "andou". Também temos o exemplo do verbo "cozinhando", que está no gerúndio e se associa a "cozinhei" ou "cozinhou".
#
# É muito interessante como os word embeddings funcionam internamente e como eles conseguem fazer associações entre muitas palavras. Evidentemente, trouxemos apenas o exemplo da palavra "avião" em relação a uma série de palavras, mas imagine que isso é uma tabela gigante, um gráfico tridimensional com todas as palavras relacionadas umas às outras. Assim funcionam os modelos de linguagem.
#
# ###**Prevendo as próximas palavras**
#
# Uma vez treinados os modelos de linguagem, eles tentam prever a próxima palavra em um contexto. Nesse caso, enviamos uma pergunta ou uma frase, e ele sempre tenta adivinhar a próxima palavra que faz mais sentido no contexto inserido. É exatamente isso que os modelos de linguagem, como o ChatGPT, o Gemini do Google, e todos os outros fazem: adivinhar a próxima palavra.
#
# É como se fosse a funcionalidade de preenchimento automático (autocomplete) do celular, que consegue dar três opções de quais são as próximas palavras mais prováveis que estarão na frase. Os modelos de linguagem também fazem isso, mas de uma maneira muito mais complexa e com um treinamento muito maior, com muito mais palavras e conhecimento por trás dele.
#
# ###**Utilizando o ChatGPT**
#
# Com o site do [ChatGPT](https://) aberto, vamos usá-lo no modo gratuito GPT-4o para fazer uma brincadeira de tentar adivinhar como funciona o ChatGPT. Para isso, preparamos um prompt, que é simplesmente um pedido que faremos para a ferramenta:

# %% [markdown]
# *Vamos simular como funciona o ChatGPT. Para cada frase que eu escrever no prompt, você deve listar as 5 palavas com maior probabilidade que você usaria para completá-la, junto com a probabilidade de cada uma delas. Combinado? Apenas as palavras e probabilidades, sem mais nada. Me diga se você entendeu.*

# %% [markdown]
# Começaremos dessa forma a primeira conversa com o ChatGPT. Como resposta, ele diz "Entendi.", então vamos enviar o primeiro exemplo utilizando o prompt abaixo:

# %%
Eu gosto muito de inteligência artificial e quero trabalhar

# %% [markdown]
# Como retorno, temos seguinte lista de palavras:

# %% [markdown]
# 1. com (45%)
#
# 2. nessa (25%)
#
# 3. na (20%)
#
# 4. no (5%)
#
# 5. em (5%)

# %% [markdown]
# Temos a palavra "com" com 45% de probabilidade de ser a próxima palavra. Também foi retornada a palavra "nessa"; poderia ser "nessa área", "quero trabalhar com isso", "quero trabalhar na área".
#
# Agora, suponha que escolhemos a primeira palavra que ele sugeriu: "com". A partir disso, enviaremos um novo prompt:

# %% [markdown]
#     Eu gosto muito de inteligência artificial e quero trabalhar com

# %% [markdown]
# Agora, recebemos novas respostas:

# %% [markdown]
# 1. isso (40%)
#
# 2. ela (30%)
#
# 3. desenvolvimento (15%)
#
# 4. você (10%)
#
# 5. projetos (5%)

# %% [markdown]
# A cada palavra, o ChatGPT tenta adivinhar qual é a maior probabilidade da próxima.
#
# Além disso, outra coisa muito interessante dos modelos de linguagem é que eles conseguem manter o contexto da conversa, que foi, na verdade, o grande motivo da disrupção que eles causaram.
#
# Vamos abrir um chat novo do ChatGPT e fazer a seguinte pergunta:

# %%
Qual era o esporte do atleta Rogério Ceni?

# %% [markdown]
# Como resposta, o ChatGPT diz o seguinte:
#
# Rogério Ceni foi um jogador de futebol brasileiro. Ele é amplamente conhecido por sua carreira como goleiro, especialmente no São Paulo Futebol Clube, onde se destacou não apenas por suas habilidades defensivas, mas também por ser um exímio cobrador de faltas e pênaltis, marcando mais de 130 gols ao longo de sua carreira.
#
# Em seguida, vamos enviar uma nova pergunta:

# %%
Qual foi o título mais relevante da carreira dele?

# %% [markdown]
# Note que não escrevemos "da carreira do Rogério Ceni", mas sim "da carreira dele". Ele responde:
#
# O título mais relevante da carreira de Rogério Ceni é, provavelmente, a conquista do Mundial de Clubes da FIFA em 2005 com o São Paulo Futebol Clube. Nesse torneio, Rogério Ceni teve uma atuação decisiva, especialmente na final contra o Liverpool, onde fez defesas cruciais e ainda foi eleito o melhor jogador da competição. Essa vitória solidificou sua reputação como um dos maiores goleiros da história do futebol.
#
# Portanto, o ChatGPT consegue manter o contexto, tanto da pergunta anterior, quanto da própria resposta que ele forneceu. Cada vez que enviamos um prompt e recebemos uma resposta de um modelo de linguagem, ele mantém todo o contexto anterior. É isso que os torna tão poderosos: a capacidade de não se perder em contextos longos.
#
# ###**Conclusão**
#
# Pensando no exemplo anterior, quando testamos a previsão das palavras, será que o modelo de linguagem sempre escolhe a palavra com maior probabilidade?

# %% [markdown]
# ### **Word embeddings**

# %% [markdown]
# Nathália é uma desenvolvedora que trabalha em uma editora de livros de tecnologia. Ela está construindo uma solução baseada em Inteligência Artificial que faça sugestões de novos livros para leitores que já são clientes da editora.
#
# Para iniciar seu projeto, Nathália está aprendendo sobre word embeddings e ficou impressionada sobre como as palavras são representadas e agrupadas no espaço de embeddings.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Em relação à distribuição das palavras nesse espaço, quais afirmações são verdadeiras?
#
# a) **Palavras que costumam aparecer juntas em frases estão mais próximas no espaço de embeddings.**
#
# Os modelos de linguagem de grande porte são treinados com base em uma quantidade muito grande de texto e aprendem sobre a semântica das palavras e sobre contexto a partir da coocorrência de palavras nos textos de treinamento. Quando palavras são frequentemente usadas juntas, o modelo de embeddings "aprende" que elas têm uma relação contextual forte, resultando em representações numéricas (embeddings) que estão mais próximas entre si.
#
# b)
# Palavras que têm o oposto de significado uma da outra estão necessariamente muito distantes no espaço de embeddings.
#
# c) **Palavras que compartilham um significado muito próximo, como “calor” e “quente”, estão próximas no espaço de embeddings.**
#
# Como "calor" e "quente" são frequentemente usados em contextos semelhantes e têm significados relacionados, seus embeddings acabam sendo similares, refletindo essa proximidade semântica.
#
# d)
# Palavras que pertencem à mesma categoria gramatical, como substantivos ou verbos, estão sempre próximas no espaço de embeddings.

# %% [markdown]
# ### *O que são tokens?*

# %% [markdown]
# No final da aula anterior, fizemos a seguinte pergunta:
#
# Será que o modelo sempre tenta prever a próxima palavra? Isto é, ele sempre escolhe a palavra que tem a maior probabilidade?
#
# Na verdade, não exatamente. Existe um conceito que as pessoas desenvolvedoras dos modelos de linguagem inventaram, chamado temperatura. Vamos entender o que isso significa?
#
# ###**Temperatura**
#
# A temperatura é basicamente a probabilidade de um modelo escolher outra palavra que não seja a mais provável. Isso foi criado porque notaram que, quando o modelo escolhia sempre a palavra mais provável, a resposta ficava robótica demais, sem os truques que nós, humanos, usamos ao escrever um texto real. Mostraremos, na prática, como funciona o conceito de temperatura.
#
# ###**Entendendo o conceito de temperatura na prática**
#
# Podemos acessar diretamente o [Playground](ttpps://) da plataforma da OpenAI, onde, geralmente, as pessoas desenvolvedoras exploram mais, criam os modelos, e também testam modelos novos. Conseguimos experimentar bastante, pois a ferramenta oferece várias opções de testes.
#
# Uma delas, no canto superior direito, é a "Temperature", que vai de 0 a 2. Por padrão, ela é definida como 1, exatamente a metade. Vamos fazer alguns testes para entender como ela funciona?
#
# **Realizando o teste com temperatura 0**
#
# Começaremos enviando o seguinte prompt no chat:

# %%
Complete a frase a seguir:

Eu gosto muito de comer…

# %% [markdown]
# Inicialmente, testaremos a **temperatura em 0.** Como retorno, recebemos:
#
#     Eu gosto muito de comer chocolate.
#
# Feito o teste, podemos apagar a resposta clicando no botão de menos (-) à direita dela. Feito isso, conseguirmos executar novamente o comando, clicando no botão "Run", no canto inferior direito.
#
# Agora, recebemos como resultado a seguinte frase:
#
#     Eu gosto de comer pizza.
#
# Note que ele mudou apenas um pouco a resposta. Vamos testar mais uma vez? Após executar novamente o prompt, recebemos a mesma resposta do primeiro envio:
#
#     Eu gosto muito de comer chocolate.
#
# Após rodar algumas vezes seguidas, notamos que o Playground quase sempre retorna a resposta "Eu gosto muito de comer chocolate.". No nosso caso, aconteceu uma única vez a resposta "pizza".
#
# ###**Realizando o teste com temperatura 1**
#
# Agora, vamos testar a temperatura no valor intermediário, ou seja, 1. Feito isso, executaremos novamente o prompt abaixo:

# %%
Complete a frase a seguir:

Eu gosto muito de comer…

# %% [markdown]
# Após rodar algumas vezes, recebemos primeiro a resposta "Eu gosto muito de comer pizza.", depois "Eu gosto muito de comer chocolate.", em seguida "Eu gosto muito de comer chocolate" se repete duas vezes, e depois vem "Eu gosto muito de comer pizza." novamente.
#
# Ele exibe a resposta com as palavras "pizza" e "chocolate" algumas vezes, então ainda existe uma preferência por essas duas comidas, mas as frequências estão variando mais.
#
# **Evidentemente, isso é um experimento anedótico, não um experimento científico, mas conseguimos entender melhor a temperatura na prática através desses testes.**
#
# **Realizando o teste com temperatura 1.4**
#
# Agora vamos definir a temperatura em 1.4, por exemplo, e executar novamente o teste.

# %% [markdown]
# Complete a frase a seguir:
#
# Eu gosto muito de comer…

# %% [markdown]
#     pizza! É uma delícia, não acha?
#
# Acima, temos a primeira resposta gerada pelo Playground. Além de usar a opção "pizza", ele completou a frase com "É uma delícia, não acha?". É a primeira vez que isso acontece nesse caso.
#
# Ao executar novamente, recebemos a mesma resposta dos testes anteriores: "Eu gosto muito de comer pizza". Na sequência, recebemos "Eu gosto muito de comer chocolate quente".
#
# Note que, quanto mais alta for a temperatura, mais variadas serão as respostas retornadas. Conforme dito anteriormente, quando colocamos uma temperatura muito baixa, ele tende a sempre, ou quase sempre, escolher a primeira resposta mais provável. Ou seja, da lista de palavras que ele pode escolher, ele irá optar quase sempre pela palavra com a probabilidade mais alta.
#
# Conforme aumentamos a temperatura de 0 para 0.7, para 1, para 1.4, e assim em diante, talvez ele escolha outras palavras diferentes da primeira (a segunda, a terceira, a quarta, ou a quinta).
#
# **Realizando o teste com temperatura 2**
#
# Quando colocamos uma temperatura muito alta, talvez o Playground possa escolher uma palavra que sequer está entre as cinco listadas no ChatGPT.
#
# Vamos observar o que acontece quando definimos a **temperatura em 2?**

# %%
Complete a frase a seguir:

Eu gosto muito de comer…

# %% [markdown]
# **he server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error.**
#
# Note que houve um erro, ou seja, ele nem sabe como processar tudo isso. Podemos testar a temperatura um pouco mais baixa, como em 1.71, por exemplo.
#
#     sorvete nos dias quentes e pipoca quando assisto a filmes.
#
# É uma resposta diferente, mas quando executamos novamente, recebemos o mesmo erro de antes. Portanto, quando colocamos uma temperatura muito alta, acima de 1.5, para essa plataforma da OpenAI, em vez de usar palavras normais que têm uma probabilidade alta de acontecer, ele começa a inserir símbolos, códigos, coisas com probabilidade muito baixa de ser a próxima palavra.
#
# No entanto, conforme alteramos isso, indicamos para a ferramenta que ela deve escolher uma próxima palavra com probabilidade muito baixa, provavelmente. Essa é a ideia da temperatura.
#
# **Tokens**
#
# Existe outro conceito que podemos abordar: o de **tokens.**
#
# Falamos muito sobre palavras até o momento, mas modelos de linguagem não funcionam com palavras, e sim com tokens, que podemos definir como a unidade básica em modelos de linguagem, uma representação de palavras ou sub palavras.
#
# Imagine, por exemplo, a palavra "infeliz". Na língua portuguesa, poderíamos ter dois tokens:
#
#  - O token "in";
#
#  - E o token "feliz".
#
# O token "in" também pode ser usado com outras palavras, como "indivisível", "incrível", entre várias outras. Por exemplo: em "indispensável", um token seria "in", e o outro seria "dispensável".
#
# Esse é apenas um conceito básico de tokens para explicar a questão dos modelos de linguagem, pois utilizamos exemplos com palavras anteriormente, mas, na verdade, são partes de palavras.
#
# Às vezes, um token corresponde a uma palavra inteira, mas, às vezes, corresponde a uma parte de uma palavra, e isso depende do algoritmo de tokenização usado pela empresa.
#
# **Conhecendo o algoritmo de tokenização da OpenAI**
#
# Vamos conhecer o algoritmo de tokenização da própria OpenAI, disponibilizado na página Tokenizer. Nela, conseguimos visualizar o tokenizador usado para os modelos GPT-3.5 e GPT-4. Em breve, teremos o do GPT-4.0, modelo mais atual no momento da gravação deste curso.
#
# Podemos testar uma mesma frase em três idiomas e conferir quantos tokens ela corresponde em casa. Começaremos com uma frase em português:

# %% [markdown]
# **Eu estou fazendo um curso de Engenharia de Prompt na Alura porque eu quero conhecer muito mais sobre inteligência artificial e usá-la na minha carreira.**

# %% [markdown]
# Uma frase básica, de **152 caracteres e 37 tokens.** "Eu" é um token, o espaço seguido de "est" é outro token, "ou" é outro token, e assim em diante. Nesse caso, poderia ser "está", "estou", "estamos".
#
# Da mesma forma, espaço seguido de "faz" um token. Poderíamos ter, por exemplo, "fazer" ou "fazendo". Espaço seguido de "curso" também é um token por si só.
#
# O importante no momento é lembrar desse número: 37 tokens para a frase em português. Agora, vamos testar a mesma frase, mas em inglês.

# %% [markdown]
# **I'm taking a Prompt Engineering course at alura because I want to learn a lot more about artificial intelligence and use it in my career.**

# %% [markdown]
# Nesse caso, temos **28 tokens.** Isso pode acontecer porque, na tradução, são usadas menos palavras, mas também há outros motivos. Observe, por exemplo, o token formado por espaço e "taking".
#
# Da mesma forma, espaço seguido de "Prompt" é um token, e espaço "Engineering" também. Poderia ser "Engineer" e "ing", mas foi representado o espaço seguido de "Engineering" como uma unidade.
#
# Quando esses modelos são treinados, nas línguas mais usadas no treinamento, os tokens tendem a ser a própria palavra. O português é um idioma com menos presença no treinamento dos modelos GPT-3.5 ou GPT-4 do que o inglês; por isso, é um pouco diferente e temos mais tokens em português.
#
# Por último, vamos testar um idioma bem diferente: **o grego.**

# %% [markdown]
# **Κάνω ένα μάθημα Prompt Engineering στην Alura επειδή θέλω να μάθω πολλά περισσότερα για την τεχνητή νοημοσύνη και να τη χρησιμοποιήσω στην καριέρα μου.**

# %% [markdown]
# Agora, temos **113 tokens.** O número de palavras é praticamente o mesmo, com 151 caracteres, mas praticamente cada letra é um token. Observe, por exemplo, a palavra "περισσότερα". O grego é uma língua pouco representada no treinamento desses modelos, então quase toda letra vira um token.
#
# **Conclusão**
#
# Conhecemos a base dos modelos de linguagem: como eles funcionam; o conceito de temperatura; bem como o conceito de tokens. Na próxima aula, continuaremos aprendendo sobre modelos de linguagem, mas entraremos na engenharia de prompt efetivamente!

# %% [markdown]
# ## **Faça como eu fiz: explorando probabilidades**

# %% [markdown]
# Nessa aula, descobrimos como modelos de linguagem de grande escala, como o ChatGPT, compreendem e geram texto.
#
# Esses modelos são treinados com uma quantidade muito grande de textos e, durante o treinamento, vão criando “compreensões matemáticas” sobre linguagem, semântica e significado.
#
# Quando enviamos uma instrução para o modelo, o texto é primeiro dividido em tokens e, em seguida, convertido em embeddings. Cada embedding é um valor numérico que representa a palavra em um espaço matemático, onde todo o vocabulário do modelo é organizado de acordo com o contexto.
#
# Então, o modelo gera uma palavra de cada vez, calculando qual próxima palavra é a mais provável no contexto da resposta.
#
# Ainda vimos o conceito de temperatura aplicado na IA generativa: a temperatura é um parâmetro que permite controlar se o modelo vai escolher a palavra mais provável e criar uma resposta robótica, ou escolher palavras com menor probabilidade e criar respostas mais criativas.
#
# **Agora é sua vez!**
#
# Envie o prompt abaixo para o ChatGPT e, então, envie alguma frase incompleta para que ele responda com as probabilidades. Experimente com diversas frases para compreender melhor como as palavras são escolhidas no momento da geração de texto.

# %% [markdown]
# **Vamos simular como funciona o ChatGPT. Para cada frase que eu escrever no prompt, você deve listar as 5 palavras com maior probabilidade que você usaria para completá-la, junto com a probabilidade de cada uma delas. Combinado? Apenas as palavras e probabilidades, sem mais nada. Me diga se você entendeu.**

# %% [markdown]
# Você também pode ajustar a temperatura no playground do modelo para experimentar como funciona a geração de texto com diferentes valores desse parâmetro.
#
# **Dica: a OpenAI, empresa que desenvolveu o ChatGPT, não fornece um nível gratuito de uso do [**playground.**](https://) Para essa atividade, é possível utilizar o [AI Studio](tttps://), o playground do modelo Gemini, do Google. Para utilizar, basta estar em uma conta Gmail. Divirta-se!**
#
# Explore também o tokenizador da OpenAI.

# %% [markdown]
# **Opinião do instrutor**
#
# Uma experiência divertida pode ser criar uma frase com as palavras menos prováveis sugeridas pelo ChatGPT. Apenas alterando a palavra maior para menor no prompt que utilizamos na simulação, assim:
#
# **Vamos simular como funciona o ChatGPT. Para cada frase que eu escrever no prompt, você deve listar as 5 palavras com menor probabilidade que você usaria para completá-la, junto com a probabilidade de cada uma delas. Combinado? Apenas as palavras e probabilidades, sem mais nada. Me diga se você entendeu.**
#
# Ao enviar a frase “Eu gosto de mergulhar no”, a maior probabilidade de continuação seria “mar”, a segunda, “rio”. Mas, pedindo as menores probabilidades, temos como resposta apenas palavras que não tem nenhuma relação com mergulho:

# %% [markdown]
# | Palavra    | Probabilidade |
# |------------|----------------|
# | elefante   | 0.00001%       |
# | contêiner  | 0.00002%       |
# | caminhão   | 0.00003%       |
# | satélite   | 0.00004%       |
# | urânio     | 0.00005%       |

# %% [markdown]
# Compreender conceitos que explicam como funcionam modelos de linguagem é um passo importante para aprender a tirar o melhor proveito dessa tecnologia. Na próxima aula, vamos conhecer o que é a famosa Engenharia de Prompt.

# %% [markdown]
# ### **O que aprendemos?**

# %% [markdown]
# **Nessa aula, você aprendeu a:**
#
#  - Conceituar como as palavras são representadas no modelo através de word embeddings e tokens;
#
#  - Identificar como as palavras se relacionam através da semântica em um modelo de linguagem;
#
#  - Simular o funcionamento do modelo de linguagem visualizando probabilidades;
#
#  - Explorar o parâmetro de temperatura no playground da OpenAI.

# %% [markdown]
# ### **Aula 02 - Engenharia de Prompt.**

# %% [markdown]
# ####**O que é Engenharia de Prompt?**

# %% [markdown]
# Finalmente, entraremos no conceito dos princípios da engenharia de prompt. Mas, antes disso, usaremos outro modelo de linguagem, o Google Gemini. Vamos explorar diferentes IAs ao longo do curso.
#
# **Usando o Google Gemini para criar um prompt**
#
# Imagine que você está no trabalho e sua liderança te dá uma tarefa. Você precisa escrever um texto para um post de Instagram sobre inteligência artificial. A página do Instagram onde será publicado, é majoritariamente acessada por pessoas jovens, entre 14 e 20 anos. Para isso, você usara uma IA para te ajudar.
#
# Para isso, no chat no Gemini encaminharemos o seguinte prompt:

# %%
Escreva um texto sobre inteligência artificial

# %% [markdown]
# Nisso, o Gemini responde com um texto com várias informações..
#
# Inteligência Artificial: Desvendando os Mistérios da Mente Humana nas Máquinas
#
# A Inteligência Artificial (IA), nascida na década de 50, busca replicar a inteligência humana em máquinas, dotando-as da capacidade de aprender, raciocinar e tomar decisões autônomas. Mais do que ficção científica, a IA já é uma realidade presente no nosso dia a dia, desde assistentes virtuais como Siri e Alexa até carros autônomos e diagnósticos médicos.
#
#     //Trecho omitido
#
# Perceba que é um texto que não atente as características que precisamos seguir, como público e o local onde será publicado.
#
# **Estrutura do prompt**
#
# Então, na lateral superior esquerda da página, clicamos no botão "Nova conversa" para abrirmos um novo chat. Nele, escrevemos um prompt mais detalhado.

# %% [markdown]
# **Escreva um texto sobre inteligência artificial. Este texto será usado em um post do Instagram. Então, siga o formato mais comum dessa rede social. Utilize uma linguagem informal, com gírias. No final, adicione uma chamada para que o público clique no link da bio, caso queira mais informações.**

# %% [markdown]
# Após encaminhar, temos a resposta abaixo:
#
# **IA: O futuro tá batendo na porta!**
#
# *Já reparou como tudo tá cheio de "inteligência artificial" por aí? Carro que dirige sozinho, app que sabe o que você quer comprar antes de você mesmo, robôs que fazem cirurgias... Mas calma, nem pira! A IA ainda tá no começo, mas o futuro promete!*
#
# *Mas o que é essa tal de IA? É tipo dar superpoderes pros computadores! Eles aprendem com os dados, raciocinam, tomam decisões... tudo igual a gente, só que muito mais rápido!*
#
#     //Trecho omitido
#
# Repare como o texto é informal, bem diferente do primeiro. Está muito semelhante à tarefa que foi solicitada. Além disso, como mencionamos que é para um post no Instagram, repare que a IA sugere hashtags. Assim, temos uma resposta muito melhor.*
#
# Quando falamos de conceito de engenharia de prompt se refere a como podemos projetar o pedido para o modelo de linguagem da melhor maneira possível. Assim, a IA poderá dar uma resposta com as informações que precisamos.
#
# Com isso, conseguimos identificar como precisamos escrever um pedido quando projetamos o prompt. No vídeo seguinte, descobriremos alguns princípios básicos na criação do prompt ideal.

# %% [markdown]
# ### **Para saber mais: motivando a ação**

# %% [markdown]
# O termo prompt é conhecido antigo de pessoas que trabalham na área de tecnologia. O “Prompt de comando” do Windows, por exemplo, é uma interface que recebe códigos que executam funções administrativas avançadas no sistema operacional. Na área da computação, esse termo já é utilizado desde as primeiras interações de usuários com máquina por meio de texto.
#
# Mas… o que essa palavra significa?
#
# Em tradução literal do inglês, prompt significa “incitar” ou “induzir”, “fazer com que algo aconteça”, “motivar”. É um verbo que indica que algum movimento está prestes a acontecer.
#
# Quando uma interface apresenta um prompt para a pessoa usuária, é exatamente isso que está acontecendo: o programa está nos “provocando” a fazer um pedido através da linha de prompt. Quando enviamos o comando, devolvemos o incentivo, e isso inicia a interação entre a pessoa e a máquina.
#
# No contexto de modelos de linguagem e inteligência artificial, o prompt é fundamental e permite que a interação se assemelhe a uma conversa, com o uso de linguagem natural.
#
# Sendo assim, criar um bom prompt para interagir com um modelo de linguagem requer técnicas que compreendam o funcionamento dessa tecnologia, assim como na comunicação humana: é importante conhecer o público-alvo para adaptar o discurso em uma palestra, por exemplo. Da mesma forma, é importante conhecer os fundamentos de um modelo de linguagem para adaptar a comunicação e obter bons resultados.

# %% [markdown]
# ### **Preparando o ambiente**

# %% [markdown]
# Na aula seguinte, utilizaremos o modelo de linguagem Mistral. Você pode utilizar qualquer modelo que prefira para acompanhar a aula, mas, caso queira conhecer o Mistral, é preciso criar uma conta.
#
# Você pode fazer login diretamente com o Google ou com a Microsoft e permitir acesso a alguns dados, ou, se preferir, clique em “Registrar” para criar uma conta do zero.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Princípios de criação**

# %% [markdown]
# Já compreendemos o conceito de engenharia de prompt. Agora, analisemos os princípios mais importantes e relevantes em sua criação.
#
# ###**Princípios para a criação de um prompt ideal**
#
# Existem algumas recomendações feitas pelas próprias empresas que estão na vanguarda da IA, como a OpenAI, Meta, o Google, Antropic, Muddy Talk e muitas outras. Vamos analisá-las.
#
# A primeira recomendação é ter clareza ao dar as instruções. Imagine que somos profissionais sêniores ensinando uma tarefa do dia a dia para uma pessoa estagiária. Foi isso que fizemos no prompt inicial, pedimos para a ferramenta escrever um texto sobre inteligência artificial.
#
# Agora, suponhamos que somos responsáveis por uma página de Instagram para jovens e pedimos para uma pessoa estagiária escrever um texto sobre IA, sem dar nenhum parâmetro. Por exemplo, não especificamos se é para o Instagram, Twitter ou para o Facebook, nem o público. Considerando tudo isso, o resultado não será bom.
#
# Portanto, é importante explicar para essa pessoa estagiária que o texto será usado em um post do Instagram, que deve seguir esse formato. Além disso, é interessante usar uma linguagem informal e com gírias, porque o público é jovem. Precisamos ter clareza quando daremos as instruções, considerando que o modelo é um auxiliar, que precisa saber exatamente do que estamos falando.
#
# Outro ponto importante é dividir tarefas complexas em sub tarefas menores. Para ilustrar isso, daremos um exemplo que a própria OpenAI percebeu em um treinamento de modelos anteriores.
#
# Existe um jogo de tabuleiro chamado Detetive no qual há vários personagens e precisamos adivinhar quem foi o responsável por cometer o crime, com qual instrumento foi e o local. Foi feito um teste semelhante com esse modelo. Então, usaremos agora o Le Chat da empresa francesa Mistral LLM. Você pode usar a que preferir, depende do modelo.
#
# Abaixo do chat, clicamos em "Model" e mudamos para "Small". Após, colamos o seguinte prompt inicial testado inicialmente:

# %% [markdown]
# Use as dicas a seguir para responder à seguinte questão de múltipla escolha, usando o seguinte procedimento:
# Dicas:
# 1. A Senhorita Scarlett era a única pessoa na sala.
# 2. A pessoa com o cachimbo estava na cozinha.
# 3. O Coronel Mostarda era a única pessoa no observatório.
# 4. O Professor Plum não estava na biblioteca nem na sala de bilhar.
# 5. A pessoa com o castiçal estava no observatório.
#
# Pergunta: O Coronel Mostarda estava no observatório com o castiçal?
#
# (a) Sim, O Coronel Mostarda estava no observatório com o castiçal
# (b) Não; O Coronel Mostarda não estava no observatório com o castiçal
# (c) Desconhecido; não há informações suficientes para determinar se o Coronel Mostarda estava no observatório com o castiçal
#
# Resposta:

# %% [markdown]
# Tentaremos analisar essas dicas. Se o Coronel Mostarda era a única pessoa no observatório e a pessoa com o castiçal estava no observatório, consequentemente a resposta é sim.
#
# Mas, quando esse prompt era enviado para a IA, com as sugestões de resposta, notou-se que frequentemente a resposta que o modelo dava era "desconhecido, não tem informações suficientes".
#
# Enviamos esse prompt no Le Chat para analisarmos sua resposta. Assim, temos o seguinte retorno:

# %% [markdown]
# b) Não; O Coronel Mostarda não estava no observatório com o castiçal.
#
# Explicação: De acordo com as dicas, sabemos que o Coronel Mostarda estava no observatório (dica 3) e que a pessoa com o castiçal também estava no observatório (dica 5). No entanto, as dicas não especificam que o Coronel Mostarda era a pessoa com o castiçal. Portanto, podemos concluir que o Coronel Mostarda não estava no observatório com o castiçal, pois as dicas não nos permitem afirmar que ele era a pessoa que possuía o castiçal.

# %% [markdown]
# Repare que temos uma resposta errada, afinal a correta seria a alternativa A. Usamos um modelo Small, menos poderoso. Talvez se fizermos novamente o mesmo teste, usando o mesmo modelo, talvez ele dê uma resposta diferente.
#
# Para isso, copiamos o prompt, depois, na lateral superior esquerda da tela, clicamos no botão identificado pelo ícone de "+". Colamos e enviamos. Feito isso, temos a resposta abaixo:

# %% [markdown]
# (a) Sim: O Coronel Mostarda estava no observatório com o castiçal.
#
# Explicação: De acordo com as dicas, o Coronel Mostarda era a única pessoa no observatório (dica 3) e também havia uma pessoa com o castiçal no observatório (dica 5). Como não há nenhuma outra pessoa mencionada no observatório, podemos concluir que o Coronel Mostarda estava no observatório com o castiçal.

# %% [markdown]
# Agora a resposta foi "Sim", repare como muda com frequência a resposta para esse. Então, as pessoas perceberam que ao pedir para dividir essa tarefa em sub tarefas, geralmente a resposta é melhor.
#
# Criaremos um novo chat, novamente clicando no botão de "+". Colamos o mesmo prompt, porém, no meio no texto, antes das dicas, escrevemos algumas novas indicações.

# %% [markdown]
# Use as dicas a seguir para responder à seguinte questão de múltipla escolha, usando o seguinte procedimento:
# Dicas:
#
# 1. Primeiramente, analise as dicas uma por uma e considere se a dica é potencialmente relevante ou não.
# 2. Em segundo lugar, combine as dicas relevantes para raciocinar a resposta correta a essa pergunta.
# 3. Em terceiro lugar, mapeie a resposta para uma das respostas de múltipla escolha A, B ou C, sim, não ou desconhecido.
#
# 1. A Senhorita Scarlett era a única pessoa na sala.
# 2. A pessoa com o cachimbo estava na cozinha.
# 3. O Coronel Mostarda era a única pessoa no observatório.
# 4. O Professor Plum não estava na biblioteca nem na sala de bilhar.
# 5. A pessoa com o castiçal estava no observatório.
#
# Pergunta: O Coronel Mostarda estava no observatório com o castiçal?
#
# (a) Sim, O Coronel Mostarda estava no observatório com o castiçal
# (b) Não; O Coronel Mostarda não estava no observatório com o castiçal
# (c) Desconhecido; não há informações suficientes para determinar se o Coronel Mostarda estava no observatório com o castiçal
#
# Resposta:

# %% [markdown]
# Feito isso, temos a seguinte resposta.

# %% [markdown]
# (a) Sim; O Coronel Mostarda estava no observatório com o castiçal
#
# Explicação: (1) As dicas relevantes para responder à pergunta são a dica 3 e a dica 5. A dica 3 indica que o Coronel Mostarda estava no observatório. A dica 5 indica que a pessoa com o castiçal também estava no observatório. (2) Combinando essas dicas, podemos concluir que, se o Coronel Mostarda estava no observatório e a pessoa com o castiçal também estava no observatório, então o Coronel Mostarda estava no observatório com o castiçal. (3) Portanto, a resposta correta é (a) Sim; O Coronel Mostarda estava no observatório com o castiçal.

# %% [markdown]
# Temos a resposta e explicação corretas. No primeiro teste tivemos uma resposta errada, pois a IA foi escolhendo a próxima palavra sem considerar o contexto.
#
# Só que quando pedimos para dividir essa tarefa, temos uma resposta bem 0melhor. Isso foi uma das coisas mais importantes que perceberam enquanto estavam testando esses modelos de engenharia de prompt.
#
# Temos outros pontos também relevantes que podemos considerar. Um deles é pedir para explicar os passos antes de dar a resposta, isso inclusive, estava no exemplo do detetive.
#
# Além disso, pedir para dar justificativas da resposta e gerar várias respostas diferentes e pedir para escolher a melhor ou talvez a mais frequente. Isso é algo que ainda aprenderemos com mais clareza ao longo do curso.
#
# Em breve aprenderemos as técnicas mais importantes e relevantes sobre engenharia de prompt.

# %% [markdown]
# | Personagem/Objeto | Local Confirmado | Local Excluído | Observações |
# | ----------------- | ---------------- | --------------- | ------------- |
# | Senhorita Scarlett | Sala | — | Única pessoa no local |
# | Pessoa com cachimbo | Cozinha | — | — |
# | Coronel Mostarda | Observatório | — | Única pessoa no local, com castiçal |
# | Professor Plum | — | Biblioteca, Sala de Bilhar | — |
# | Pessoa com castiçal | Observatório | — | — |

# %% [markdown]
# ### **Comunicando instruções**

# %% [markdown]
# Maria Isabel, uma engenheira de dados sênior, precisa orientar um estagiário que acabou de chegar na empresa. Ela sabe que, para se fazer entender, é preciso tomar alguns cuidados na forma como ela comunica as tarefas, principalmente as mais complexas.
#
# Esses mesmos cuidados são recomendados ao escrever comandos para uma IA generativa.
#
# Quais dos seguintes itens são importantes tanto na comunicação com o estagiário quanto na criação de prompts para uma IA generativa?
#
# a)
# Usar termos técnicos complexos para garantir precisão na comunicação.
#
# b)
# Permitir flexibilidade nas respostas, deixando espaço para interpretação.
#
# c)
# **Falar as instruções com clareza, dividir tarefas complexas em subtarefas menores, e explicar o raciocínio por trás das instruções.**
#
# Esses elementos são fundamentais para evitar mal-entendidos na comunicação e melhorar a precisão e, portanto, obter resultados mais assertivos. Clareza, explicação e divisão de tarefas complexas em tarefas menores funcionam bem tanto ao ensinar uma pessoa aprendiz quanto ao dar instruções para a IA.
#
# d)
# Incluir detalhes pessoais na explicação, criando uma relação amigável para que o estagiário fique à vontade.

# %% [markdown]
# ### **Faça como eu fiz: princípios fundamentais**

# %% [markdown]
# Nessa aula, vimos alguns princípios gerais da Engenharia de Prompt: o ato de construir cuidadosamente um comando eficaz para extrair o melhor resultado possível de uma IA generativa.
#
# Essas diretrizes são comprovadamente eficazes na melhora na qualidade das respostas. As principais delas são:
#
#  1. Ter clareza ao dar as instruções;
#
#  2. Dividir tarefas complexas em subtarefas menores;
#
# 3. Pedir para o modelo explicar seus passos antes de dar a resposta;
#
# 4. Pedir para o modelo dar justificativas de suas respostas;
#
# 5. Gerar várias respostas diferentes e pedir para o modelo escolher a melhor.
#
# **Pratique**
#
# O prompt a seguir contém as dicas do joguinho detetive e as alternativas “Sim”, “Não” e “Desconhecido”.

# %% [markdown]
# **Use as dicas a seguir para responder à seguinte questão de múltipla escolha.**
#
# **Dicas:
# 1. A Senhorita Scarlett era a única pessoa na sala.
# 2. A pessoa com o cachimbo estava na cozinha.
# 3. O Coronel Mostarda era a única pessoa no observatório.
# 4. O Professor Plum não estava na biblioteca nem na sala de bilhar.
# 5. A pessoa com o castiçal estava no observatório.**
#
# **Pergunta: O Coronel Mostarda estava no observatório com o castiçal?**
#
# **(a) Sim; O Coronel Mostarda estava no observatório com o castiçal**
#
# **(b) Não; O Coronel Mostarda não estava no observatório com o castiçal**
#
# **(c) Desconhecido, não há informações suficientes para determinar se o Coronel Mostarda estava no observatório com o castiçal**
#
# **Resposta:**

# %% [markdown]
# Teste também, em outro chat, o mesmo jogo, mas aplicando alguns princípios da engenharia de prompt

# %% [markdown]
# Use as dicas a seguir para responder à seguinte questão de múltipla escolha, usando o seguinte procedimento:
#
# (1) Primeiramente, analise as dicas uma por uma e considere se a dica é potencialmente relevante
#
# (2) Em segundo lugar, combine as dicas relevantes para raciocinar a resposta correta à pergunta
#
# (3) Em terceiro lugar, mapeie a resposta para uma das respostas de múltipla escolha: (a), (b) ou (c)
#
#
# Dicas:
# 1. A Senhorita Scarlett era a única pessoa na sala.
# 2. A pessoa com o cachimbo estava na cozinha.
# 3. O Coronel Mostarda era a única pessoa no observatório.
# 4. O Professor Plum não estava na biblioteca nem na sala de bilhar.
# 5. A pessoa com o castiçal estava no observatório.
#
# Pergunta: O Coronel Mostarda estava no observatório com o castiçal?
#
# (a) Sim; O Coronel Mostarda estava no observatório com o castiçal
#
# (b) Não; O Coronel Mostarda não estava no observatório com o castiçal
#
# (c) Desconhecido, não há informações suficientes para determinar se o Coronel Mostarda estava no observatório com o castiçal
#
# Resposta:

# %% [markdown]
# Nesse último prompt, dividimos a tarefa principal em subtarefas, e a instrução ficou mais clara, consequentemente. Compare os resultados e teste em diferentes modelos. É bacana, também, testar em tarefas do seu dia a dia que não obtiveram resultados satisfatórios anteriormente.

# %% [markdown]
# ###**Opinião do instrutor**
#
# No momento em que você está fazendo esse curso, pode ser que os modelos de linguagem atuais já estejam muito mais preparados para responder ao enigma do Coronel Mostarda, mesmo sem as especificidades das orientações do segundo prompt. Isso é ótimo!
#
# A área de IA se movimenta com muita rapidez e os modelos estão em melhoria constante. O ChatGPT 4, por exemplo, que foi lançado em 2024, tem cerca de 170 trilhões de parâmetros em seu treinamento, e já foi aperfeiçoado pelas experimentações científicas feitas com os modelos que vieram antes dele.
#
# Como comparação, o modelo 3.5 (o que foi lançado em 2022 e trouxe o assunto IA à tona), tinha 170 bilhões de parâmetros! Ou seja, o modelo 4 tem um “conhecimento” mil vezes maior que seu modelo anterior. Esse salto impressionante impacta consideravelmente na capacidade do modelo.
#
# Porém, a melhora na capacidade dos modelos não nos exime de conhecer as técnicas de engenharia de prompt, muito pelo contrário! Conforme a tecnologia avança em complexidade, é imperativo que nós, pessoas usuárias dessas tecnologias, avancemos em nossa compreensão sobre elas, também.

# %% [markdown]
# ### **O que aprendemos?**
#
# ### **Nessa aula, você aprendeu:**
#
#  - O que o termo “Engenharia de Prompt” significa;
#
#  - As principais recomendações para criar um prompt eficaz.

# %% [markdown]
# ## **Aula 03 - Few-Shot Prompt**

# %% [markdown]
# **Preparando o ambiente**

# %% [markdown]
# Na aula seguinte, utilizaremos o modelo de linguagem Sabiá, da empresa brasileira [Maritaca AI](https://). Você pode utilizar qualquer modelo que prefira para acompanhar a aula, mas, caso queira conhecer o Maritalk, a plataforma que hospeda o chat, é preciso criar uma conta.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Entendendo a técnica**

# %% [markdown]
# Vamos explorar as técnicas mais usadas e importantes na indústria para engenharia de prompt, com o objetivo de melhorar e obter respostas mais precisas. Utilizaremos o Maritalk, https://chat.maritaca.ai/auth, o chatbot da MariTalk, uma empresa brasileira.
#
# Acessando e Usando o Maritalk
# Podemos acessar o Maritalk com a nossa conta Google. Após o acesso, o uso será semelhante ao que estávamos fazendo com o ChatGPT, o Google Gemini, o Uol Chat e outros chatbots com funcionalidades similares.
#
# Utilizamos o modelo Sabiá-2 Small na parte superior esquerda e enviamos a seguinte pergunta:

# %% [markdown]
# **Um diretor de cinema já dirigiu 16 filmes. Metade dos filmes que ele dirigiu são de ação, e metade dos filmes de ação têm a participação do Nicolas Cage, e na metade deles o Nicolas Cage tem bigode. Quantos filmes de ação com a participação do Nicolas Cage com bigode ele dirigiu?**

# %% [markdown]
# Esse problema pode ser mais complexo do que parece. Quando as empresas começaram a desenvolver modelos, especialmente os mais simples, perceberam que perguntas como essa nem sempre recebiam respostas corretas. Realizaremos alguns testes para explorar como esses modelos lidam com esse tipo de questão.
#
# Enviamos o prompt e observamos que ele retornou a resposta correta:

# %% [markdown]
# Para resolver essa questão, vamos seguir uma lógica de etapas:
#
# 1. O diretor dirigiu 16 filmes.
# 2. Metade dos filmes que ele dirigiu são de ação. Isso resulta em 8 filmes de ação.
# 3. Metade dos filmes de ação têm a participação do Nicolas Cage. Isso resulta em 4 filmes com Nicolas Cage.
# 4. E metade desses filmes com Nicolas Cage tem ele com bigode. Isso resulta em 2 filmes com Nicolas Cage e bigode.
#
# Portanto, o diretor dirigiu 2 filmes de ação com a participação do Nicolas Cage e com ele usando bigode.

# %% [markdown]
# Realizaremos o teste novamente para confirmar a precisão. Iniciaremos uma nova conversa clicando em "Começar uma nova conversa" na parte superior esquerda e utilizaremos o Sabiá Small para respostas mais rápidas. Enviamos o mesmo prompt e obtemos:

# %% [markdown]
# Vamos resolver esse problema passo a passo.
#
# 1. O diretor dirigiu 16 filmes.
# 2. Metade dos filmes que ele dirigiu são de ação. Isso significa que 8 filmes são de ação.
# 3. Metade dos filmes de ação têm a participação do Nicolas Cage. Isso significa que 4 filmes de ação têm o Nicolas Cage.
# 4. Na metade dos filmes de ação com a participação do Nicolas Cage, ele tem bigode. Isso não é especificado, então vamos assumir que é verdadeiro por enquanto (ou seja, 2 filmes).
#
# Agora, vamos verificar as afirmações:
#
# - 4 filmes são de ação e têm a participação do Nicolas Cage.
# - 2 filmes são de ação, têm a participação do Nicolas Cage e ele tem bigode.
#
# Portanto, o diretor dirigiu 2 filmes de ação com a participação do Nicolas Cage e com ele usando bigode.*

# %% [markdown]
# Retornou a resposta correta e realizamos o teste mais uma vez.
#
# **Conceito de Zero-Shot Prompting**
#
# Esse tipo de teste é conhecido como Zero-Shot Prompting, em que enviamos a pergunta sem ensinar nada.
#
# *Prompting é o ato de criar e enviar um prompt. No caso de zero shot, "zero" se refere a não fornecer exemplos ou amostras, enquanto "shot" significa exemplo ou amostra. Portanto, zero shot é uma técnica onde o prompt é dado sem exemplos prévios.*
#
# **Exemplos de prompt zero-shot**
#
# No zero-shot prompting, fazemos uma pergunta direta sem fornecer exemplos. Por exemplo, ao perguntar "Quem criou o modelo ChatGPT?", esperamos que o modelo responda corretamente que "O modelo ChatGPT foi criado por cientistas da OpenAI."
#
# Se pedirmos "Crie um post no Instagram sobre IA", o modelo começa a criar o post sem ter recebido exemplos prévios. Isso caracteriza o zero shot prompting: criamos um prompt sem amostras ou exemplos, apenas fazendo o pedido e esperando a resposta.
#
# **Introdução ao Few-Shot Prompting**
#
# As empresas desenvolveram uma técnica mais eficaz chamada Few-Shot Prompting ("Prompting com poucos exemplos"). O termo Few-Shot se refere a fornecer poucos exemplos ou amostras. Few significa poucos ou alguns, e Shot refere-se a exemplos ou amostras.
#
# Para ilustrar essa técnica, usaremos o mesmo exemplo do Nicolas Cage. O objetivo é alinhar o modelo com o tipo de resposta desejada, fornecendo exemplos que direcionem o modelo para o caminho correto. Isso ajuda a melhorar a precisão das respostas em comparação com o zero shot prompting.
#
# O problema com o Nicolas Cage é essencialmente um problema matemático. Estamos solicitando cálculos que envolvem dividir valores sucessivamente. Modelos antigos, e até alguns modelos mais recentes, podem ter dificuldades em resolver problemas desse tipo com precisão.
#
# Para aplicar o Few-Shot Prompting, fornecemos um exemplo de um problema na mesma área de conhecimento, neste caso, matemática. Isso ajuda a direcionar o modelo e orientá-lo na direção correta, ajustando suas redes neurais para entender melhor o tipo de resposta desejada. Por exemplo:

# %% [markdown]
# Pergunta: João tem 10 bolas. Metade delas são azuis e metade são vermelhas. Quantas bolas vermelhas o João tem?
#
# Resposta: A resposta é 5.
#
# Pergunta: Um diretor de cinema já dirigiu 16 filmes. Metade dos filmes que ele dirigiu são de ação, e metade dos filmes de ação têm a participação do Nicolas Cage, e na metade deles o Nicolas Cage tem bigode. Quantos filmes de ação com a participação do Nicolas Cage com bigode ele dirigiu?

# %% [markdown]
# Esse exemplo ajuda a orientar o modelo a seguir a abordagem correta. Em seguida, apresentamos a nossa pergunta real, que é a do Nicolas Cage, exatamente como vimos anteriormente. Isso ajusta o modelo para fornecer a resposta desejada com base no exemplo fornecido.
#
# Após fornecer o exemplo matemático, podemos adicionar a nossa pergunta real com a indicação "resposta:" e solicitar que o modelo a resolva.

# %% [markdown]
# Pergunta: João tem 10 bolas. Metade delas são azuis e metade são vermelhas. Quantas bolas vermelhas o João tem?
#
# Resposta: A resposta é 5.
#
# Pergunta: Um diretor de cinema já dirigiu 16 filmes. Metade dos filmes que ele dirigiu são de ação, e metade dos filmes de ação têm a participação do Nicolas Cage, e na metade deles o Nicolas Cage tem bigode. Quantos filmes de ação com a participação do Nicolas Cage com bigode ele dirigiu?
#
# Resposta:

# %% [markdown]
# Com isso, o modelo deve fornecer a resposta correta, que é "o diretor dirigiu dois filmes com a participação de Nicolas Cage e com bigode."

# %% [markdown]
# O diretor dirigiu 4 filmes de ação com a participação do Nicolas Cage com bigode. Vamos detalhar o raciocínio:
#
# 1. O diretor dirigiu 16 filmes no total.
# 2. Metade desses filmes são de ação (8 filmes de ação).
# 3. Metade dos filmes de ação têm a participação do Nicolas Cage (4 filmes com o Nicolas Cage).
# 4. Desses filmes com o Nicolas Cage, metade tem o Nicolas Cage com bigode (2 filmes com o Nicolas Cage e bigode).
#
# Portanto, o diretor dirigiu 2 filmes com a participação do Nicolas Cage e com ele tendo bigode.

# %% [markdown]
# Em nosso caso, o modelo já forneceu a resposta correta de 2 no zero shot prompting, mas, como os modelos têm se aprimorado, a precisão pode variar. Em casos mais complexos ou diferentes, o Few Shot Prompting pode oferecer melhores resultados ao fornecer exemplos relevantes para guiar o modelo de forma mais eficaz.
#
# Voltando ao exemplo mais recente, mostramos a nossa pergunta e a resposta simples, seguida da pergunta real e sua resposta. Em outros sites e modelos, a apresentação pode ser um pouco mais clara.
#
# A ideia do Few Shot Prompting é fornecer exemplos para direcionar o modelo na direção correta. No nosso exemplo, demos apenas um exemplo, mas em contextos diferentes, como outros campos além da matemática, poderíamos fornecer mais exemplos para melhorar a precisão das respostas.
#
# **Próximo passo**
#
# Na próxima aula, exploraremos como usar múltiplos exemplos, ou shots, para otimizar ainda mais os resultados.

# %% [markdown]
# ### **Mais exemplos**

# %% [markdown]
# Vamos continuar com nossos exemplos de Few-Shot Prompting e trabalhar com o chat da Mistral.
#
# **Testando Few-Shot Prompting em diversas áreas do conhecimento**
#
# Consideremos o seguinte prompt inicial:

# %% [markdown]
# *Pergunta: Havia 23 maçãs no refeitório. Se foram usadas 20 para fazer o almoço e foram compradas mais 6, quantas maçãs eles têm agora?*

# %% [markdown]
# Havia 23 maçãs, usaram 20, sobraram 3, e compraram mais 6, então o total é 9 maçãs. Vamos testar isso no modelo para verificar a resposta. O modelo deve responder: "Agora eles têm 9 maçãs".
#
# Como é um problema simples, é provável que o modelo acerte com frequência. Vamos testar novamente. A resposta é: "9 maçãs". O modelo está fornecendo a resposta correta consistentemente.
#
# Como podemos utilizar a engenharia de prompt para um modelo com o conceito de Few-Shot? Vamos criar um novo exemplo e fazer o prompting manualmente.

# %% [markdown]
# *Pergunta: O Rogério tem 5 bolas de tênis. Ele compra mais 2 caixas de bolas, cada uma com 3 bolas. Quantas bolas de tênis ele tem agora?*

# %% [markdown]
# Esse exemplo ilustra como estamos ensinando o modelo a pensar e a direcioná-lo para o caminho correto. A resposta que desejamos é calculada da seguinte forma: se ele tinha 5 e compra mais 2 caixas, cada uma com 3 itens, no total são 6 itens adicionais. Somando os 5 iniciais, ele terá 11 bolas de tênis.

# %% [markdown]
# *Pergunta: O Rogério tem 5 bolas de tênis. Ele compra mais 2 caixas de bolas, cada uma com 3 bolas. Quantas bolas de tênis ele tem agora?*
#
# *Resposta: Ele tem 11 bolas de tênis.*

# %% [markdown]
# Estamos fornecendo essas informações ao modelo.
#
# Aplicamos a mesma lógica para a nossa pergunta sobre as maçãs do refeitório. Podemos deixar a resposta em branco e verificar como o modelo responde.

# %% [markdown]
# Pergunta: O Rogério tem 5 bolas de tênis. Ele compra mais 2 caixas de bolas, cada uma com 3 bolas. Quantas bolas de tênis ele tem agora?
#
# Resposta: Ele tem 11 bolas de tênis.
#
# Pergunta: Havia 23 maçãs no refeitório. Se foram usadas 20 para fazer o almoço e foram compradas mais 6, quantas maçãs eles têm agora?
#
# Resposta:

# %% [markdown]
# Enviamos o prompt e obtemos "Eles têm 9 maçãs agora", isso está correto.
#
# Revisando o conceito apresentado no último vídeo, aplicamos o conceito de matemática, que foi o foco principal. Agora, vamos testar o mesmo conceito de Few-Shot Prompting em uma área diferente do conhecimento.
#
# **Análise de sentimentos**
#
# Vamos considerar um cenário em que desejamos realizar uma análise de sentimentos. Suponha que estamos na página do Instagram, onde há vários comentários sobre um filme ou uma série.
#
# Para determinar se os comentários expressam sentimentos positivos ou negativos, precisamos categorizar cada um. Por exemplo, se encontramos o comentário "Esse filme foi terrível", desejamos classificá-lo como negativo.
#
# Se o comentário for "Esse é o meu filme favorito agora", a classificação será positiva. Por outro lado, um comentário como "Esse é o pior filme que eu já vi" também deve ser classificado como negativo.

# %% [markdown]
# "Esse filme foi terrível"
# - Negativo.
#
# "Esse filme é o meu filme favorito agora!"
# - Positivo
#
# "Esse é o pior filme que eu já vi!"
# - Negativo

# %% [markdown]
# Esses exemplos são usados no método few-shot prompting. Nesse método, fornecemos exemplos de como classificar sentimentos para orientar o modelo. Com base nesses exemplos, o modelo aprende a categorizar novos comentários como positivos ou negativos.
#
# Vamos considerar um novo comentário na nossa página de Instagram: "Esse filme foi bacana".

# %% [markdown]
# "Esse filme foi terrível"
# - Negativo.
#
# "Esse filme é o meu filme favorito agora!"
# - Positivo
#
# "Esse é o pior filme que eu já vi!"
# - Negativo
#
# "Esse filme foi bacana"
# -

# %% [markdown]
# O objetivo é verificar como o modelo responde com base no que ensinamos.
#
# Se utilizarmos os exemplos fornecidos anteriormente, esperamos que o modelo classifique "bacana" como um sentimento positivo. Ao rodar o modelo, obtemos a resposta "positivo", que é exatamente o que desejamos.
#
# Ensinar o modelo consiste em fornecer exemplos de respostas, como "negativo" e "positivo". Com esses exemplos, o modelo aprende a classificar novos comentários com a mesma lógica. Neste caso, o modelo reconheceu que "bacana" indica um sentimento positivo e respondeu de acordo com o padrão estabelecido.
#
# Note que, inicialmente, usamos um ponto no primeiro exemplo e não usamos nos demais. Mesmo assim, o modelo manteve a consistência e respondeu corretamente.

# %% [markdown]
# Ao remover o ponto do "Negativo", o modelo continuou a fornecer a resposta correta e até ofereceu exemplos adicionais, como "Esse filme não vale a pena assistir".

# %% [markdown]
# Positivo
#
# "Esse filme foi muito interessante"
# - Positivo
#
# "Esse filme não vale a pena assistir"
# - Negativo
#
# "Esse filme é uma obra-prima"
# - Positivo
#
# "Esse filme é um desperdício de tempo"
# - Negativo

# %% [markdown]
# Isso indica que o modelo compreendeu bem a tarefa e produziu a resposta desejada para a análise de sentimentos.
#
# **Tradução de idiomas**
#
# Vamos explorar um exemplo na área de tradução de idiomas usando few-shot prompting:

# %% [markdown]
# Inglês: Hello, how are you?
# Francês: Bonjour, comment ça va?
#
# Inglês: I am learning to speak French.
# Francês: J'apprends à parler français.
#
# Inglês: The weather is very nice today.

# %% [markdown]
# Suponha que você tenha uma frase em inglês: "Hello, how are you?" e deseja traduzi-la para o francês. O objetivo é que o modelo forneça a tradução correta, que é "Bonjour, comment ça va?".
#
# Para treinar o modelo com few-shot prompting, fornecemos exemplos de tradução, como este:
#
#  - Inglês: "Hello, how are you?"
#
#  - Francês: "Bonjour, comment ça va?"
#
# Dessa forma, ao introduzirmos novas frases em inglês, o modelo deve conseguir traduzir para o francês com base nos exemplos fornecidos.
#
# Enviamos o prompt e obtemos "Francês: Le temps est très beau aujourd'hui.".
#
# O processo é o seguinte: o modelo recebe a frase em inglês e, com base nos exemplos dados, gera a tradução em francês. Assim, para qualquer nova frase em inglês, o modelo utilizará o padrão aprendido para fornecer a tradução correta.
#
# **Conclusão e próximo passo**
#
# Esses três exemplos ilustram bem o conceito de Few-Shot Prompting em diferentes contextos. O primeiro exemplo aborda a análise de sentimentose e o segundo a tradução de frases entre idiomas.
#
# O Few-Shot Prompting mais puro, como vimos, é menos comum atualmente, mas serve para demonstrar a ideia básica de fornecer exemplos para orientar o modelo. Na próxima aula, exploraremos uma abordagem mais avançada e amplamente utilizada do Few-Shot Prompting, que oferece mais poder e flexibilidade.

# %% [markdown]
# ### **Para saber mais: Few-Shot vs Zero-Shot**

# %% [markdown]
# Em 2020, cientistas da OpenAI publicaram um artigo chamado Language Models are Few-Shot Learners, ou seja: modelos de linguagem aprendem com alguns exemplos.
#
# Esse artigo descreve as técnicas de aprendizado de máquina utilizadas no treinamento do modelo de linguagem de grande porte GPT-3. O artigo relata como foi observado que o modelo já treinado em uma grande quantidade de texto pode demonstrar melhores resultados em tarefas específicas após passar por um “refinamento” no treinamento, focado nessas tarefas.
#
# Desde então, o GPT evoluiu e tem se desempenhado cada vez melhor em uma diversidade de tarefas, e a técnica de few-shot learning se expandiu para os prompts enviados por pessoas usuárias do ChatGPT e de outros modelos de linguagem em geral.
#
# Com essa técnica, utilizamos, de maneira indireta, alguns dos pilares do aprendizado de máquina que foram empregados no treinamento desses LLMs. Como:
#
#  - **Aprendizado por exemplos.** O modelo, inicialmente, aprende a reconhecer padrões e estruturas a partir de uma grande quantidade de exemplos. Quando o prompt contém exemplos, o modelo utiliza desse aprendizado anterior para inferir padrões e lógica necessárias.
#
#  - **Memorização e Generalização:** A técnica few-shot prompting se baseia na capacidade que o modelo tem de memorizar padrões e, então, generalizar esses padrões para outras situações.
#
#  - **Previsão sequencial:** Os modelos são treinados para prever a próxima palavra de uma sequência. Os exemplos no prompt ajudam o modelo a prever de maneira mais precisa em tarefas específicas.
#
# Isso nos leva a considerar que, mesmo com incontáveis benefícios na utilização de few-shot prompting na precisão da resposta do modelo, pode ser que não seja a técnica mais adequada a todas as situações. Além disso, é notável que comandos com zero-shot são melhores “compreendidos” em modelos mais evoluídos, como o GPT-4, devido ao seu treinamento mais abrangente.
#
# *Se quiser saber mais sobre as diferenças entre o* [GPT-3 e o GPT-4, confira o artigo GPT-3 e GPT-4: o que é, diferenças e como a inteligência artificial pode te ajudar.](https://)
#
# Compreender essas diferenças é crucial para decidir como e quando aplicar as técnicas de few-shot prompting e zero-shot prompting de forma eficaz. A seguir, observe em quais situações cada abordagem é mais adequada.
#
# **Quando utilizar Few-Shot Prompting**
#
#  - Quando a tarefa requer alta precisão;
#
#  - Geração de textos com um formato definido;
#
#  - Em categorizações onde há muita variedade;
#
#  - Tarefas com regras complexas.
#
# **Quando utilizar Zero-Shot Prompting**
#
#  - Exploração inicial de novas tarefas, que ainda não dispõem de exemplos;
#
#  - Quando você quer que o modelo generalize;
#
#  - Em tarefas simples e bem definidas, como categorização de spams óbvios, por exemplo;
#
#  - Situações que exigem respostas rápidas em detrimento de precisão;
#
#  - Quando fornecer exemplos específicos pode introduzir viés indesejado.
#
# Escolher a técnica apropriada pode melhorar significativamente a qualidade das respostas geradas e a eficiência na realização de diversas tarefas. Enquanto o few-shot prompting permite um ajuste mais fino e preciso ao fornecer exemplos específicos, o zero-shot prompting é valioso para tarefas gerais e quando a flexibilidade é necessária.

# %% [markdown]
# **Escolhendo técnicas**
#
# Harri está planejando abrir sua padaria e, como ele quer ter tempo para desenvolver receitas e criar relações saudáveis com sua equipe, está se dedicando a automatizar alguns processos simples, mas que tomam bastante tempo no dia a dia. Ele está explorando como usar modelos de linguagem para ajudar a categorizar os e-mails que recebe como “encomendas”, “feedbacks”, “fornecedores”, “promoções” e “geral”.
#
# **Qual abordagem é mais apropriada para fazer a categorização automática dos e-mails?**
#
# a)
# Fornecer exemplos de e-mails que não se encaixam claramente em nenhuma das categorias e pedir ao modelo para classificá-los nas categorias existentes.
#
# b)
# Fornecer exemplos para apenas uma das categorias, e deixar que o modelo decida sobre o restante.
#
# c)
# Utilizar zero-shot prompting e apenas fornecer ao modelo uma instrução como “categorize os feedbacks em categorias”.
#
# d)
# **Utilizar few-shot prompting e fornecer exemplos específicos para cada uma das categorias desejadas.**
#
# Fornecer exemplos específicos para cada categoria ajuda o modelo a entender melhor as características de cada tipo de e-mail, aumentando a precisão da categorização.

# %% [markdown]
# **Faça como eu fiz: comandos com exemplos**
#
# Nessa aula, conhecemos os conceitos de zero-shot, one-shot e few-shot prompting.
#
#  - **Zero-shot prompting:** apenas o comando, sem nenhum exemplo;
#
#  - **One-shot prompting:** quando há um exemplo do comportamento esperado do modelo, além do comando;
#
#  - **Few-shot prompting:** quando há dois ou mais exemplos do comportamento esperado do modelo, além do comando.
#
# Enviar um ou mais exemplos orienta o modelo a como gerar a resposta, e é muito mais eficaz do que uma descrição detalhada do formato. Além disso, os exemplos também indicam com qual área de conhecimento estamos trabalhando, seja matemática, tradução, análise de sentimento, etc.
#
# **Observe, em seu dia a dia de trabalho ou estudos, alguma situação que exige um padrão e se beneficiaria do uso da Inteligência Artificial.**
#
# Se preferir, você também pode testar com os mesmos exemplos que foram trabalhados em aula!
#
# **Problema de matemática**

# %% [markdown]
# Pergunta: João tem 10 bolas. Metade delas são azuis e metade são vermelhas. Quantas bolas vermelhas o João tem?
#
# Resposta: A resposta é 5.
#
# Pergunta: Um diretor de cinema já dirigiu 16 filmes. Metade dos filmes que ele dirigiu são de ação, e metade dos filmes de ação têm a participação do Nicolas Cage, e na metade deles o Nicolas Cage tem bigode. Quantos filmes de ação com a participação do Nicolas Cage com bigode ele dirigiu?
#
# Resposta:

# %% [markdown]
# ### **Outro problema de matemática**

# %% [markdown]
# Pergunta: Roger tem 5 bolas de tênis. Ele compra mais 2 latas de bolas de tênis. Cada lata contém 3 bolas de tênis. Quantas bolas de tênis ele tem agora?
#
# Resposta: A resposta é 11.
#
# Pergunta: Havia 23 maçãs no refeitório. Se foram usadas 20 para fazer o almoço e foram compradas mais 6, quantas maçãs eles têm agora?
#
# Resposta:

# %% [markdown]
# ### **Análise de sentimentos**

# %% [markdown]
# "Esse filme foi terrível"
# - Negativo
#
# "Esse filme é o meu filme favorito agora!"
# - Positivo
#
# "Esse é o pior filme que eu já vi!
# -Negativo
#
# "Esse filme foi bacana"
# -

# %% [markdown]
# ### **Tradução**

# %% [markdown]
# Inglês: Hello, how are you?
#
# Francês: Bonjour, comment ça va?
#
# Inglês: I am learning to speak French.
#
# Francês. J'apprends à parler français.
#
# Ingles: The weather is very nice today.

# %% [markdown]
# ### **Opinião do instrutor**
#
# Uma das vantagens mais bacanas da técnica few-shot prompting é a possibilidade de manter um estilo.
#
# Se você gosta de escrever textos para um blog, por exemplo, mas tem dificuldade em escolher títulos, pode mostrar ao modelo alguns textos que já escreveu com os títulos que mais gostou. O modelo entenderá o padrão e dará sugestões que seguem o seu jeitinho.
#
# Outra aplicação interessante é a reescrita de textos em diferentes estilos, para comunicar o mesmo assunto para públicos diversos. Apenas instruir ao modelo para que reescreva um texto com uma linguagem informal, geralmente, não tem resultados tão naturais. Porém, com exemplos de qualidade, essa tarefa pode ter uma grande assistência.

# %% [markdown]
# ### **O que aprendemos?**

# %% [markdown]
# **Explique com suas próprias palavras os principais conceitos que você aprendeu nesta aula.**

# %% [markdown]
# Você abordou os conceitos de zero-shot e few-shot prompting, o que é ótimo. Também vimos que o **zero-shot prompting** é uma técnica onde o modelo é solicitado a gerar uma resposta sem nenhum exemplo prévio. Já o **few-shot prompting** envolve fornecer alguns exemplos ao modelo para guiá-lo na geração da resposta desejada.

# %% [markdown]
# ### **Aula 04 - Chain-of-Thought Prompt**

# %% [markdown]
# **Preparando o ambiente**

# %% [markdown]
# Na aula seguinte, utilizaremos o modelo de linguagem Gemini, do Google. Você pode utilizar qualquer modelo que prefira para acompanhar a aula, mas, [caso queira conhecer o Gemini](https://), basta estar logado em uma conta Gmail.
#
# Clique em “fazer login” para acessar a tela de login e inserir seu e-mail Google ou criar uma nova conta.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Entendendo a técnica**

# %% [markdown]
# Como mencionado anteriormente, vamos nos aprofundar no conceito de Few-Shot Prompting, criando prompts e analisando alguns exemplos.
#
# **Melhorando o exemplo**
#
# Na última aula, estávamos no Le Chat e utilizamos o exemplo do Rogério, onde fornecemos nosso Few-Shot, que neste caso é um único exemplo, o One Shot. Indicamos que a questão estava relacionada à matemática e fizemos nossa pergunta, esperando uma resposta. O modelo forneceu a resposta esperada, mas percebemos que havia espaço para melhorias. Então, vamos tentar aprimorar isso.
#
# Vamos abrir um novo chat no Le Chat, copiar o mesmo exemplo, mas, em vez de fornecer uma resposta básica, queremos pensar como se fôssemos profissionais seniores, professores ou professoras, ensinando o modelo a raciocinar da seguinte forma: se Rogério inicialmente tinha 5 bolas de tênis e comprou 2 caixas, cada uma contendo 3 bolas, isso significa que ele adquiriu mais seis 6. Portanto, no total, ele agora possui 5 + 6, resultando em 11 bolas de tênis.

# %% [markdown]
# Pergunta: O Rogério tem 5 bolas de tênis. Ele compra mais 2 caixas de bolas, cada uma com 3 bolas. Quantas bolas de tênis ele tem agora?
#
# Resposta: O Rogério inicialmente tinha 5 bolas de tênis. Se cada caixa tem 3 bolas e ele comprou 2 caixas, isso significa que ele comprou mais 6 bolas. Ou seja, no total agora ele tem 5 + 6, que resulta em 11 bolas de tênis.
#
# Pergunta: Havia 23 maçãs no refeitório. Se foram usadas 20 para fazer o almoço e foram compradas mais 6, quantas maçãs eles têm agora?
#
# Resposta:

# %% [markdown]
# Dessa forma, estamos, literalmente, ensinando o modelo a raciocinar, não apenas fornecendo uma resposta direta.
#
# Dentro do nosso exemplo de Few-Shot, fornecemos essa informação antes de fazer a pergunta desejada. Em seguida, podemos formular a pergunta normalmente, que neste caso é sobre as maçãs no refeitório, uma questão matemática. Vamos executar isso e observar como o modelo responde.
#
# *No início, havia 23 maçãs. Se foram usadas 20 para fazer o almoço, sobraram 23-20 = 3 maçãs. Como foram compradas mais 6 maçās, agora eles têm 3 + 6 = 9 maçãs no total.*
#
# **Chain of Thought**
#
# Em vez de simplesmente fornecer a resposta, como fez anteriormente, o modelo agora raciocina: inicialmente havia 23 maçãs, e se 20 foram usadas para o almoço, restam 23 - 20, ou seja, 3 maçãs. Como foram compradas mais 6 maçās, agora eles têm 3 + 6 = 9 maçãs no total.
#
# Assim, ele começa a realizar pequenos passos de raciocínio, dividindo o problema, que é um dos principais passos mencionados para criar um prompt ideal.
#
# Essa técnica é chamada de Chain of Thought (Cadeia de Pensamento).
#
# Inclusive, existe um artigo publicado pelas equipes do Google Research e do Google Brain, atualmente conhecido como DeepMind. Você pode acessá-lo pelo seguinte link: [Chain-of-Thought Prompting Elicits Reasoning in Large Language Models](https://).
#
# Eles perceberam que, muitas vezes, quando apenas forneciam a resposta, o modelo chegava a uma conclusão errada. No entanto, ao explicar o processo e utilizar essa cadeia de pensamento, o Chain of Thought, junto com o modelo, o modelo começava a raciocinar, em vez de apenas fornecer a resposta diretamente, resultando em respostas muito mais precisas.
#
# Eles afirmam que houve uma grande melhoria, alcançando uma resposta de estado da arte, ou seja, a melhor possível na época em que estavam testando com modelos mais antigos, como o GPT-3. Mesmo hoje, com modelos muito mais avançados, como o GPT-4 Omni, o Google Gemini e outros, o método de Few-Shot combinado com o Chain of Thought continua sendo um dos mais poderosos.

# %% [markdown]
# ### Outro exemplo

# %% [markdown]
# Neste último exemplo de Few-Shot utilizando a cadeia de pensamento (Chain of Thought) vamos propor um problema matemático um pouco mais complexo!
#
# **Apresentação do problema**
#
# Imagine que temos um país chamado Carraristão, onde calculamos a alíquota de imposto de renda das pessoas. Sabemos que o assunto pode ser um pouco tedioso, mas trata-se basicamente de um problema matemático.
#
# Temos os nomes dos habitantes do Carraristão e o rendimento anual que eles declararam no imposto de renda.

# %%
import pandas as pd

dados = {
    'Indivíduo': [
        'Juliana da Silva Santos',
        'Pedro Henrique Souza Lima',
        'Marcelo Pereira Costa',
        'Amanda Ferreira Oliveira',
        'José Carlos Almeida Silva',
        'Isabella Santos Alves',
        'Cleiton Moreira Cardoso',
        'Larissa Oliveira Alves',
        'Túlio de Oliveira Ribeiro',
        'Thaís da Conceição Cunha'
    ],
    'Rendimento anual': [
        'R$31.000,00',
        'R$15.000,00',
        'R$52.000,00',
        'R$103.000,00',
        'R$42.000,00',
        'R$156.000,00',
        'R$15.000,00',
        'R$27.000,00',
        'R$82.000,00',
        'R$33.000,00'
    ]
}

df = pd.DataFrame(dados)
print(df)**
# Out:
#                    Indivíduo Rendimento anual
# 0    Juliana da Silva Santos      R$31.000,00
# 1  Pedro Henrique Souza Lima      R$15.000,00
# 2      Marcelo Pereira Costa      R$52.000,00
# 3   Amanda Ferreira Oliveira     R$103.000,00
# 4  José Carlos Almeida Silva      R$42.000,00
# 5      Isabella Santos Alves     R$156.000,00
# 6    Cleiton Moreira Cardoso      R$15.000,00
# 7     Larissa Oliveira Alves      R$27.000,00
# 8  Túlio de Oliveira Ribeiro      R$82.000,00
# 9   Thaís da Conceição Cunha      R$33.000,00

# %% [markdown]
# Estamos utilizando números, mas poderíamos usar outras informações, como faixas etárias, se a pessoa é aposentada, trabalhadora ou criança. Independentemente disso, estamos usando este exemplo mais matemático.
#
# No nosso país hipotético, temos apenas uma alíquota de imposto de renda fixa, sempre de 30%. Não há variação por faixa de rendimento; para simplificar, vamos considerar que é sempre 30%. No entanto, se a pessoa ganha menos de R$ 40 mil, ela é isenta e não paga nada. Se ela ganhar R$ 40 mil ou mais, então pagará sempre essa alíquota fixa de 30% sobre o rendimento anual.
#
# Por exemplo, se uma pessoa ganha R$ 100 mil, ela pagará exatamente R$ 30 mil de imposto de renda, ficando com R$ 70 mil para si.
#
# **Estrutura do exemplo Few-Shot com Chain of Thought**
#
# Vamos abrir novamente o Chat GPT e ensiná-lo a pensar, começando com um exemplo. Primeiramente, vamos fornecer nosso Few-Shot, que deve ser um exemplo da mesma área de pensamento. Podemos até utilizar o mesmo exemplo, com a mesma pergunta, mas oferecendo uma resposta para um caso mais simples. Vamos tentar isso.
#
# Analisando o problema que temos aqui, precisamos identificar as pessoas que ganham mais de R$ 40 mil em nossa tabela.
#
# Se a alíquota é de 30% para todos e queremos apenas o valor final, não o valor individual para cada pessoa, podemos simplificar dizendo: some o valor de todas as pessoas que ganham mais de R$ 40 mil e aplique 30%.

# %% [markdown]
# Para complementar nosso prompt, podemos incluir alguns exemplos de valores:

# %% [markdown]
# Pergunta: Tenho uma lista de valores. O meu resultado final será 30% da soma desses valores. Porém, nem todos os valores serão somados, apenas aqueles acima de R$40.000,00.
#
# Para a lista abaixo, conte quantos valores existem acima de R$40.000,00, quais são eles, faça a soma desses valores e, no fim, calcule o valor de 30% dessa soma.
#
# R$10.000,00
#
# R$20.000,00
#
# R$50.000,00
#
# R$60.000,00

# %% [markdown]
# Somando R$ 50 mil e R$ 60 mil, obtemos R$ 110 mil.
#
# Adicionando R$ 10 mil, temos R$ 120 mil. Com mais R$ 20 mil, totaliza R$ 140 mil. No entanto, estamos interessados apenas nos valores acima de R$ 40 mil, que somam R$ 110 mil. Utilizando a calculadora, calculamos que 30% de R$ 110 mil é R$ 33 mil.
#
# Agora, vamos fornecer a cadeia de pensamento, ensinando o modelo exatamente como queremos que ele responda. A resposta correta, conforme discutido, será apresentada em formato de texto para o modelo.

# %% [markdown]
# Pergunta: Tenho uma lista de valores.
# O meu resultado final será 30% da soma desses valores.
#
# Porém, nem todos os valores serão somados, apenas aqueles acima de R$40.000,00.
#
# Para a lista abaixo, conte quantos valores existem acima de R$40.000,00, quais são eles, faça a soma desses valores e, no fim, calcule o valor de 30% dessa soma.
#
# R$10.000,00
#
# R$20.000,00
#
# R$50.000,00
#
# R$60.000,00
#
# Resposta: Nessa lista, existem 4 valores.
#
# Há 2 valores acima de R$40.000,00, que são R$50.000,00 e R$60.000,00.
#
# A soma desses valores é R$110.000,00. O resultado final é 30% desse
#
# valor, portanto, 30% de R$110.000,00, que resulta em R$33.000,00.

# %% [markdown]
# Esta é a nossa cadeia de pensamento: fizemos a pergunta no contexto, fornecemos um exemplo com números fictícios e ensinamos o modelo a pensar, utilizando a técnica de Chain of Thought (Cadeia de Pensamento).
#
# Em nosso problema real, que envolve a lista de pessoas com seus respectivos valores, temos 10 indivíduos, dos quais 5 ganham mais de R$ 40 mil e 5 ganham menos. Além disso, temos a seguinte tabela com os valores para a conferência do resultado que devemos obter:

# %% [markdown]
# | *Descrição* | *Valores para conferência com resultado do Gemini* | *Valores para conferência com resultado da Inteligência Artificial* |
# | --------------- | ----------------------------------------------------- | ----------------------------------------------------------------------- |
# | Total de indivíduos | 10 | 10 |
# | Total de indivíduos com rendimentos >40.000 | 5 | 5 |
# | Imposto a ser arrecadado | R$130.500,00 | R$556.000,00 R$435.000,00 |

# %% [markdown]
# A soma total dos rendimentos é R$ 556 mil, mas a soma apenas dos rendimentos acima de R$ 40 mil deve ser R$ 435 mil. O imposto a ser arrecadado, que é 30% desse valor, deve ser R$ 130.500,00.
#
# Para resolver isso, utilizaremos a mesmo pergunta, pois se tratada exatamente do mesmo problema. Como já fornecemos a pergunta, a resposta e exemplos aleatórios, agora basta utilizarmos os valores reais em vez dos valores aleatórios.
#
# Sendo assim, podemos replicar a perguntar anterior utilizando os valores reaisi e deixar o campo "Resposta" vazio. O modelo entenderá que queremos que ele forneça a resposta seguindo o mesmo padrão que ensinamos anteriormente.

# %% [markdown]
# Pergunta: Tenho uma lista de valores. O meu resultado final será 30% da soma desses valores. Porém, nem todos os valores serão somados, apenas aqueles acima de R$40.000,00.
#
# Para a lista abaixo, conte quantos valores existem acima de R$40.000,00, quais são eles, faça a soma desses valores e, no fim, calcule o valor de 30% dessa soma.
#
# R$10.000,00
#
# R$20.000,00
#
# R$50.000,00
#
# R$60.000,00
#
# Resposta: Nessa lista, existem 4 valores.
#
# Há 2 valores acima de R$40.000,00, que são R$50.000,00 e R$60.000,00.
#
# A soma desses valores é R$110.000,00. O resultado final é 30% desse valor, portanto, 30% de R$110.000,00, que resulta em R$33.000,00.
#
# Pergunta: Tenho uma lista de valores.
#
# O meu resultado final será 30% da soma desses valores.
#
# Porém, nem todos os valores serão somados, apenas aqueles acima de R$40.000,00.
#
# Para a lista abaixo, conte quantos valores existem acima de R$40.000,00, quais são eles, faça a soma desses valores e, no fim, calcule o valor de 30% dessa soma.
#
# R$31.000,00
#
# R$15.000,00
#
# R$52.000,00
#
# R$103.000,00
#
# R$42.000,00
#
# R$156.000,00
#
# R$15.000,00
#
# R$27.000,00
#
# R$82.000,00
#
# R$33.000,00
#
# Resposta:

# %% [markdown]
# Vamos executar e ver como o GPT responde.
#
# **Analisando a resposta**
#
# Perceba que ele começará a listar os valores, somar os rendimentos acima de R$ 40 mil e fornecer a resposta final, seguindo exatamente o padrão que pedimos.

# %% [markdown]
# Para resolver essa questão, vamos seguir o mesmo procedimento descrito no exemplo.
#
# Primeiramente, identificaremos os valores acima de R$40.000,00, em seguida faremos a soma desses valores e, por fim, calcularemos 30% dessa soma.
#
# 1. Contar quantos valores existem acima de R$40.000,00.
#
# 2. Listar quais são esses valores.
#
# 3. Fazer a soma desses valores.
#
# 4. Calcular 30% dessa soma.
#
# Vamos aos cálculos:
#
# Lista de valores:
#
# R$31.000,00
#
# R$15.000,00
#
# R$52.000,00
#
# R$103.000,00
#
# R$42.000,00
#
# R$156.000,00
#
# R$15.000,00
#
# R$27.000,00
#
# R$82.000,00
#
# R$33.000,00
#
# Valores acima de R$  40.000,00:
#
# R$52.000,00
#
# R$103.000,00
#
# R$42.000,00
#
# R$156.000,00
#
# R$82.000,00
#
# Quantidade de valores acima de R$40.000,00: 5
#
# Soma dos valores acima de R$40.000,00:
#
# 52.000+ 103.000 + 42.000+156.000+82.000 = 435.000
#
# 30% dessa soma: 435.000 x 0.30 = 130.500
#
# Portanto, a resposta é:
#
# Nessa lista, existem 10 valores.
#
# Há 5 valores acima de R$40.000,00, que são R$52.000,00, R$103.000,00, R$42.000,00, R$156.000,00 e R$82.000,00.
#
# A soma desses valores é R$435.000,00.
#
# Ο resultado final é 30% desse valor, portanto, 30% de R$435.000,00, que resulta em R$130.500,00.
#
# O resultado foi R$ 130.500,00, exatamente o que esperávamos. Portanto, conseguimos ensinar o modelo a pensar, a seguir um padrão e a responder exatamente no mesmo formato e vocabulário que fornecemos como exemplo.
#
# **Considerações finais**
#
# Veja como é poderosa essa técnica de Few-Shot combinada com o Chain of Thought (Cadeia de Pensamento).
#
# Provavelmente, essa será a técnica que vocês mais utilizarão no dia a dia, pois pode ser aplicada de maneira programática e automatizada, com código e usando APIs, mas também manualmente, escrevendo e conversando com o ChatGPT, Google Gemini, Le Chat, Mari Talk ou qualquer outro chat de Inteligência Artificial.
#
# Estude essa técnica, faça mais testes e use-a no seu cotidiano, seja para posts nas redes sociais ou outras atividades. Assim, você conseguirá ensinar o modelo a aprender o seu tom de voz e a criar novos conteúdos.
#
# Se você tiver dúvidas, acesse o Discord da Alura, converse com outros estudantes e discuta sobre este e outros exemplos.
#
# O exemplo que abordamos foi sobre números e matemática, mas é importante lembrar que modelos de linguagem não são necessariamente a ferramenta ideal para cálculos matemáticos.
#
# Este exemplo foi utilizado para ilustrar a técnica de Few-Shot, mas você poderia ter usado o Google Sheets, o Excel ou outra ferramenta, para as quais também oferecemos cursos na Alura. Lembre-se não usar um modelo de linguagem como solução para todos os problemas.
#
# Este exemplo é útil para entender como funciona a técnica, mas pode não ser o mais adequado para cálculos matemáticos. Para casos como e-mails, postagens ou outras situações do dia a dia, essa técnica ou os modelos de linguagem podem ser mais úteis e relevantes.
#
# **Próximos passos**
#
# Na próxima aula, exploraremos outras técnicas que também são populares no mercado. Algumas serão apenas mencionadas, enquanto outras serão abordadas mais detalhadamente. Essas técnicas são geralmente usadas de maneira programática, utilizando APIs.

# %% [markdown]
# ### **Para saber mais: Zero-Shot com Chain of Thought**

# %% [markdown]
# A técnica Chain of Thought nasceu com base na few-shot prompting. Ou seja, a cadeia de pensamentos era apresentada ao modelo na resposta de cada exemplo fornecido, e, ao se basear nos exemplos, o modelo replicava a lógica necessária para solução de problemas mais simbólicos.
#
# Entretanto, um estudo posterior explorou a capacidade dos modelos de explicar raciocínio mesmo sem uma quantidade de exemplos elaborados, apenas com a adição da frase “explique passo a passo” no prompt.
#
# Essa técnica é particularmente útil em situações que demandam pensamento simbólico e abstrato, como decisões estratégicas, problemas matemáticos complexos, análise filosófica e ética ou interpretação de dados científicos, por exemplo.
#
# Como vimos na aula sobre few-shot e zero-shot prompting, modelos avançados conseguem lidar muito melhor com comandos sem orientação explícita. Ainda assim, o uso do comando “explique passo a passo” ainda é extremamente útil em cenários em que o detalhamento cuidadoso e consideração de múltiplos fatores são cruciais.

# %% [markdown]
# **Otimizando algoritmos**
#
# Armano trabalha em uma multinacional e está desenvolvendo um sistema de busca para uma nova aplicação do sistema interno da empresa. O sistema de busca estava indo bem, mas começou a apresentar problemas de desempenho ao ser testado com grandes volumes de dados.
#
# **Como Armano pode elaborar um prompt para que um modelo de linguagem o ajude a otimizar o algoritmo para lidar com grandes volumes de dados da forma mais eficaz possível?**
#
# a)
# Enviando o código completo para o modelo e pedindo que reescreva com otimizações.
#
# b)
# Descrevendo detalhadamente a arquitetura do sistema e solicitando que o modelo identifique gargalos e sugira aprimoramentos.
#
# c)
# **Armano pode descrever a arquitetura do projeto, fornecer exemplos dos problemas encontrados na execução e solicitar que o modelo explique passo a passo a análise desses exemplos e como otimizar o desempenho do sistema de busca.**
#
# Com essa abordagem, o modelo fica à par do que realmente está acontecendo. Além disso, com o comando para explicar passo a passo, a técnica chain of thought permite que o modelo forneça explicações mais detalhadas que podem ajudar Armano a encontrar a causa do problema e aplicar soluções mais eficazes.
#
# d)
# Armano pode solicitar ao modelo que gere um algoritmo de busca que seja eficiente para lidar com grandes quantidades de dados.

# %% [markdown]
# ### **Faça como eu fiz: cadeia de pensamentos**

# %% [markdown]
# Nessa aula, conhecemos a técnica Chain-of-thought, que pode ser traduzida como cadeia de pensamentos.
#
# Essa técnica se baseia em incitar que o modelo “raciocine”, tanto com uso de few-shot prompting quanto de zero-shot prompting, indicando que é possível obter respostas muito mais precisas ao “ensinar” ao modelo o processo lógico por trás de uma pergunta.
#
# A cadeia de pensamentos se faz necessária em situações que demandam um pensamento lógico complexo ou abstrato, característicos de algumas áreas do conhecimento humano.
#
# Com uso de exemplos, o indicado é demonstrar a lógica necessária para se chegar na resposta correta, conforme o exemplo dado no prompt abaixo:
#
# Pergunta: O Rogério tem 5 bolas de tênis. Ele compra mais 2 caixas de bolas, cada uma com 3 bolas. Quantas bolas de tênis ele tem agora?
#
# Resposta: O Rogério inicialmente tinha 5 bolas de tênis. Se cada caixa tem 3 bolas e ele comprou 2 caixas, isso significa que ele comprou mais 6 bolas. Ou seja, no total agora ele tem 5+ 6, que resulta em 11 bolas de tênis.
#
# Pergunta: Havia 23 maçãs no refeitório. Se foram usadas 20 para fazer o almoço e foram compradas mais 6, quantas maçãs eles têm agora?
#
# Resposta:
#
# Já no caso de zero-shot chain of thought, a frase “explique passo a passo” adicionada ao comando é que incita o modelo a raciocinar. Isso pode ser útil quando não há exemplos disponíveis ou até mesmo para desvendar a lógica por trás de um problema.
#
# Agora é sua vez de praticar! Teste a técnica chain of thought com problemas do seu dia a dia ou, se preferir, utilize o problema do cálculo da alíquota do “Carraristão”. Os valores estão disponíveis [na planilha](https://).

# %% [markdown]
# **Opinião do instrutor**
#
# Se preferir, você pode utilizar o mesmo prompt da aula.

# %% [markdown]
# Pergunta: Tenho uma lista de valores. O meu resultado final será 30% da soma desses valores. Porém, nem todos os valores serão somados, apenas aqueles acima de R$40.000,00.
#
# Para a lista abaixo, conte quantos valores existem acima de R$40.000,00, quais são eles, faça a soma desses valores e, no fim, calcule o valor de 30% dessa soma.
#
# R$10.000,00
#
# R$20.000,00
#
# R$50.000,00
#
# R$60.000,00
#
# Resposta: Nessa lista, existem 4 valores.
#
# Há 2 valores acima de R$40.000,00, que são
# R$50.000,00 e R$60.000,00.
#
# A soma desses valores é R$110.000,00. O resultado final é 30% desse valor, portanto, 30% de R$110.000,00, que é R$33.000,00
#
# Pergunta: Tenho uma lista de valores.
#
# O meu resultado final será 30% da soma desses valores. Porém, nem todos os valores serão somados, apenas aqueles acima de R$40.000,00.
#
# Para a lista abaixo, conte quantos valores existem acima de R$40.000,00. Para a lista abaixo, conte quantos valores existem e qual o resultado final.
#
# R$ 31.000,00
#
# R$ 15.000,00
#
# R$ 52.000,00
#
# R$ 103.000,00
#
# R$ 42.000,00
#
# R$ 156.000,00
#
# R$ 15.000,00
#
# R$ 27.000,00
#
# R$ 82.000,00
#
# R$ 33.000,00
#
# Resposta:

# %% [markdown]
# **O que aprendemos?**
#
# **Nessa aula, você aprendeu a:**
#
#  - Criar prompts que incitam raciocínio do modelo;
#
#  - Utilizar técnicas few-shot e zero-shot com chain of thought.

# %% [markdown]
# ## **Aula 04  - Mais técnicas de Prompt**

# %% [markdown]
# **Least-to-Most Prompting**

# %% [markdown]
# Nesta última aula, vamos comentar e mostrar algumas das outras técnicas que também se tornaram populares no mercado durante esses últimos anos do boom dos modelos de linguagem. A primeira delas se chama Least-to-Most Prompting (Do Menor para o Maior).
#
# O problema que estava ocorrendo era que a parte de reasoning (raciocínio) em modelos de linguagem nem sempre funcionava muito bem. Isso foi percebido por Denny Zhou e outras pessoas da Google, que criaram um paper para tentar melhorar isso, ainda na época do ChatGPT-3.
#
# Em problemas que exigiam raciocínio lógico, essas pessoas tentaram dividir o problema em partes menores, algo que nós mencionamos também nas aulas iniciais como uma das técnicas para resolver. Elas fizeram isso de maneira programática.
#
# Vamos imaginar um problema, que foi o caso que elas deram como exemplo. Temos a Amy, que leva 4 minutos para subir até o topo de um toboágua. Para escorregar até o chão de volta, leva 1 minuto.
#
# Então, no total, são 4 minutos para subir, mais 1 para descer, dá 5 minutos. O toboágua vai fechar daqui a 15 minutos. Então, temos uma questão de matemática. Quantas vezes ela ainda consegue escorregar antes que esse toboágua feche?
#
# Quando essa pergunta era feita de uma vez só, em um zero-shot prompting, o modelo se confundia, ele não conseguia raciocinar, não conseguia entender muito bem.
#
# **Uma possível solução**
#
# A proposta da Google foi decompor o problema em subproblemas e ir adicionando ao prompt final. Então, ela pediu para o modelo decompor esse problema inicial em outros subproblemas e adicionar, e aí dar a resposta para a versão adicionada.
#
# Por exemplo, o que queremos resolver é: quanto tempo leva cada viagem? É o primeiro subproblema que podemos querer resolver. Então, temos o mesmo enunciado inicial, o toboágua fecha daqui a 15 minutos. Então, antes da pergunta de quantas vezes ela consegue escorregar, podemos fazer uma outra pergunta, um outro subproblema, que é: quanto tempo leva a cada viagem?
#
# Não somos nós que estamos fazendo, é o próprio modelo que está fazendo isso. Isso pode ser feito de maneira programática, utilizando a API desses modelos.
#
# E aqui o modelo já dá uma resposta. O modelo fez um subproblema e deu a resposta para o próprio subproblema:
#
# *Amy leva 4 minutos para subir ao topo e 1 minuto para escorregar até o solo. 4 mais 1 é igual a 5.*
#
# Então, cada viagem leva 5 minutos. E aí, ele vai ter a pergunta que ele queria saber: quantas vezes ela ainda consegue escorregar antes que esse toboágua feche? E aí ele vai dar a resposta, que seriam 3 vezes. Seria 15 minutos dividido por 5.
#
# **Os resultados práticos da solução**
#
# A equipe percebeu que, quando fez isso usando o modelo GPT-3 da DaVinci, que é um modelo muito mais fraco do que os modelos que temos hoje em dia, a precisão do modelo foi para 99%. Usando só 14 exemplos, claro, mas usando o Chain of Thought (Cadeia de Pensamento) era 16. Então, para problemas de lógica, ele melhorou de 16% para 99% a acurácia.
#
# Tem um ponto negativo que é, como isso é feito programaticamente, isso vai custar mais, porque ele vai ter idas e voltas. E como falamos no começo, isso aqui são tokens. São tokens que ele está prevendo.
#
# O modelo de linguagem prevê sempre qual é o próximo token. E todas essas empresas, como a OpenAI e a Google, quando você usa a API delas, elas cobram por token. O token da pergunta e o token da resposta.
#
# Lembram do exemplo que demos sobre o Rogério Ceni? Ele sempre mantém o contexto inteiro da pergunta e da resposta. Então, em uma conversa muito longa que você está tendo com esse modelo, ele vai mandar um grande mapa com várias perguntas e várias respostas para manter esse contexto e obter a resposta abaixo. Como isso está sendo cobrado por tokens, pode acabar saindo mais caro para quem está utilizando isso.
#
# E isso foi chamado por ele de Least-to-Most Prompting, que significa do menor para o maior ou do menos para o mais. Ou seja, eles tenta dividir um problema maior em problemas menore

# %% [markdown]
# ### **Chain-of-Verification**

# %% [markdown]
# Outra técnica proposta por Shehzaad Dhuliawala e outras pessoas da Meta, é chamada de Chain-of-Verification (Cadeia de Verificação). Essa técnica é mais utilizada para problemas de fatos reais, biografias de pessoas, entre outros, para verificar se a informação fornecida pelo modelo está correta ou não.
#
# O Chain-of-Verification funciona em quatro fases ou passos:
#
# 1. O primeiro passo é o prompt e as respostas iniciais;
#
# 2. Em seguida, o modelo gera perguntas de verificação;
#
# 3. Depois, executa essas verificações;
#
# Por fim, gera a resposta final com base nessas verificações.
#
# **Detalhamento das etapas**
#
# Vamos ver passo a passo como isso funciona?
#
# Na fase 1, vamos supor que o exemplo seja: "Cite alguns políticos que nasceram na cidade de Nova Iorque". O modelo inicialmente, que pode ser o Llama, ChatGPT, Claude, Gemini ou qualquer outro, fornece uma lista de pessoas.
#
# Essa é uma questão factual: quem nasceu onde? Suponhamos que o modelo forneceu a seguinte lista: Hillary Clinton, Donald Trump, Michael Bloomberg e Bernie Sanders. Todos esses são políticos norte-americanos que, supostamente, nasceram na cidade de Nova Iorque.
#
# Na fase 2, o modelo gera perguntas de verificação com base no prompt e nas respostas. Por exemplo, o modelo pode criar perguntas como: "Onde nasceu Hillary Clinton?", "Onde nasceu Donald Trump?", "Onde nasceu Michael Bloomberg?" e assim por diante, para cada pessoa da lista.
#
# Na fase 3, o modelo executa essas verificações, ou seja, responde a cada uma dessas perguntas. Por exemplo, Hillary Clinton nasceu em Chicago, Illinois, então ela não nasceu em Nova Iorque. Donald Trump nasceu no Queens, em Nova Iorque, então está correto. Michael Bloomberg nasceu em Boston, Massachusetts, então ele também não nasceu em Nova Iorque. Assim, começamos a eliminar as respostas erradas.
#
# Na fase 4, o modelo analisa essas respostas, compara com a resposta inicial e oferece a resposta final verificada. Por exemplo, da nossa lista inicial, apenas Donald Trump nasceu em Nova Iorque. Então, o modelo pode gerar uma nova lista com Donald Trump e adicionar outras pessoas que nasceram em Nova Iorque, como Alexandria Ocasio-Cortez e Bernie Sanders.
#
# Essa é a técnica de Chain-of-Verification. No entanto, ela pode ter o mesmo problema da técnica List-to-Most, que é o custo elevado, pois envolve várias chamadas e interações com os modelos. Por isso, essa técnica geralmente é realizada de maneira programática, utilizando APIs, e não manualmente.
#
# No próxima aula, vamos ensinar outra técnica muito interessante, mostrando o código para vocês.

# %% [markdown]
# ### **Self-Consistency**

# %% [markdown]
# Finalizando esta última aula, vamos ensinar uma técnica chamada Self-Consistency (Autoconsistência), publicada no trabalho "Self-Consistency Improves Chain of Thought Reasoning in Language Models", escrito pela Xuezhi Wang e por outras pessoas do Google em 2022. Essa técnica é muito poderosa, principalmente quando estamos lidando com números, valores e fatos.
#
# A Self-Consistency consegue melhorar o Chain of Thoughts (Cadeia de Pensamento), ou seja, o raciocínio em cadeia de pensamento em modelos de linguagem. A ideia é simples, mas muito eficaz.
#
# Podemos supor que, à medida que os modelos de linguagem se tornam mais poderosos, as respostas que eles fornecem também melhoram. Na maioria das vezes, a resposta que o modelo fornece estará correta. No entanto, é possível que o modelo cometa erros.
#
# Imagine que você está executando seu sistema, seja manualmente ou de maneira automatizada, utilizando API, e você faz uma pergunta e o modelo fornece uma resposta.
#
# Você não tem certeza se a resposta estava correta e quer verificá-la. Para isso, foi inventada a técnica de Self-Consistency, que consiste basicamente em fazer a mesma pergunta várias vezes para o modelo, criar uma lista com as respostas e ver qual foi a mais frequente.
#
# *A resposta mais frequente provavelmente será a resposta correta, considerando que esses modelos acertam na maioria das vezes.*
#
# **Entendendo a técnica na prática**
#
# Para demonstrar isso, criamos um código no Google Colab. Para quem não conhece, o Google Colab é um ambiente onde você pode programar em Python sem ter que baixar nada. Você pode fazer isso diretamente no site colab.research.google.com.
#
# Primeiramente, precisamos instalar a biblioteca da OpenAI no nosso ambiente do Colab:

# %%
pip install -q openai

# %% [markdown]
# Depois, importamos a biblioteca e precisamos de uma API para nos identificarmos para a OpenAI. Nós usamos uma API key, que é um valor que identifica quem somos para a OpenAI.
#
# Temos a nossa mensagem inicial, que define o papel do modelo. Neste caso, o modelo é um assistente prestativo. Depois, definimos os parâmetros iniciais do ChatGPT, que é o valor mais básico da maioria dos modelos.

# %% [markdown]
# from google.colab import userdata
# import openai
#
# # seta a API key
# openai.api_key = userdata.get('OPENAI_API_KEY')
#
# # Definição de persona do sistema e histórico de mensagens
# messages = [
#     {"role": "system", "content": "You are a helpful assistant."},  # seta a persona do modelo, se vai ser educado, formal, sarcástico etc.
# ]

# %% [markdown]
# A parte interessante começa quando criamos uma variável chamada answers, que inicialmente está vazia. Vamos supor que faremos a pergunta quatro vezes, então o número de loopings será quatro.

# %% [markdown]
# # SELF-CONSISTENCY
# answers = []
#
# LOOPS = 4
#
# prompt = """Retorne no final sempre a string 'Resultado: ' com apenas valor do resultado depois dela, nenhuma operação nem pontuação além do valor.
#
# Pergunta: Se houver 3 carros no estacionamento e chegarem mais 2 carros, quantos carros estarão no estacionamento?
#
# Resposta: Já existem 3 carros no estacionamento. Chegam mais 2. Agora existem 3 + 2 = 5 carros. A resposta é 5.
#
# Resultado: 5
#
# Pergunta: Os patos de Janet botam 16 ovos por dia. Ela come três no café da manhã todas as manhãs e faz muffins para seus amigos todos os dias utilizando mais quatro. Ela vende o restante por 2 dólares por ovo. Quanto dinheiro ela ganha todos os dias?
#
# Resposta:
#
# Resultado:"""

# %% [markdown]
# Estamos fazendo a nossa cadeia de pensamento e ensinando o modelo a raciocinar com o exemplo dos carros. A pergunta, a resposta e o resultado do problema dos carros somos nós que estamos fornecendo.
#
# Logo abaixo, está o caso real, para o qual queremos uma resposta. Se a Janet tinha 16 ovos, comeu três e usou outros quatro para fazer muffins, sobraram nove. Assim, multiplicando nove ovos por dois dólares, temos 18 dólares.
#
# Deixamos a resposta e o resultado em branco para o modelo preencher, seguindo o nosso padrão de Chain of Thoughts. Depois de definir o prompt, colocamos ele dentro de uma variável e essa variável será enviada dentro das mensagens para a OpenAI.
#
# Fazemos um for loop, que é basicamente uma repetição. Fazemos uma vez tudo que está dentro do looping, depois fazemos uma segunda vez, depois uma terceira vez, até chegar no número que pedimos para parar.
#
# Fazemos a chamada para a OpenAI, pegamos a resposta e adicionamos na lista de respostas (answers). No final, queremos ver qual é o valor mais frequente e quantas vezes ele aparece.

# %%
messages.append({"role": "user", "content": prompt})  # adiciona sua pergunta no histórico do chat

for loop in range(0, LOOPS):
    # Chamada à API
    response = openai.chat.completions.create(
        model = "gpt-3.5-turbo",
        messages = messages,
        max_tokens = 200,
        temperature = 1
    )

    # Extrai a resposta de dentro do JSON de resposta
    answer = response.choices[0].message.content
    print(f"### LOOP", loop, ':\n')
    print(answer)

    start_index = answer.find("Resultado: ") + len("Resultado: ")
    if start_index != -1:
        number_answer = answer[start_index:].split()[0].rstrip('.')
        print("Answer:", number_answer, '\n------')
        answers.append(int(number_answer))  # adiciona a resposta à lista de respostas

print(answers, '\n')

# %% [markdown]
# Vamos rodar o código e ver como ele funciona na prática. Rodamos o código e vemos que o valor mais frequente é 18, que aparece quatro vezes.
#
# Vamos executar mais uma vez o mesmo código. Desta vez, o valor mais frequente é 18, que aparece três vezes. Então, entendemos como funciona a técnica. Poderíamos fazer mais vezes, por exemplo, 10 ou 15 vezes, e pegar o valor mais frequente, se for algo mais importante.
#
# [18, 18, 24, 18]
#
# **O valor mais frequente é 18 que aparece 3 vezes.**
#
# Baseado na ideia de que a maioria das vezes o modelo estará correto, conseguimos obter o resultado. No entanto, esse código não está perfeito, porque às vezes o modelo não retorna exatamente o resultado de dois pontos, ele retorna um texto, e, nessa conversão, se ele pegar um texto vai dar um erro, e não poder comparar texto com número.
#
# Mas já serve para explicar como funciona essa técnica de Self-Consistency. Esse código base estará disponível para vocês melhorarem e adaptarem para suas necessidades.

# %% [markdown]
# **Organizando processos**
#
# Monalisa é uma cientista de dados e está planejando um projeto complexo de aprendizado de máquina para sua empresa. Esse processo envolve várias etapas interligadas, e ela gostaria de utilizar um modelo de linguagem como assistente na organização de cada etapa do projeto.
#
#
# **Qual técnica de engenharia de prompt seria mais eficaz para garantir que o modelo pense em cada etapa de forma detalhada?**
#
# a)
# Self-consistency, pois pode verificar várias respostas para garantir precisão em cada etapa.
#
# b)
# Few-shot prompting, pois com exemplos de projetos similares, o modelo já pode fazer o novo projeto.
#
# c)
# **Chain of thought prompting, pois permite uma análise detalhada de cada fase do projeto de forma sequencial.**
#
# Com essa técnica, o modelo terá mais capacidade de raciocínio para cada etapa do projeto.
#
# d)
# Zero-shot prompting, para que o modelo gere uma resposta criativa.

# %% [markdown]
# ### **Mão na massa: aplicando técnicas de Prompt no cotidiano**

# %% [markdown]
# E aí, bora praticar?
#
# Elabore um prompt que seja realmente útil para o seu dia a dia. Fique à vontade para usar a criatividade, ou escolha algumas das sugestões a seguir.
#
#  - Crie um prompt para organizar sua rotina de estudos na Alura, que considere suas áreas de interesse, outras atividades e diferentes estilos de estudo (assistir aulas, prática em projetos, exercícios, etc);
#
#  - Crie um prompt que permita uma interação com o modelo simulando uma entrevista técnica na sua área. Informe tópicos técnicos específicos e instrua o modelo como ele deve agir;
#
#  - Desenvolva um prompt para gerar perguntas e respostas sobre os tópicos estudados em um curso. Use o modelo para revisar e reforçar seu aprendizado, e pratique com ele simulando um quiz de conhecimento.
#
# Refine seus prompts e teste em diferentes interações, até encontrar o prompt que melhor funciona.
#
# Se desejar, compartilhe seus resultados e reflexões no fórum!

# %% [markdown]
# **Opinião do instrutor**
#
# Aqui vão algumas dicas que devem ser aplicadas na criação de prompts:
#
#  - Lembre-se de escrever de forma clara e com especificidade. Quanto mais detalhado for o seu pedido, melhor será o resultado.
#
#  - Dê instruções sobre o formato que você espera a resposta. Pode ser lista, texto, tabela…
#
#  - Considere utilizar exemplos, mas lembre-se que, em algumas situações, pode ser melhor utilizar apenas outras técnicas.
#
#  - Experimente refinar o prompt. Se a resposta inicial não for o que você espera, faça alterações no prompt, adicione detalhes ou mude o foco.
#
#  - Peça para o modelo explicar suas respostas e sugerir melhorias.
#
#  - Se simular cenários interativos, como a entrevista técnica, explique claramente no prompt inicial como o modelo deve agir durante toda a interação.
#
# Quanto mais você explora os conceitos de engenharia de prompt no seu dia a dia, mais eficazes serão seus resultados com IAs generativas.
#
# Experimente as técnicas aprendidas no curso em situações diversas de sua vida profissional e pessoal, e aproveite a IA como valiosa assistente para otimizar seus processos e resultados.

# %% [markdown]
# **O que aprendemos?**
#
# **Nessa aula, você aprendeu :**
#
#  - Técnica Least-to-most prompting, aplicada em problemas de raciocínio lógico complexo;
#
#  - Técnica Chain of verification, aplicada para verificação de fatos reais;
#
#  - Técnica Self Consistency, aplicada para seleção da melhor resposta do modelo;
#
#  - Possibilidade de uso programático dos LLMs.

# %% [markdown]
# ### **Conclusão**

# %% [markdown]
# Começamos desde o início aprendendo o que são os modelos de linguagem, como eles funcionam, o que fazem nos bastidores, word embeddings (incorporações de palavras), temperatura, o que são tokens.
#
# Depois, entramos nos princípios da engenharia de prompt, os princípios para criar um prompt ideal. Abordamos as técnicas mais utilizadas para criar esses prompts, como, por exemplo, o zero-shot prompting (sugestão sem nenhum exemplo), o few-shot prompting (sugestão com alguns exemplos) ou a poderosa técnica de few-shot com chain-of-thoughts (cadeia de pensamentos), também com alguns exemplos.
#
# Abordamos vários exemplos dessas técnicas utilizadas na prática e também exploramos outras técnicas que são mais usadas de maneira programática, como o least-to-most prompting (sugestão do menor para o maior), o chain of verification (cadeia de verificação) e, por fim, chegamos ao self-consistency (autoconsistência), onde abordamos até a parte de código.
#
# Se você gostou do curso, deixe uma avaliação, comente o que gostou, o que não gostou, o que pode melhorar, isso sempre ajuda muito. Mas sempre incentivamos a compartilhar o que você aprendeu nas suas redes sociais para mostrar que agora conhece sobre engenharia de prompt, podendo também colocar o certificado deste curso na sua rede social
