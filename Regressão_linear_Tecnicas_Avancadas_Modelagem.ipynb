# %% [markdown]
# <a href="https://colab.research.google.com/github/tluistorres/Cursos/blob/main/Regress%C3%A3o_linear_Tecnicas_Avancadas_Modelagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style='color: green; font-size: 36px; font-weight: bold;'>Data Science - Regressão Linear II</h1>

# %% [markdown]
# ## <font color=red>Introdução</font>

# %% [markdown]
# Técnicas Avançadas de Modelagem da Alura, que será como uma continuação do curso de Regressão Linear: Testando Relações e Prevendo Resultados.
#
# Trabalharemos algumas técnicas diferentes para lidar com problemas cotidianos para pessoas que trabalham com data science, mantendo o padrão utilizado no curso anterior, ou seja, criaremos um notebook, que ficará todo documentado, com as células vazias, e as preencheremos ao longo dos estudos.
#
# Estudaremos técnicas de transformação de variáveis, inclusive de algumas que não apresentam relação linear entre si. E, a partir dessas técnicas de transformação, conseguiremos resolver problemas e estimar modelos de Regressão Linear.
#
# Além disso, nesse notebook, conheceremos testes mais formais de parâmetros de regressão. Anteriormente, abordamos análises gráficas e testes informais. Agora, lidaremos com os testes mais formais, sem entrar em muitos detalhes em testes de hipótese. Basicamente, entenderemos a forma de interpretar os testes, chegando à conclusões.
#
# Será um curso bem prático, para que possamos utilizar o conteúdo no dia a dia, de fato. Espero que seja bastante útil no seu trabalho e ajude seus estudos.
#
# Adiante, já colocaremos a mão na massa e conheceremos o data set. Vamos lá?

# %% [markdown]
# # <font color=red>Aula 01 - Análise Preliminares</font>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>1.2 Conhecendo o Dataset</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Importando a biblioteca pandas
#
# https://pandas.pydata.org/

# %% [markdown]
# Começaremos conhecendo o ambiente que foi criado para desenvolvimento desse segundo curso de Regressão Linear. O arquivo que o contém está disponível para download em ["Projeto inicial do treinamento"](https://), no menu à esquerda.
#
# Feito o download do projeto, acessaremos "data-science > reg-linear-II". Nessa pasta, encontraremos os conjuntos de dados que serão utilizados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dentro de "Dados", temos o arquivo dataset.csv e uma pasta ("img") com as imagens que serão exibidas no notebook. Já em "Projeto", encontramos a pasta ".ipynb_checkpoints" e o arquivo Regressão Linear.ipynb, o notebook que utilizaremos. Por fim, o arquivo Start Jupyter.bat, no qual escrevemos jupyter notebook para iniciar o Jupyter, dentro dessa pasta que estamos trabalhando. Ou seja, essa pasta funcionará em qualquer local que for salva — isso se as variáveis de ambiente estiverem configuradas corretamente.
#
# Clicaremos duas vezes em Start Jupyter.bat para abrir a nossa pasta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Assim que ela abrir, acessaremos "Projeto > Regressão Linear.ipynb". Uma nova aba se abrirá com o nosso notebook, Regressão Linear.ipynb.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Da mesma forma que no curso anterior, o notebook já está preparado, para servir como um roteiro tanto para esse curso, quanto para executar seus projetos individuais. Se analisarmos, perceberemos que ele já está todo documentado. As células estão vazias, mas serão preenchidas ao longo de nossos estudos.
#
# Inicialmente, conheceremos o Dataset que será utilizado no projeto. Logo no início do notebook, no item "1.2 Conhecendo o Dataset", encontramos "Importando a biblioteca pandas", seguido pelo seguinte link: https://pandas.pydata.org. Abaixo, na célula vazia, faremos a importação, digitando:

# %%
import pandas as pd

# %% [markdown]
# E teclaremos "Enter". Feita a importação, abaixo, encontraremos um Dataset sobre o mercado imobiliário, semelhante ao que foi utilizado no curso de Pandas, para executar o nosso projeto.
#
# Para esse curso, foram feitas algumas adaptações para destacar alguns assuntos de Regressão Linear. No caso, encontraremos nos "Dados" de "Dataset" as seguintes variáveis:
#
#   - Valor — Valor (R$) de oferta do imóvel
#
#   - Area — Área do imóvel em m²
#
#   - Dist_Praia — Distância do imóvel até a praia (km) (em linha reta), no caso a orla mais próxima
#
#   - Dist_Farmacia — Distância do imóvel até a farmácia mais próxima (km) (em linha reta)
#
# Dica: Caso tenha curiosidade em saber como criar as duas últimas variáveis, recomendo esses dois cursos de GeoPandas da Alura:
#
#     GeoPandas Parte 1: Trabalhando com dados Geoespaciais
#
#     GeoPandas Parte 2: Visualização com mapas interativos
#
# Na célula vazia de "Leitura dos dados", vamos abrir a pasta "Dados" para fazer a leitura de dataset.csv, digitando:

# %% [markdown]
# ## O Dataset e o Projeto
# <hr>
#
# ### Descrição:
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify; text-indent: 35px;'>O mercado imobiliário vem sendo objeto de diversos estudos e pesquisas nos últimos tempos. A crise financeira que afeta a economia tem afetado significativamente os investimentos e ganhos advindos deste setor. Este cenário incentiva o aumento do interesse por estudos de previsão de demanda baseados em características deste mercado, dos imóveis e do entorno destes imóveis.</p>
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify; text-indent: 35px;'>Neste contexto o objetivo principal do nosso projeto é desenvolver um sistema de avaliação imobiliária utilizando a metodologia de regressões lineares que é uma das técnicas de machine learning.</p>
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify; text-indent: 35px;'>Nosso *dataset* é uma amostra aleatória de tamanho 5000 de imóveis disponíveis para venda no município do Rio de Janeiro.</p>
#
# ### Dados:
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#     <li><b>Valor</b> - Valor (R$) de oferta do imóvel</li>
#     <li><b>Area</b> - Área do imóvel em m²</li>
#     <li><b>Dist_Praia</b> - Distância do imóvel até a praia (km) (em linha reta)</li>
#     <li><b>Dist_Farmacia</b> - Distância do imóvel até a farmácia mais próxima (km) (em linha reta)</li>
# </ul>

# %% [markdown]
# ## Leitura dos dados

# %%
dados = pd.read_csv('/content/dataset.csv', sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2-1909505244.py in <cell line: 0>()
# ----> 1 dados = pd.read_csv('/content/dataset.csv', sep=';')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ## Visualizar os dados

# %%
dados.head()

# %% [markdown]
# ## Verificando o tamanho do dataset

# %% [markdown]
# Nela, encontramos as variáveis com as respectivas unidades de medida apresentadas anteriormente. Continuaremos, preenchendo a célula de "Verificando o tamanho do dataset" com:

# %%
dados.shape

# %% [markdown]
# Ou seja, são 5000 observações e 4 variáveis.
#
# Acabamos de conhecer o Dataset, o nosso projeto. Com base nele, estimaremos o modelo de Regressão Linear para tentar prever o valor dos imóveis, a partir das três características iniciais — Area, Dist_Praia e Dist_Farmacia — propostas.
#
# Assim, geraremos um sistema de avaliação imobiliário, utilizando técnicas de Machine Learning, no caso, a Regressão Linear. Essa é a ideia do nosso projeto.
#
# Como dito anteriormente, seguiremos o mesmo procedimento do curso anterior, só que com algumas modificações.
#
# Antes, a ideia era desenvolver sensibilidade para uma análise de dados mais visual, com base em comportamento de dados e em padrões lineares entre as variáveis. Agora, a ideia é conhecer mais algumas coisas, como as transformações de dados para poder rodar modelos lineares — considerando que alguns não possuem um padrão linear entre as variáveis dependentes e as variáveis explicativas. Portanto, estudaremos como realizar algumas transformações para fazer funcionar. Além disso, serão apresentados alguns testes mais formais do que os do curso anterior, baseados em testes de hipótese com algumas estatísticas de aceitação e rejeição dos testes.
#
# Adiante, no item "1.3 Análises Preliminares", começaremos a analisar os dados para ter uma ideia do comportamento dos dados.

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>1.3 Análises Preliminares</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# A seguir, iniciaremos uma análise preliminar dos dados, uma análise descritiva, que é muito importante em qualquer projeto de regressão linear. Precisamos entender como os dados se comportam, qual a variação e a correlação entre eles.
#
# Primeiro, preencheremos a célula de "Estatísticas descritivas", no item "1.3 Análises Preliminares". Lembrando que, caso tenha fechado o notebook, após abrir o projeto novamente, clique em "Cell > Run All", no menu superior. Assim, as células preenchidas anteriormente serão executadas, colocando nosso DataFrame dados na memória.

# %% [markdown]
# ## Estatísticas descritivas

# %%
dados.describe().round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-1981477581.py in <cell line: 0>()
# ----> 1 dados.describe().round(2)
#
# NameError: name 'dados' is not defined

# %% [markdown]
# Nesse grupo de estatísticas, na primeira linha, temos uma contagem (count) que está de acordo com o número de observação (5000.00) que obtivemos anteriormente. Abaixo, encontramos as linhas para:
#
# média (mean);
# desvio padrão (std);
# valor mínimo (min);
# primeiro quartil (25%);
# mediana (50%);
# terceiro quartil (75%);
# valor máximo (max).
# Na coluna de Valor, encontramos um valor máximo um pouco estranho, de 25000000.00 — vinte e cinco milhões — de reais. Pode ser que exista, já que estamos tratando de dados da cidade Rio de Janeiro, na qual existem imóveis muito caros. Mas, o foco do curso não é tratamento de outliers. Lidaremos com isso como se já estivesse tratado — se você fez o curso de Pandas, conhece ao menos uma técnica para tratamento. Enfim, não abordaremos tratamento de outliers neste curso. No entanto, fique à vontade para aplicar um tratamento para melhorar os resultados da regressão que obteremos no projeto. Inclusive, será bem legal se você aplicar algum.
#
# Na coluna de Area também encontramos um valor que causa estranhamento. Um apartamento de 2000.00m². Pode ser que também exista, mas é um valor um tanto exagerado, que não parece real. Mas, vamos deixar isso de lado, por enquanto.
#
# As colunas seguintes são as de Dist_Praia e Dist_Farmacia, ambas medidas e quilômetros. Nelas, encontramos valores mais aceitáveis na linha de max. A linha de min dessas colunas apresentam 0.00, ou seja, estão bem situados — muito próximo à praia e à farmácia.
#
# Feita a análise preliminar, partiremos para a Análise de Correlação, que é uma análise de associação linear, entre duas variáveis. Para isso, na célula de "Matriz e correlação", digitaremos:

# %% [markdown]
# ## Matriz de correlação
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O <b>coeficiente de correlação</b> é uma medida de associação linear entre duas variáveis e situa-se entre <b>-1</b> e <b>+1</b> sendo que <b>-1</b> indica associação negativa perfeita e <b>+1</b> indica associação positiva perfeita.</p>

# %% [markdown]
# Assim, criaremos a matriz de correlação (corr()), limitando o número de casas decimais a quatro (round(4)). Ao executar, obteremos a seguinte matriz:

# %%
dados.corr().round(4)

# %% [markdown]
# O objetivo é identificar a correlação entre as variáveis e a direção dessa correlação. Lembrando que esse valor vai de -1 a 1, onde -1 é uma associação negativa perfeita e 1 é uma associação positiva perfeita. Vale ressaltar que 1 positivo não significa que todos os dados estão subindo. A associação positiva significa que os dados vão na mesma direção, ou seja, quando um sobe, o outro sobe também ou quando um desce, o outro desce também. Já a associação negativa é o contrário da positiva: quando um sobe, o outro desce.
#
# Inicialmente, a linha que analisaremos é a de Valor, porque é a nossa variável dependente. Lembre-se que estamos criando um sistema de avaliação imobiliário e ela será nosso Y, considerando que queremos estimar o valor dos imóveis. A correlação com:
#
#   - Area é de 0.7110 (70%), bastante alta e positiva, o que faz sentido: quanto maior a Area, maior o Valor;
#
#   - Dist_Praia é mais fraca, -0.3665, de quase 40% e negativa, o que também faz sentido, pois quanto mais distante da praia, menor o Valor;
#
#   - Dist_Farmacia é um tanto baixa, -0.0244, além de negativa. Faz sentido, apesar de muito baixa. Investigaremos com mais atenção se essa variável faz sentido ou não quando chegarmos nos testes formais e codarmos a regressão.
#
# Algo importante que precisamos examinar é se as variáveis explicativas não estão muito correlacionadas entre si. Isso pode ser um problema, como vimos no curso anterior.
#
# Na linha de Area, há uma correlação negativa de quase 30%(-0.2834), não tão alta. Em Dist_Farmacia permanece baixa, mas tudo bem. Analisando os valores de Dist_Praia e Dist_Farmacia, percebemos que as variáveis não estão muito correlacionadas entre si, o que é um ponto positivo.
#
# Adiante, começaremos a a analisar o comportamento da variável dependente (Y), entendendo porquê precisamos analisar os dados e verificar se eles precisam, de fato, da transformação.

# %% [markdown]
# ## <font color=red>Consolidando o seu conhecimento</font>

# %% [markdown]
# Chegou a hora de você seguir todos os passos realizados por mim durante esta aula:
#
#   - Fazer o download do projeto inicial do treinamento
#
#   - Importar o pandas
#
#   - Ler e visualizar os dados
#
#   - Verificar o tamanho do dataset
#
#   - Criar uma tabela com estatísticas descritivas dos dados do dataset
#
#   - Criar uma matriz de correlação dos dados da tabela de estatísticas descritivas
#
# Caso já tenha feito, excelente. Se ainda não, é importante que você execute o que foi visto nos vídeos para poder continuar com a próxima aula.

# %% [markdown]
# ## <font color=red>O que aprendemos?</font>

# %% [markdown]
# ## Nesta aula, aprendemos:
#
#   - Como importar a biblioteca pandas
#
#   - Como ler e visualizar os dados
#
#   - Como verificar o tamanho do dataset
#
#   - Como criar uma tabela com estatísticas descritivas dos dados do dataset
#
#   - Como criar uma matriz de correlação dos dados da tabela de estatísticas descritivas

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>2.1 Comportamento da Variável Dependente (Y)</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Importando biblioteca seaborn
# https://seaborn.pydata.org/
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O Seaborn é uma biblioteca Python de visualização de dados baseada no matplotlib. Ela fornece uma interface de alto nível para desenhar gráficos estatísticos.</p>

# %% [markdown]
# A partir de agora, iniciaremos uma análise da variável dependente (y), ou seja, uma análise gráfica, com a qual conseguiremos identificar o comportamento da distribuição, possibilitando a tomada de decisões para o resto do nosso projeto.
#
# Essa análise gráfica é muito importante. Faremos algo bastante semelhante ao que fizemos no curso anterior, no qual utilizamos o Seaborn. Sendo assim, no item "2.1 Comportamento da Variável Dependente (y)", faremos a importação dele, preenchendo a célula de "Importando biblioteca seaborn" da seguinte forma:

# %%
import seaborn as sns

# %% [markdown]
# sns é como um apelido utilizado pela comunidade para se referir ao Seaborn. Executaremos a importação e seguiremos para "Configurações de formatação dos gráficos". Sigo reforçando: da mesma forma que fizemos no curso anterior, aplicaremos algumas configurações e, caso queira salvar as imagens e os gráficos que criar para gerar um relatório para seu acervo profissional, é possível configurar nessa célula para obter uma formatação bem estruturada dos seus gráficos.
#
# Então, na célula de "Configurações de formatação dos gráficos", na linha abaixo de # palette ->, chamaremos o Seaborn com sns, qe será seguido por .set_palette("Accent"). Lembrando que nessa célula, você encontra todas as possíveis configurações de paleta de estilo. Passamos Accent para set_palette(), mas fique à vontade para configurar seus projetos da maneira que desejar. Feita a configuração da paleta, configuraremos o estilo, abaixo de # style ->, chamando o Seaborn (sns) e setando o estilo (set_style() com darkgrid.

# %% [markdown]
# ## Configurações de formatação dos gráficos

# %%
# palette -> Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r
sns.set_palette("Accent")

# style -> white, dark, whitegrid, darkgrid, ticks
sns.set_style("darkgrid")

# %% [markdown]
# Aplicadas as configurações de paleta e estilo, seguiremos para "Boxplot da variável dependente (y)", onde começaremos a analisar com um boxplot, ferramenta gráfica com a qual conseguimos identificar as posições das estatísticas principais ou de posição — no caso, o primeiro quartil (Q1), mediana e terceiro quartil (Q3).

# %% [markdown]
# ## Box plot da variável *dependente* (y)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# É um desenho de como construir um boxplot, que consiste, basicamente, nas três estatísicas — Q1, mediana e Q3. No curso de Pandas, estudamos como construir um boxplot, então, caso precise, você pode consultar esse material.
#
# Na sequência, encontramos uma célula com suporte para a construção de um:

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.boxplot.html?highlight=boxplot#seaborn.boxplot

# %%
ax = sns.boxplot(data=dados['Valor'], orient='h', width=0.3)
ax.figure.set_size_inches(20, 5)
ax.set_title('Preço dos Imóveis', fontsize=20)
ax.set_xlabel('Reais', fontsize=16)
ax

# %% [markdown]
# Como o foco deste curso está em regressão, não nos aprofundaremos em visualização. Sendo assim, as formatações, como a descrita logo acima, ficarão disponíveis, mas não as digitaremos toda hora. Basicamente, configuraremos os gráficos. As outras configurações já estarão prontas.
#
# No código acima, encontramos a configuração do título (set_title()), do label do eixo x (set_xlabel) e do tamanho da figura set_size_inches(). Vale lembrar que ax é a variável que armazenará o objeto gráfico. Sendo assim, a utilizaremos para futuras configurações.
#
# Continuando, na primeira linha do código, que está vazia, armazenaremos o boxplot na variável ax, chamando o sns e o boxplot(), ao qual passaremos a fonte dos dados. Na verdade, passaremos o dado que desejamos exibir, no caso, data=dados['Valor']. E aproveitaremos para mudar a orientação, deixando-a horizontal com `orient='h'.

# %% [markdown]
# Para evitar o aspecto esticado do gráfico, podemos adicionar width=0.3 entre os parênteses de boxplot().

# %%
ax = sns.boxplot(data=dados['Valor'], orient='h', width=0.3)
ax.figure.set_size_inches(20, 5)
ax.set_title('Preço doa Imóveis', fontsize=20)
ax.set_xlabel('Reais', fontsize=16)
ax

# %% [markdown]
# Inicialmente, esse boxplot pode assustar um pouco, mas o tipo da variável que estamos analisando possui esse tipo de comportamento. Adiante, analisaremos outros gráficos que nos ajudarão a entender esse padrão.
#
# Essas variáveis possuem uma concentração muito alta de valores mais próxima a 0.0 do que a 2.5. E elas possuem uma configuração básica que pode gerar a impressão de que é um monte de outliers, mas cuidado com variáveis desse tipo, para não perder detalhes que são importantes. Nessa análise é preciso ter mais cuidado em relação aos outliers, mesmo utilizando essas variáveis em nível.
#
# Na distribuição que obtivemos nesse gráfico, talvez os pontos próximos a 2.5 sejam realmente outliers. Talvez tenhamos que utilizar outra técnica e separar essa amostra por faixas de preço de imóveis para estimar regressões diferentes. Enfim, muito cuidado com outliers, evite dispensar dados, pois você pode acabar eliminando informações importantes do Dataset.
#
# Analisando esse boxplot, percebemos que ele tem um formato um pouco diferente do que esperávamos. Ele está um pouco puxado para o lado esquerdo. Isso indica — adiantando um pouco o que será comentado adiante — uma assimetria à direita.
#
# Adiante, desenharemos a distribuição de frequência para entendermos melhor esse tipo de distribuição.

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>2.2 Distribuição de Frequências</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# Anteriormente, obtivemos um boxplot diferente do que esperávamos. Ele apresentava uma concentração próximo a 0.5 e muita dispersão próximo a 2.5. O que pode ser considerado um comportamento um tanto estranho.

# %% [markdown]
# Continuando a análise da variável dependente (y), faremos uma distribuição de frequência desse mesmo dado para verificar se esse comportamento se repete — é o que esperamos, mas a intenção é entender um pouco melhor, a partir de outra análise gráfica para auxiliar na identificação desse tipo de problema.
#
# No item ["2.2 Distribuição de Frequências"](https://), encontraremos as configurações, abaixo de uma linha vazia, na célula:

# %% [markdown]
# ## Distribuição de frequências da variável *dependente* (y)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.distplot.html?highlight=distplot#seaborn.distplot

# %%
ax = sns.distplot(dados['Valor'])
ax.figure.set_size_inches(20, 6)
ax.set_title('Distribuição de Frequências', fontsize=20)
ax.set_xlabel('Preço dos Imóveis (R$)', fontsize=16)
ax

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.histplot(dados['Valor'], kde=True)
ax.figure.set_size_inches(20, 6)
ax.set_title('Distribuição de Frequências', fontsize=20)
ax.set_xlabel('Preço dos Imóveis (R$)', fontsize=16)
plt.show()

# %% [markdown]
# Antes de preencher a primeira linha, que está vazia, vale ressaltar que, acima das células, você encontra o link de ajuda para cada uma das funcionalidades que estamos trabalhando. Ao longo das transcrições também, os tópicos que possuírem um link já estarão linkados, conforme os endereços disponibilizados.
#
# Continuando, na primeira linha da configuração, atribuiremos um valor à variável ax, chamando sns e distplot(), ao qual passaremos a variável Valor, que desejamos plotar, para analisar o comportamento.

# %% [markdown]
# Esse comportamento é muito comum para esse tipo de informação. Há mais imóveis com valores mais baixos — aproximadamente com o mesmo valor, seguindo um mesmo padrão — do que imóveis de luxo, que compõem a minoria e custam muito mais caro. E é basicamente isso que o gráfico de distribuição de frequências nos mostra.
#
# Esse tipo de variável — preço de imóvel — possui esse comportamento, também encontrado em análise de variável de renda, que apresenta uma concentração alta de pessoas ganhando muito pouco — um valor padrão próximo ao do salário mínimo, talvez um pouco maior — e pouquíssimas pessoas ganhando fortunas, altíssimos salários.
#
# Por isso estamos analisando esse tipo de gráfico, porque esse tipo de variável é bastante comum e pode gerar alguns problemas na hora de estimar um modelo de regressão, como estudaremos adiante.
#
# Mas, já vamos entender um pouco de simetria. Para estimar um modelo de regressão, seria legal assumirmos que a variável dependente tem uma distribuição normal, que possui um pico na altura da mediana, com ascendência e descendência proporcional nos lados esquerdo e direito. No caso, seria algo no molde do gráfico simétrico, exibido na imagem abaixo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Logicamente, a perfeição é quase que impossível de se alcançar nesses gráficos, mas a ideia é nos aproximarmos ao máximo do padrão simétrico, para obtermos estimativas — estatísticas — mais confiáveis para utilizar no futuro. Caso contrário, teremos que partir para análise de outros tipos de estatísticas, diferentes das que são baseadas na distribuição simétrica. Adiante discutiremos mais a respeito.
#
# No momento, no gráfico de distribuição de frequências, nitidamente, temos uma assimetria à direita. Tanto a curva quanto o boxplot de assimetria à direita estão bem semelhantes aos resultados obtidos nas análises que fizemos. O boxplot também está achatado, praticamente todo jogado para o lado esquerdo. Em função disso, é dado o nome de assimetria à direita, pois o "braço" — a linha que se estende da queda da curva — fica à direita, criando uma assimetria no lado com menos valores.
#
# Existem dados que possuem assimetria à esquerda, mas no caso dos que estamos analisando, claramente trata-se de uma assimetria à direita, com concentração de valores próximo a Q1.
#
# Dados dessa natureza podem gerar problemas para estimarmos regressão, porém possibilitam a transformação para que se aproximem de uma forma simétrica, que permite estimar um modelo de regressão. E, então, para pegar as previsões, retornamos essas transformações — as destransformamos.
#
# Nisso que focaremos nossos estudos. Adiante, entenderemos as dispersões entre as variáveis para tentar identificar uma relação linear entre elas. Perceberemos como é difícil em função do comportamento dessa variável, que obtivemos acima.

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>2.3 Dispersão Entre as Variáveis</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# Anteriormente, com auxílio do boxplot e da distribuição de frequência, identificamos a assimetria do dado que estamos analisando, no caso, uma assimetria à direita.
#
# Agora, tentaremos identificar se a variável dependente e as variáveis explicativas possuem alguma relação linear. Ainda não analisamos as outras variáveis — que seria o correto —, mas para seguir o curso, partiremos para o item ["2.3 Dispersão Entre as Variáveis"](https://). Lembrando que já utilizamos a ajuda do pairplot para isso, no curso anterior.
#
# Nas duas células desse tópico, encontraremos a seguinte configuração de título:

# %% [markdown]
# ## Gráficos de dispersão entre as variáveis do dataset

# %% [markdown]
# ## seaborn.pairplot
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html?highlight=pairplot#seaborn.pairplot
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>Plota o relacionamento entre pares de variáveis em um dataset.</p>

# %% [markdown]
# Assim, chamamos o pairplot(), ao qual passamos dados. Se rodarmos o código dessa forma, obteremos vários gráficos, sendo que, na verdade, queremos analisar somente os três primeiros.
#
# Para fazer somente o pairplot da primeira linha, isolando os três primeiros gráficos, passaremos o valor de y_vars — no caso, a variável dependente Valor — e o que queremos analisar em x, atribuindo uma lista a x_vars.
#
# Aproveitaremos para definir um tamanho para os gráficos, com height, deixando-os maiores, para facilitar a visualização. Feitas as alterações, o código ficará assim:

# %%
ax = sns.pairplot(dados, y_vars='Valor', x_vars=['Area', 'Dist_Praia', 'Dist_Farmacia'], height=5)
ax.fig.suptitle('Dispersão entre as Variáveis', fontsize=20, y=1.05)
ax

# %% [markdown]
# No eixo y dos gráficos, encontramos a variável Valor. No eixo x de cada gráfico temos as variáveis explicativas Area, Dist_Praia e Dist_Farmacia. Em uma rápida análise, já é possível perceber que há certas "explosões".
#
# O primeiro gráfico, de Area, pode indicar uma tendência a uma curva, pois a distribuição dos pontos é um tanto curvilínea. No segundo gráfico, de Dist_Praia, não conseguimos traçar uma reta. Precisaremos das estatísticas para identificar qual a relação entre os pontos. Sabemos que é uma relação negativa, então provavelmente, a reta será traçada ao longo do eixo x. No terceiro, da variável Dist_Farmacia, temos uma reta diferente, com variação estranha, um pouco "explosiva".
#
# Na segunda célula que temos com as configurações do gráfico, vamos plotar o mesmo que plotamos na primeira, só que agora, traçando uma reta de regressão (kind='reg') para analisar o que o pairplot nos mostrará, preenchendo a primeira linha da seguinte forma:

# %%
ax = sns.pairplot(dados, y_vars='Valor', x_vars=['Area', 'Dist_Praia', 'Dist_Farmacia'], kind='reg', height=5)
ax.fig.suptitle('Dispersão entre as Variáveis', fontsize=20, y=1.05)
ax

# %% [markdown]
# O primeiro gráfico, de Area, traz uma reta com um intervalo muito escancarado, mostrando que há uma "explosão". No segundo gráfico, de Dist_Praia, a reta apresenta uma tendência para baixo, mesmo com uma quantidade considerável de dados fora da reta. Visualmente, nota-se que não é uma boa representação. No terceiro gráfico, de Dist_Farmacia, encontramos uma reta na base, onde está a concentração de dados, mas também está um pouco estranho pois não há variação, nem direção, portanto está reto. Então, considerando a correlação anterior também, parece que essas distribuições não explicarão muito bem a variação da variável Valor. Sendo assim, identificaremos isso no modelo de regressão, sem o menor problema.
#
# Sabendo que os gráficos estão uma bagunça e que as relações lineares praticamente não existem em algumas variáveis, adiante, utilizaremos uma técnica de transformação de dados, que consiste em passar o logaritmo deles. Com a transformação logarítmica e repetindo todas essas análises gráficas, conferiremos o que acontece com os dados transformados e se eles já indicam uma relação linear, de forma que possamos estimar um número de regressão a partir deles.

# %% [markdown]
# ## <font color=red>Consolidando o seu conhecimento</font>

# %% [markdown]
# Chegou a hora de você seguir todos os passos realizados por mim durante esta aula:
#
#   - Importar a biblioteca seaborn
#
#   - Configurar a formatação dos gráficos
#
#   - Construir o box-plot da variável dependente
#
#   - Realizar a distribuição de frequências da variável dependente
#
#   - Plotar os gráficos de dispersão entre as variáveis do dataset
#
#   - Analisar a dispersão entre as variáveis
#
# Caso já tenha feito, excelente. Se ainda não, é importante que você execute o que foi visto nos vídeos para poder continuar com a próxima aula.

# %% [markdown]
# ## <font color=red>O que aprendemos?</font>

# %% [markdown]
# ## Nesta aula, aprendemos:
#
#   - Como configurar a formatação dos gráficos
#
#   - Como construir o box-plot da variável dependente
#
#   - Como realizar a distribuição de frequências da variável dependente
#
#   - Como plotar os gráficos de dispersão entre as variáveis do dataset
#
#   - A análise da dispersão entre as variáveis

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>3.1 Transformando os Dados</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# Anteriormente, encontramos um probleminha nas relações entre a variável dependente e as variáveis explicativas, pois não conseguimos identificar uma relação linear entre elas. Além disso, descobrimos que a variável dependente que estamos analisando é assimétrica à direita.
#
# Agora, utilizaremos uma técnica de transformação de variável para tentar corrigir esse problema e, quem sabe, estimar um modelo de regressão linear com essa base de dados, após a transformação.
#
# No item "3.1 Transformando os Dados", encontramos uma apresentação da "Distribuição Normal", explicando o porquê de utilizá-la. No caso, os testes paramétricos assumem que a amostra é retirada de uma população com distribuição de probabilidade conhecida. A maioria dos testes estatísticos assumem que essa distribuição de probabilidade conhecida é a distribuição normal e, por isso, queremos que os dados tenham uma distribuição de frequência semelhante a de um sino, como demonstrado no gráfico simétrico. Então, tentaremos alcançar essa simetria, utilizando a transformação dos dados, que estudaremos a seguir.
#
# Iniciaremos a transformação importando a biblioteca numpy. Sendo assim, na respectiva célula, digitaremos:

# %% [markdown]
# ## <font color=red>Distribuição Normal</font>
# <hr>
#
# ### Por quê?
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>Testes paramétricos assumem que os dados amostrais foram coletados de uma população com distribuição de probabilidade conhecida. Boa parte dos testes estatísticos assumem que os dados seguem uma distribuição normal (t de Student, intervalos de confiança etc.).</p>
#
#
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'></p>

# %% [markdown]
# ## <font color=red>Importando biblioteca numpy</font>

# %%
import numpy as np

# %% [markdown]
# ## <font color=red>Aplicando a transformação logarítmica aos dados do *dataset*</font>
#
# https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.log.html

# %%
np.log(1)

# %% [markdown]
# Chamamos numpy (np.log()) e passamos um valor (1). Nesse caso, obteremos 0.0 como retorno. Mas, note que interessante o que acontece se passarmos 0 como valo

# %%
np.log(0)

# %% [markdown]
# Como retorno, obteremos -inf, um infinito negativo porque é uma função que possui uma linha que sobe e vira à direita, sem tocar no eixo y. Ou seja, quando o x é igual a 0, não há valor para y e ela vai até o infinito. Isso é importante porque, se voltarmos às estatísticas descritivas, repare que temos o min (mínimo) de cada variável. Os valores de Valor e Area são aceitáveis, mas os de Dist_Praia e Dist_Farmacia são iguais a 0.0.

# %% [markdown]
# Se passarmos esse log, teremos o -inf como retorno e isso é um problema, pois os dados serão cortados e não é o que queremos. Queremos que os imóveis com Dis_Praia mínima igual a 0.0 estejam na praia mesmo, queremos que eles estejam na base de dados. Inclusive os de Dis_Farmacia.
#
# Para resolver esse problema, vamos voltar ao item "3.1 Transformando os Dados" e, na segunda célula de "Aplicando a transformação logarítmica aos dados do dataset", começaremos a aplicar as transformações. Sendo assim, digitaremos:

# %%
dados['log_Valor'] = np.log(dados['Valor'])

# %% [markdown]
# Começamos com 'log_Valor' — guarde a ideia do valor 0.0, que discutiremos adiante — e igualamos a np.log(dados['Valor']), que é isso que queremos fazer para cada uma das variáveis. Portanto, podemos selecionar e copiar essa primeira linha e colar três cópias dela logo abaixo, aplicando a substituição das outras variáveis. Note que para as variáveis de distância, faremos algo diferente.

# %%
dados['log_Valor'] = np.log(dados['Valor'])
dados['log_Area'] = np.log(dados['Area'])
dados['log_Dist_Praia'] = np.log(dados['Dist_Praia'] + 1)
dados['log_Dist_Farmacia'] = np.log(dados['Dist_Farmacia'] + 1)

# %% [markdown]
# Para resolver o nosso problema e evitar a perda de dados, somamos um (+ 1) a todos os valores de Dist_Praia e Dist_Farmacia. Assim, não alteraremos a variação dessa variável. Só passaremos ao patamar superior. E, quando passarmos o log, os valores que aparecem como 0.0 na tabela, serão igual a 1, então será 0.0, considerando o retorno que obtivemos quando executamos a primeira célula de "Aplicando a transformação logarítmica aos dados do dataset" com:

# %% [markdown]
# Inclusive, caso não tenha alterado o parâmetro, antes de continuar, recomendo que volte a inserir 1 entre os parênteses de log().
#
# A terceira célula, será preenchida para que possamos visualizar os dados, com:

# %%
dados.head()

# %% [markdown]
# Feita a tabela, o próximo passo será verificar se a criação desses logs resolve, pelo menos, o problema que tivemos na distribuição de frequência. Ou seja, vamos conferir se essa transformação elimina, ou melhora pelo menos um pouco, o efeito estranho, a assimetria à direita. Nosso ideal é obter uma simétrica, mas obviamente, não a obteremos de primeira. Sendo assim, no momento, esperamos nos aproximar à simétrica, o que será o indicativo de que estamos seguindo um bom caminho.
#
# Para isso, na célula de "Distribuição de frequências da variável dependente transformada (y)", considerando que a variável dependente transformada é log_Valor, preencheremos a primeira linha, acima das configurações, deixando-a da seguinte forma:

# %% [markdown]
# ## Distribuição de frequências da variável *dependente transformada* (y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = sns.histplot(dados['log_Valor'], kde=True)
ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências', fontsize=20)
ax.set_xlabel('Log do Preço dos Imóveis', fontsize=16)
plt.show()

# %% [markdown]
# Ele está um pouco esticado, mas podemos reduzir isso, substituindo 20 de set_size_inches() por 12.

# %% [markdown]
# Ficou melhor. Agora já conseguimos eliminar aquele efeito de assimetria à direita. Inclusive, obtivemos um gráfico bem bonito e próximo à distribuição normal, que estamos tentando alcançar.
#
# Adiante, tentaremos obter uma relação linear entre as variáveis transformadas, no item "3.2 Verificando Relação Linear".

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>3.2 Verificando Relação Linear</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# Conseguimos transformar as variáveis e verificar que aquele problema de assimetria à direita já foi meio que consertado. No gráfico de Distribuição de Frequências elaborado com as variáveis transformadas, temos um dado bem mais comportado e próximo ao que teríamos em uma distribuição normal, que é o nosso objetivo.

# %% [markdown]
# Então, vamos verificar se essas variáveis transformadas apresentam uma relação linear entre elas. Para isso, podemos utilizar a seguinte linha, que usamos anteriormente:

# %% [markdown]
# ## <font color=red>Gráficos de dispersão entre as variáveis transformadas do dataset</font>

# %%
ax = sns.pairplot(dados, y_vars='log_Valor', x_vars=['log_Area', 'log_Dist_Praia', 'log_Dist_Farmacia'], height=5)
ax.fig.suptitle('Dispersão entre as Variáveis Transformadas', fontsize=20, y=1.05)
ax

# %% [markdown]
# A reutilizaremos, só que dessa vez, com as variáveis transformadas, para verificar se existe uma relação linear ou se continuará bagunçado e não conseguiremos prosseguir com a estimativa de um modelo de regressão linear, o que nos levaria a buscar outra técnica para trabalhar com esses dados.
#
# Selecionaremos a linha acima, a copiaremos e a colaremos na célula de "Gráficos de dispersão entre as variáveis transformadas do dataset", localizada no item "3.2 Verificando Relação Linear". Faremos as devidas alterações, adicionando log às variáveis, já que utilizaremos as variáveis transformadas. O código ficará da seguinte forma:

# %%
ax = sns.pairplot(dados, y_vars='log_Valor', x_vars=['log_Area', 'log_Dist_Praia', 'log_Dist_Farmacia'], height=5)
ax.fig.suptitle('Dispersão entre as Variáveis Transformadas', fontsize=20, y=1.05)
ax

# %% [markdown]
# Ao executar ("Shift + Enter"), obteremos os três gráficos e, principalmente no de log_Area, já percebemos uma relação linear crescente bastante forte. No de log_Dist_Praia, também é possível identificar uma relação linear para baixo, algo que já desconfiávamos — quanto mais distante da praia, menor o valor do imóvel —, uma correlação negativa. Já o de log_Dist_Farmacia, provavelmente apresentará um problema na hora de estimar a regressão, porque quase não há variação entre log_Valor e log_Dist_Farmacia, ele parece constante: os dados permanecem da mesma forma, tanto quando a variável log_Dist_Farmacia sobe, quanto quando ela desce, o comportamento da variável log_Valor permanece o mesmo. Anteriormente, já tínhamos percebido que a correlação é muito baixa com a variável dependente. Então, provavelmente, será eliminado com os testes que estudaremos nos próximos vídeos.

# %% [markdown]
# No próximo item, "4.1 Criando os Datasets de Treino e Teste", passaremos pela famosa fase de Data Science, na qual separaremos os dados em treino e teste. Mas, antes de iniciar a estimativa, estudaremos algumas técnicas que nos auxiliem a perceber que variáveis como log_Dist_Farmacia não são boas para manter o nosso modelo. Para isso, utilizaremos estatísticas de testes formais para identificar e poder afirmar que, por conta da estatística, podemos retirar essa variável do modelo ou podemos mantê-la porque ela tem significância para o estudo.
#
# Adiante, começaremos a estimar regressões lineares, com técnicas um pouco mais diferentes.

# %% [markdown]
# ## <font color=red>Consolidando o seu conhecimento</font>

# %% [markdown]
# Chegou a hora de você seguir todos os passos realizados por mim durante esta aula:
#
#   - Importar a biblioteca numpy
#
#   - Aplicar a transformação logarítmica aos dados do dataset
#
#   - Realizar a distribuição de frequências da variável dependente transformada
#
#   - Plotar os gráficos de dispersão entre as variáveis transformadas do dataset
#
#   - Analisar a dispersão entre as variáveis transformadas
#
# Caso já tenha feito, excelente. Se ainda não, é importante que você execute o que foi visto nos vídeos para poder continuar com a próxima aula.

# %% [markdown]
# ## <font color=red>O que aprendemos?</font>

# %% [markdown]
# Nesta aula, aprendemos:
#
#   - A transformar os dados
#
#      - Como aplicar a transformação logarítmica aos dados do dataset
#
#      - Como realizar a distribuição de frequências da variável dependente
# transformada
#
#   - Como plotar os gráficos de dispersão entre as variáveis transformadas do dataset
#
#   - Como analisar a dispersão entre as variáveis transformadas

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>4.1 Criando os *Datasets* de Treino e Teste</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# Anteriormente, identificamos as relações lineares entre as variáveis transformadas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# No último gráfico, de log_Dist_Farmacia, não conseguimos identificar uma tendência clara. Adiante, estudaremos como resolver esse problema e se utilizaremos essa variável ou não. Agora, começaremos a fase de estimação de modelos, algo em que realmente estamos interessados.
#
# Trabalharemos com uma técnica conhecida em Data Science, que consiste em pegar o Dataset e dividi-lo aleatoriamente em duas partes: uma para treino — utilizada para estimar o modelo — e outra para teste, justamente para testar o modelo estimado.
#
# Lembrete: fizemos isso no curso anterior também. Então, caso tenha feito, será uma ótima revisão. Caso não tenha feito, faremos de forma muito semelhante, para que não fiquem dúvidas.
#
# Então, no item "4.1 Criando os Datasets de Treino e Teste", começaremos preenchendo a célula de "Importando o train_test_split da biblioteca scikit-learn. Lembrando que alguns recursos estão linkados com a respectiva "Ajuda". Continuando, faremos a importação de uma ferramenta do scikit-learn, que nos ajudará a separar o arquivo em treino e teste, preenchendo a célula da seguinte forma:

# %% [markdown]
# ## Importando o *train_test_split* da biblioteca *scikit-learn*
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Feita a importação, seguiremos para a criação de uma Series e de um DataFrame, que serão alimentadas por uma função. Primeiro preencheremos a célula de "Criando uma Series (pandas) para armazenar o Preço de Imóveis (y)" com:

# %% [markdown]
# ## Criando uma Series (pandas) para armazenar o Preço dos Imóveis (y)

# %%
y = dados['log_Valor']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-2118601649.py in <cell line: 0>()
# ----> 1 y = dados['log_Valor']
#
# NameError: name 'dados' is not defined

# %% [markdown]
# Na sequência, faremos o mesmo para as variáveis explicativas, na célula de "Criando um DataFrame (pandas) para armazenar as variáveis explicativas (X)", que será preenchida da seguinte forma:

# %% [markdown]
# ## Criando um DataFrame (pandas) para armazenar as variáveis explicativas (X)

# %%
X = dados[['log_Area', 'log_Dist_Praia', 'log_Dist_Farmacia']]

# %% [markdown]
# ## Criando os datasets de treino e de teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2811)

# %% [markdown]
# Após preencher a célula, acionaremos "Shift + Enter". Agora, já temos os dois grupos de variáveis que serão alimentados com a função train_test_split.
#
# Na próxima célula, "Criando os datasets de treino e de teste" vamos retomar o desempacotamento de tuplas. Trata-se do retorno que obteremos da função inserida nessa célula. No caso, a função será composta por:
#
#    - X, DataFrame com as variáveis explicativas;
#
#    - y, variável dependente, considerando que treino e teste também serão criados para ela também;
#
#    - test_size=0.2, para especificar o tamanho de arquivo de teste e de treino. Para definir o tamanho, podemos usar um de dois tipos de parâmetros. No caso, usamos test_size e estabelecemos que o arquivo de teste terá 20% (0.2) do conjunto de dados, mas poderíamos ter usado train_size=0.8 como alternativa;
#
#    - random_state=2811, para termos resultados idênticos — eu e você que está fazendo o curso. É similar ao seed de um gerador de números aleatórios: ao fixarmos um número nele — se você utilizar o mesmo número que eu, no caso, 2811 —, obteremos o mesmo resultado. Caso contrário, teremos resultados com amostras aleatórias diferentes.
#
# Com isso, a célula ficará da seguinte forma:

# %%
train_test_split(X, y, test_size=0.2, random_state=2811)

# %% [markdown]
# Ao executar, obteremos uma listagem na qual são criados quatro conjuntos de dados diferentes. No caso, queremos esses conjuntos em variáveis diferentes. Para isso, retomaremos o desempacotamento de tuplas ou de lista.
#
# A ordem que estabelecemos na função é a ordem que obteremos no retorno dela. Então, na primeira linha da listagem, separados pelas seguintes colunas, encontramos:

# %% [markdown]
# Então, vamos separar esses dados, adicionando ao início da célula de "Criando os datasets de treino e teste":
#
#   - X_train, que é o X de train (treino);
#
#   - X_test;
#
#   - y_train;
#
#   - y_test.
#
# Os nomes das variáveis que foram utilizados são idênticos aos encontrados na "Ajuda" do scikit-learn, por isso os utilizamos, mas fique à vontade para nomear da forma que achar melhor.
#
# Após a alteração, a célula de "Criando os datasets de treino e teste" ficará assim:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2811)

# %% [markdown]
# Agora, ao executar, os dados serão armazenados dentro das variáveis. Podemos pegar um de exemplo, acionando "Esc + B" para adicionar uma célula abaixo da que acabamos de preencher e preenchê-la com:

# %%
X_train

# %% [markdown]
# Ao executar, obteremos um DataFrame com o X_train, referente às variáveis explicativas que utilizaremos para estimar o modelo.

# %% [markdown]
# Feito isso, podemos apagar a célula que acabamos de adicionar para demonstração.
#
# Adiante, faremos a primeira estimativa do modelo utilizando uma ferramenta diferente, o StatsModels, antes de utilizar o scikit-learn.

# %% [markdown]
# ## Trabalhando com StatsModels

# %% [markdown]
# Continuando o que iniciamos anteriormente, após separar os dados em treino e teste, agora, entenderemos um pouco de regressão linear. Trata-se do estudo da dependência de uma variável em relação a uma ou mais variáveis explicativas.
#
# No Dataset, você encontra um texto sobre regressão linear. Nele, há uma menção do scikit-learn, que utilizaremos. Pouco mais abaixo, encontra-se "Importando a biblioteca statsmodels" e sua respectiva célula.
#
# Utilizaremos essa ferramenta para fazer a primeira estimativa, analisando algumas estatísticas mais formais do modelo para tentar estimar um modelo melhor e, depois, realizar os testes a partir dele. Posteriormente, voltamos a utilizar o scikit-learn.
#
# O nosso Modelo log-linear é um pouco diferente do que utilizamos no curso anterior, é o modelo que transformamos. Inicialmente, tínhamos uma forma funcional do tipo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Com ela, percebemos que as relações entre as variáveis não são lineares e geram dificuldade para identificar as retas. Após uma transformação logarítmica, chegamos à seguinte fórmula funcional:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Deixamos também as propriedades dos logaritmos, que é matemática pura em que A e B são variáveis positivas e k é uma constante.
#
#  1. ln(AB) = ln A + ln B
#
#  2. ln(A/B) = ln A - ln B
#
#  3. ln(Aᵏ) = k ln A
#
#  4. ln e = 1
#
# Na primeira propriedade, mostramos que o log de A vezes B é igual ao log de A mais B. Depois, o log de A dividido por B é igual ao log de A menos B. Em seguida, o log de A elevado a k é igual a k vezes o log de A. Por fim, o log de e é igual a um. Neste caso, estamos usando um logarítmo niperiano ou natural como é conhecido, e por isso usamos o e.
#
# É interessante entender como passamos da fórmula funcional para a outra usando essas propriedades simples.
#
# Agora conheceremos uma nova ferramenta, que é a biblioteca statsmodel, a qual faz estimações e gera testes de hipótese, tendo uma característica mais estatística, o que é bem parecido com a linguagem R.
#
# Queremos mostrá-la justamente porque tem outputs com testes mais formais, e veremos alguns mais importantes. Aprenderemos a identificar e interpretá-los de forma simples e rápida sem precisarmos entrar em detalhes sobre teste de hipótese neste momento, pois apenas precisamos entender como aceitar ou rejeitar no dia-a-dia.
#
# Importaremos o statsmodels, mas como estamos usando o Anaconda, já vem com a biblioteca instalada, mas caso ainda não tenhamos, a documentação pode ajudar. Em nosso caso, a instalação usando conda seria mais apropriado, porém na versão que estamos utilizando já está instalada.
#
# O import será de statsmodels.api como sm, e apertaremos "Shift + Enter" para importar.
#
# Estimamos modelos com contantes como já vimos no curso anterior, e agora queremos estimar um modelo com a constante intercepto. Nesta biblioteca, precisamos colocá-la dentro do dataframe que iremos utilizar com .  explicativas para gerar as estimativas.
#
# Para isso, há uma ferramenta que iremos chamar. Mas para não atrapalhar o conjunto de variáveis explicativas de treino X_train que criamos anteriormente, criaremos um novo.
#
# O chamaremos de X_train_com_constante, e chamaremos o statsmodels escrevendo apenas sm seguido de .add_constant(), passando o dataframe X_train.

# %%
X_train_com_constante = sm.add_constant(X_train)

# %% [markdown]
# Executando a célula, mostraremos o resultado disso em seguida:

# %%
X_train_com_constante

# %% [markdown]
# Com isso, já teremos uma variável const que é uma constante com o valor 1.0. Se já tivermos estudado Estatística, já teremos visto a álgebra matricial por trás da estimação de modelos de regressão lineares utilizando o método OLS(), que significa os mínimos quadrados ordinários.
#
# Veremos que isso é a forma como estima as matrizes e calcula o intercepto, criando uma coluna com 1.0, e é isso que o statsmodels precisa que forneçamos.
#
# Fornecido isso, teremos um novo dataframe que é o que utilizaremos para fazer as estimativas e analisar as estatísticas. Portanto, daremos um nome modelo_statsmodels em seguida, e só o utilizaremos na análise dos testes.
#
# Chamaremos sm com .OLS() passando o y_train que criamos anteriormente, seguido do X_train_com_constate, pois do contrário não teríamos um modelo com constante e não irá adicioná-la.
#
# Também passaremos que queremos a constante escrevendo hasconst sendo igual a True. Após o método, aplicaremos .fit() para fazermos o ajuste do modelo.
#
# Isso já nos gera um objeto modelo_statsmodels que analisaremos mais adiante em detalhes. Numa nova célula seguinte, veremos que este já possui um sumário com as estatísticas escrevendo modelo_statsmodels.summary(), mas também analisaremos isso futuramente.

# %% [markdown]
# # Regressão Linear
# <hr>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>A análise de regressão diz respeito ao estudo da dependência de uma variável (a variável <b>dependente</b>) em relação a uma ou mais variáveis, as variáveis explanatórias, visando estimar e/ou prever o valor médio da primeira em termos dos valores conhecidos ou fixados das segundas.</p>
#
#
# ## scikit-learn (https://scikit-learn.org/stable/)
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>O *scikit-learn* é um módulo Python especializado em soluções para *machine learning*.</p>

# %% [markdown]
# <img width='800px' src='/content/Log-linear.png'>

# %% [markdown]
# ## Importando a biblioteca statsmodels
#
# https://www.statsmodels.org/stable/index.html

# %%
import statsmodels.api as sm

# %% [markdown]
# ## Estimando o modelo com statsmodels

# %%
X_train_com_constante = sm.add_constant(X_train)

# %%
X_train_com_constante

# %%
modelo_statsmodels = sm.OLS(y_train, X_train_com_constante, hasconst = True).fit()

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>4.2 Avaliando o Modelo Estimado</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# No último vídeo, fizemos a estimação do modelo e adicionamos a estimativa toda dentro da variável modelo_statsmodels e mostramos o resultado, que será o foco desta aula.
#
# Continuando em 4.2 Avaliando o Modelo Estimado vamos reproduzir o que havíamos feito anteriormente com modelo_statsmodels.summary() que apresentará o sumário da estimativa . Lembre-se que caso você não esteja usando o Júpiter não terá visualização sem que se faça um print print(modelo_statsmodels.summary())

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Deixamos dessa forma no vídeo para que todos possam ter a mesma visualização.
#
# Focalizaremos em apenas duas estatísticas, que são bastante relevantes - as outras não serão abordadas pois cada uma tem a sua peculiaridade - que são o teste F e o teste T.
#
# Aqui, conseguimos ver também o R-squared que é o R2 em que alcançamos 80% o R2 (Adj. R-squared) ajustado também é uma estatística interessante que é basicamente o que considera os graus de liberdade, ou seja, se colocarmos muitas variáveis ele vai diminuindo seu grau de liberdade.
#
# O R2 está sempre subindo ou se mantendo o mesmo, ele nunca cai, o R2 ajustável tem por característica,conforme adicionamos muitas propriedades, ou seja, perdermos o grau de liberdade e ganhamos em explicação. Ele começa a cair, este é seu indicativo.
#
# O teste F (F-statistic) é um teste de importante - todos estes são testes de hipótese - que testa a significância de todos os parâmetros do modelo em conjunto. O teste que ele faz é se você aceita a hipótese ou não desses itens conjuntamente serem iguais a zero, ou seja, regressão de sentido. Como verificar isso de forma simples?
#
# Tínhamos a estatística de Teste (F-statistic) 5495 e a Aceitação (Prob (F-statisc)) de 0.00. Valores acima de 0.05, rejeitamos o modelo, ou seja, ele não é estatisticamente significativo, segundo essa estatística eles são praticamente zero, a regressão não é boa. Ao nível de 95% em Prob F Statistic você teria que ter uma estatística menor ou igual a0.05, maior que isso nosso modelo precisaria ser revisto.
#
# Indo aqui para o teste individual dos parâmetros, temos a constante que foi uma variável criada no vídeo anterior.

# %%
X_train_com_constante = sm.add_constant(X_train)
X_train_com_constante

# %% [markdown]
# Também aqui temos o teste t com as estatísticas para cada variável. P>|t| é o equivalente ao Prob (F-statistic) então funciona da mesma maneira que ele. Identificamos que o parâmetro não é estatisticamente significativo, ou seja, ele tá dizendo que esse parâmetro. Nota-se, portanto, que o parâmetro log_Dist_Farmacia não passa no testes, que testa se "esse cara é igual a zero ou não".
#
# O teste T testa a significância individual dos parâmetros e o teste F a significância conjunta dos parâmetros, ou seja, T se ele é zero ou não e se todos são zero ou não conjuntamente.
#
# Agora entendemos os testes mais importantes e no próximo videos vamos reestimar o modelo eliminando' log_Dist_Farme vendo o que acontece com as estatísticas e também com os outros parâmetros/variáveis.

# %% [markdown]
# ## Avaliando as estatísticas de teste do modelo

# %%
print(modelo_statsmodels.summary())

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>4.3 Modificando o Modelo e Avaliando Novamente o Ajuste</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# No vídeo anterior, identificamos que a variável log_Dist_Farmacia não é estatisticamente significativa por conta do parâmetro P>|t| ser 0.603, ou seja, significativamente maior que 0.05. Então vamos reestimar esse nosso modelos eliminando esse variável e vamos ver o resultado que obteremos a partir disso.
#
# ## 4.3 Modificando o Modelo e Avaliando Novamente o Ajuste
#
# Para isso, é necessário refazer o sistema de treino e teste, então vamos começar com o X. As variáveis independentes não vão mudar, o que vai mudar é o conjunto de variáveis explicativas. o X será reproduzido da mesma maneira como o anteriores mas sem o log_Dist_Farmacia.
#
# ## Criando um novo conjunto de variáveis explicativas (X)

# %% [markdown]
# ## Criando um novo conjunto de variáveis explicativas (X)

# %%
X = dados[['log_Area', 'log_Dist_Praia']]

# %% [markdown]
# ## Criando os datasets de treino e de teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2811)

# %% [markdown]
# Dessa forma ele cria um novo X de treino e de teste sem a variável de log_Dist_Farmacia
#
# Estimando o modelo com statsmodels
# O modelo precisa novamente ser estimado. Para isso, são necessários dois passos

# %% [markdown]
# ## Estimando o modelo com o statsmodels

# %%
X_train_com_constante = sm.add_constant(X_train)

# %%
modelo_statsmodels = sm.OLS(y_train, X_train_com_constante, hasconst = True).fit()

# %% [markdown]
# ## Avaliando as estatísticas de teste do novo modelo
#
# ### Teste de significância conjunta dos parâmetros
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>Prob (F-statistic) <= 0.05 (<b>OK</b>)</p>
#
# ### Teste de significância individual dos parâmetros
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>P>|t| <= 0.05 (<b>OK</b>)</p>

# %%
print(modelo_statsmodels.summary())

# %% [markdown]
# Reparem que nosso R2 (R-squared) ficou estacionado o que mostra que a variável log_Dist_Praia era bastante ruim porque como anteriormente dito, se é colocado informação e e ele está sempre aumenta o valor do R2 e nesse caso vemos que o R2 travou, logo, continua com R2 bom. Analisando nossa estatística de teste F, também passou - aqui os valores de F sendo menor ou igual a 0.05 foram deixados como cortesia
#
# Podemos assumir que esse modelo está bem estimado.
#
# Mais para frente vamos usar essa especificação de X, as variáveis explicativas e vamos voltar scikit-learn e fazer toda a modelagem que já aprendemos para estimar com os dados de treino e modelo e testar no teste e ver os resultados obteremos.

# %% [markdown]
# ## Consolidando o seu conhecimento

# %% [markdown]
# Chegou a hora de você seguir todos os passos realizados por mim durante esta aula:
#
#   - Importando a função train_test_split da biblioteca scikit-learn
#
#   - Criar uma Series, do pandas, para armazenar o preço dos imóveis
#
#   - Criar um DataFrame, do pandas, para armazenar as variáveis explicativas
#
#   - Criar os datasets de treino e de teste
#
#   - Importar a biblioteca statsmodels
#
#   - Estimar o modelo de regressão linear
#
#   - Avaliar as estatísticas do teste de modelo
#
#   - Modificar o modelo e avaliar o ajuste
#
# Caso já tenha feito, excelente. Se ainda não, é importante que você execute o que foi visto nos vídeos para poder continuar com a próxima aula.

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>5.1 Estimando o Modelo com os Dados de Treino</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# Já fizemos a especificação do nosso modelo ao elaborar testes formais. Mesmo utilizando poucas variáveis, conseguimos elaborar um modelo interessante para este projeto. A proposta agora é retornar ao scikit-learn e fazer as estimativas no padrão data science. Primeiramente, iremos importar as bibliotecas a serem utilizadas:

# %% [markdown]
# ## Importando *LinearRegression* e *metrics* da biblioteca *scikit-learn*
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# https://scikit-learn.org/stable/modules/classes.html#regression-metrics

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ## Instanciando a classe *LinearRegression()*

# %%
modelo = LinearRegression()

# %% [markdown]
# Assim feito, utilizaremos o método fit() para realizar o ajuste e estimar nosso modelo linear utilizando os dados de treino.

# %% [markdown]
# ## Utilizando o método *fit()* do objeto "modelo" para estimar nosso modelo linear utilizando os dados de TREINO (y_train e X_train)
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.fit

# %%
modelo.fit(X_train, y_train)

# %% [markdown]
# O que faremos agora é obter R² utilizando o sckitlearn, e faremos um arredondamento dos valores ao utilizar o round() :

# %% [markdown]
# Teremos como saída o valor R² = 0.805. Em seguida, iremos calcular o R², mas para utilizar esse valor na previsão. Criaremos uma variável y_previsto, então escreveremos:

# %% [markdown]
# ## Obtendo o coeficiente de determinação (R²) do modelo estimado com os dados de TREINO
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score
#
# ### Coeficiente de Determinação - R²
#
# O coeficiente de determinação (R²) é uma medida resumida que diz quanto a linha de regressão ajusta-se aos dados. É um valor entra 0 e 1.
#
# $$R^2(y, \hat{y}) = 1 - \frac {\sum_{i=0}^{n-1}(y_i-\hat{y}_i)^2}{\sum_{i=0}^{n-1}(y_i-\bar{y}_i)^2}$$

# %% [markdown]
# O que faremos agora é obter R² utilizando o sckitlearn, e faremos um arredondamento dos valores ao utilizar o round() :

# %%
print('R² = {}'.format(modelo.score(X_train, y_train).round(3)))

# %% [markdown]
# Teremos como saída o valor R² = 0.805. Em seguida, iremos calcular o R², mas para utilizar esse valor na previsão. Criaremos uma variável y_previsto, então escreveremos:

# %%
y_previsto = modelo.predict(X_test)

# %% [markdown]
# Agora, obteremos o coeficiente de determinações para as previsões do nosso modelo:

# %%
print('R² = %s' % metrics.r2_score(y_test, y_previsto).round(3))

# %% [markdown]
# Teremos como resultado R² = 0.79, bastante positivo, pois não apresenta uma diferença de valor muito grande do valor calculado anteriormente para o conjunto de dados.
#
# Nas próximas aulas obteremos previsões pontuais.

# %% [markdown]
# ## Gerando previsões para os dados de TESTE (X_test) utilizando o método *predict()* do objeto "modelo"
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.predict

# %% [markdown]
# ## Obtendo o coeficiente de determinação (R²) para as previsões do nosso modelo
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score

# %%
print('R² = %s' % metrics.r2_score(y_test, y_previsto).round(3))

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>5.2 Obtendo Previsões Pontuais</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# Estamos caminhando para a fase final do nosso projeto. Fizemos a estimativa do nosso modelo, e agora aprenderemos a obter as previsões pontuais ou de um grupo de valores.
#
# Continuaremos a usar os dados de teste, que serão armazenados na variável entrada, e coletaremos o primeiro registro do dataset.

# %% [markdown]
# ## Dados de entrada

# %%
entrada = X_test[0:1]
entrada

# %% [markdown]
# Para gerar a previsão, chamaremos o modelo.predict, passaremos a entrada e acrescentaremos [0] para indicar que queremos o primeiro elemento do array,:

# %% [markdown]
# ## Gerando previsão pontual

# %%
modelo.predict(entrada)[0]

# %% [markdown]
# Teremos como saída uma previsão de 14.28. Não se trata de um valor de imóvel, afinal como realizamos uma transformação para a escala logarítmica, e precisamos inverter essa transformação para obter o valor em reais.

# %% [markdown]
# ## Invertendo a transformação para obter a estimativa em R$
#
# https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.exp.html

# %%
modelo.predict(entrada)[0]

# %% [markdown]
# Teremos uma saída de 1598889.784, agora sim temos o valor convertido para reais. Em seguida, geraremos um simulador simples em que podemos utilizar quaisquer valores que sejam do nosso interesse. Lembrando que os valores passados pelo usuário não estarão em log, então precisaremos realizar essa transformação posteriormente.

# %% [markdown]
# Teremos como saída uma previsão de 14.28. Não se trata de um valor de imóvel, afinal como realizamos uma transformação para a escala logarítmica, e precisamos inverter essa transformação para obter o valor em reais.

# %%
np.exp(modelo.predict(entrada)[0])

# %% [markdown]
# ## Criando um simulador simples

# %%
Area = 250
Dist_Praia = 1
entrada = [[np.log(Area), np.log(Dist_Praia + 1)]]

print('R$ {0: 2f}'.format(np.exp(modelo.predict(entrada)[0])))

# %% [markdown]
# Teremos como resultado o valor de 2777292.84, então essa é o valor estimado de um imóvel com essas características. Podemos alterar os valores para obter resultados diferentes.

# %%
Area = 150
Dist_Praia = 1
entrada = [[np.log(Area), np.log(Dist_Praia + 1)]]

print('R$ {0:.2f}'.format(np.exp(modelo.predict(entrada)[0])))

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>5.3 Interpretação dos Coeficientes Estimados</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Obtendo o intercepto do modelo
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>O <b>intercepto</b> representa o efeito médio em $Y$ (Preço do Imóveis) tendo todas as variáveis explicativas excluídas do modelo. No caso do modelo log-linear este coeficiente deve ser transformado com o uso da função exponencial para ser apresentado em R$.</p>

# %%
modelo.intercept_

# %%
np.exp(modelo.intercept_)

# %% [markdown]
# ## Obtendo os coeficientes de regressão
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>Os <b>coeficientes de regressão</b> $\beta_2$ e $\beta_3$ são conhecidos como <b>coeficientes parciais de regressão</b> ou <b>coeficientes parciais angulares</b>. </p>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>Um aspecto interessante do modelo log-linear, que o tornou muito utilizado nos trabalhos aplicados, é que os coeficientes angulares $\beta_2$ e $\beta_3$ medem as elasticidades de Y em relação a $X_2$ e $X_3$, isto é, a variação percentual de Y correspondente a uma dada variação percentual (pequena) em $X_2$ e $X_3$.</p>

# %% [markdown]
# á estimamos o modelo e criamos previsões pontuais. Nesta aula, nos debruçaremos sobre a interpretação dos coeficientes no modelo log-linenar. Muitas vezes em algum projeto estamos interessados em medir qual é o efeito das variáveis de maneira individual, e assim descobrir qual é mais significativa para o seu negócio.
#
# Começaremos pelo intercepto, a constante que criamos. O intercepto representa o efeito médio em Y (preço do Imóvel) tendo todas as variáveis explicativas excluídas do modelo. No caso do modelo log-linear, este coeficiente deve ser transformado com o uso da função exponencial para ser apresentado em reais(R$). Para obter o intercepto, escreveremos:

# %%
modelo.coef_

# %% [markdown]
# A saída será de 9.334916. Faremos a transformação do valor obtido em reais, ao escrever:

# %% [markdown]
# ## Confirmando a ordem das variáveis explicativas no DataFrame

# %%
np.exp(modelo.intercept_)

# %% [markdown]
# Agora começaremos a obter os coeficientes de regressão, também conhecidos como coeficientes parciais angulares. Esse tipo de modelo é muito utilizado em estudos econômicos, pois eles medem o que chamamos de elasticidade da variável dependente em relação às variáveis explicativas. A variação percentual de Y corresponde a uma dada variação percentual (pequena) em X2 e X3. Para obter esses coeficientes de forma simples, escreveremos:

# %%
modelo.coef_

# %% [markdown]
# e teremos como saída os dois coeficientes:
#
# array([ 1.05807818, -0.49061226])
#
# Criaremos uma pequena coluna para confirmar a ordem das variáveis explicativas no dataframe:

# %%
X.columns

# %% [markdown]
# Em seguida, criaremos um dataframe para guardar as informações dos coeficientes e exibir uma tabela no Jupyter.

# %% [markdown]
# Exibiremos um dataframe para armazenar os coeficientes do modelo:

# %% [markdown]
# ## Criando uma lista com os nomes das variáveis do modelo

# %%
index = ['Intercepto', 'log Área', 'log Distância até a Praia']

# %% [markdown]
# Exibiremos um dataframe para armazenar os coeficientes do modelo:

# %% [markdown]
# ## Criando um DataFrame para armazenar os coeficientes do modelo
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.append.html?#numpy.append

# %%
pd.DataFrame(data=np.append(modelo.intercept_, modelo.coef_), index=index, columns=['Parâmetros'])

# %% [markdown]
# Agora iremos à interpretação dos coeficientes estimados. Intercepto: excluindo o efeito das variáveis explicativas (X2 = X3 = 0 ) o efeito médio o Preço dos Imóveis seria de R$ 11.326,68 (exp[9.334916]).
#
# Área(m²): Mantendo-se o valor de X3 (Distância até a Praia) constante, um acréscimo de 1% ma Área de imóvel gera, em média, um acréscimo de 1.06% no Preço Imóvel.
#
# Distância até a Praia(km): mantendo-se o valor de X2 (Área) constante, um acréscimo de 1% da Distância de um imóvel até a praia gera, em média, decréscimo de 0.49% no Preço do Imóvel.
#
# Nas próximas aulas faremos análises gráficas do resíduo e da estimativa e fechamos nosso curso.

# %% [markdown]
# ## Interpretação dos Coeficientes Estimados
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>
# <b>Intercepto</b> → Excluindo o efeito das variáveis explicativas ($X_2=X_3=0$) o efeito médio no Preço dos Imóveis seria de <b>R$ 11.326,68</b> (exp[9.334916]).
# </p>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>
# <b>Área (m²)</b> → Mantendo-se o valor de $X_3$ (Distância até a Praia) constante, um acréscimo de 1% na Área de um imóvel gera, em média, um acréscimo de <b>1.06%</b> no Preço do Imóvel.
# </p>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>
# <b>Distância até a Praia (km)</b> → Mantendo-se o valor de $X_2$ (Área) constante, um acréscimo de 1% na Distância de um imóvel até a praia gera, em média, um decréscimo de <b>0.49%</b> no Preço do Imóvel.
# </p>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>5.4 Análises Gráficas dos Resultados do Modelo</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Gerando as previsões do modelo para os dados de TREINO

# %% [markdown]
# Nesta aula, nos voltaremos para as análises gráficas dos resultados do modelo que estimamos. Começaremos gerando as previsões do modelo para os dados de treino, assim poderemos plotar o dado real com o dado que foi previsto. Escreveremos:

# %% [markdown]
# Faremos um scatterplot() e utilizaremos algumas configurações de formatação:

# %%
y_previsto_train = modelo.predict(X_train)

# %% [markdown]
# ## Gráfico de dispersão entre valor estimado e valor real
#
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
ax = sns.scatterplot(x=y_previsto_train, y=y_train)
ax.figure.set_size_inches(12, 6)
ax.set_title('Previsão X Real', fontsize=18)
ax.set_xlabel('log do Preço - Previsão', fontsize=14)
ax.set_ylabel('log do Preço - Real', fontsize=14)
ax

# %% [markdown]
# Não temos uma grande dispersão em nosso gráfico, o que indica que nossa estimativa está mais precisa. Obviamente que preços de imóvel são flutuantes e precisaríamos de mais variáveis para ajustar esse gráfico à realidade.
#
# Nosso próximo ponto é exibir os resíduos, lembrando que o resíduo em nossa equação corresponde ao Ui:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Criaremos uma variável residuo que corresponderá:

# %% [markdown]
# ## Obtendo os resíduos

# %%
residuo = y_train - y_previsto_train

# %% [markdown]
# Assim feito, iremos realizar a plotagem:

# %% [markdown]
# ## Plotando a distribuição de frequências dos resíduos

# %%
ax = sns.distplot(residuo)
ax.figure.set_size_inches(12, 6)
ax.set_title('Distribuição de Frequências dos Resíduos', fontsize=18)
ax.set_xlabel('log do Preço', fontsize=14)
ax

# %% [markdown]
# Como resultado, teremos uma curva agradável que indica dados bem comportados, o que favorece um modelo bem estimado.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# É importante frisar que este se trata de um estudo, e não de um modelo a ser usado comercialmente, que precisaria de mais variáveis e elementos para operar de maneira funcional. Contudo, conseguimos antever qual seria o comportamento adequado para que um modelo estimativo nos fornecesse informações seguras, e para este fim, nosso projeto cabe perfeitamente.

# %% [markdown]
# ## Consolidando o seu conhecimento

# %% [markdown]
# Chegou a hora de você seguir todos os passos realizados por mim durante esta aula:
#
#   - Estimar o modelo linear utilizando os dados de treino
#
#   - Obter o coeficiente de determinação (R²) do modelo estimado
#
#   - Gerar as previsões para os dados de teste do modelo
#
#   - Obter o coeficiente de determinação (R²) para as previsões do modelo
#
#   - Gerar a previsão pontual do modelo
#
#   - Inverter a transformação para obter a estimativa em reais
#
#   - Criar um simulador simples
#
#   - Obter o intercepto do modelo
#
#   - Obter os coeficientes de regressão
#
#   - Criar um DataFrame para armazenar os coeficientes do modelo
#
#   - Interpretar os coeficientes estimados
#
#   - Analisar graficamente os resultados do modelo
#
# Caso já tenha feito, excelente. Se ainda não, é importante que você
# execute o que foi visto nos vídeos para poder continuar com os próximos cursos que tenham este como pré-requisito.

# %% [markdown]
# ## O que aprendemos?

# %% [markdown]
# ## Nesta aula, aprendemos:
#
#    - Como estimar o modelo linear utilizando os dados de treino
#
#    - Como obter o coeficiente de determinação (R²) do modelo estimado
#
#    - Como gerar as previsões para os dados de teste do modelo
#
#    - Como obter o coeficiente de determinação (R²) para as previsões do modelo
#
#    - Como gerar a previsão pontual do modelo
#
#    - Como inverter a transformação para obter a estimativa em reais
#
#    - Como criar um simulador simples
#
#    - Como obter o intercepto do modelo
#
#    - Como obter os coeficientes de regressão
#
#    - Como criar um DataFrame para armazenar os coeficientes do modelo
#
#    - Como interpretar os coeficientes estimados
#
#    - Como analisar graficamente os resultados do modelo
